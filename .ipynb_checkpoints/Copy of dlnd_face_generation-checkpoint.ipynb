# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
#!pip install --upgrade pip
#!pip install torch
#!pip install torchvision
#!pip install -U numpy
#!pip show numpy

# %%
# necessary imports
import pandas as pd
import torch
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from PIL import Image 
import glob
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip > /dev/null

# %%
from google.colab import files
def getLocalFiles():
    _files = files.upload()
    if len(_files) >0:
       for k,v in _files.items():
         open(k,'wb').write(v)
getLocalFiles()
# Out:
#      <input type="file" id="files-d63636d5-7862-45b5-953d-d4f9ba186e98" name="files[]" multiple disabled />
#      <output id="result-d63636d5-7862-45b5-953d-d4f9ba186e98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving problem_unittests.py to problem_unittests.py

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests


# %matplotlib inline

# %%
# Parameter settings
train_n = 44
param = 'drop'

# set parameter sets
number_epochs = [1, 10, 50, 100, 500, 1000]
lr_set = [0.0002]
batch_size_set = [32]
conv_dim_set = [64, 128, 256]

# default
batch_size = 32
img_size = 32
n_epochs = 101
conv_dim = 64
lr = 0.0002
beta1=0.2
beta2=0.999
z_size = 100

# %%
# Make directories if they do not exist
data_dir_2 = './training_results_pkl'
if not os.path.exists(data_dir_2):
    os.makedirs(data_dir_2)
    
data_dir_2 = './training_results'
if not os.path.exists(data_dir_2):
    os.makedirs(data_dir_2)
    
data_dir_2 = './image_sets'
if not os.path.exists(data_dir_2):
    os.makedirs(data_dir_2)

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
print('Number of images used for the Discriminator Training: ', len(glob.glob("processed_celeba_small/celeba/*.jpg")))
# Out:
# Number of images used for the Discriminator Training:  32600

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    # Tensor transform
    transform = transforms.Compose([transforms.Resize(image_size),
                                    transforms.CenterCrop(image_size),
                                    transforms.ToTensor()
                                    ])
    
    dataset = datasets.ImageFolder(data_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size, shuffle=True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=16
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %%
fig.savefig('image_sets/orig_examples.png')

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
     # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.9922)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim=32):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32x32 input
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # first layer, no batch_norm
        # 16x16 out
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        # 8x8 out
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        # 4x4 out
        self.conv4 = conv(conv_dim*4, conv_dim*8, 4)
        # 2x2 out
        
        # final, fully-connected layer
        self.fc = nn.Linear(conv_dim*8*2*2, 1)
        
        # set dropout layer
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv3(out), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv4(out), 0.2)
        # flatten
        out = out.view(-1, self.conv_dim*8*2*2)
        out = self.dropout(out)
        # final output layer
        out = self.fc(out)        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # first, fully-connected layer
        self.fc = nn.Linear(z_size, conv_dim*8*2*2)

        # transpose conv layers
        self.t_conv1 = deconv(conv_dim*8, conv_dim*4, 4)
        self.t_conv2 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv3 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv4 = deconv(conv_dim, 3, 4, batch_norm=False)
        
        # set dropout layer
        self.dropout = nn.Dropout(p=0.5)
        

    def forward(self, x):
        # fully-connected + reshape 
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*8, 2, 2) # (batch_size, depth, 2, 2)
        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out = self.dropout(out)
        out = F.relu(self.t_conv2(out))
        out = self.dropout(out)
        out = F.relu(self.t_conv3(out))
        out = self.dropout(out)
        # last layer + tanh activation
        out = self.t_conv4(out)
        out = F.tanh(out)
        
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed
# /anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
# takes in a module and applies the specified weight initialization
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and classname.find('Linear') != -1:
        m.weight.data.normal_(0, 0.02)
        m.bias.data.fill_(0)
    
    elif hasattr(m, 'weight') and classname.find('Conv') != -1:
        m.weight.data.normal_(0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        labels = torch.ones(batch_size)*0.9 # smooth, real labels = 0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models.

# %%
# Create optimizers for the discriminator and generator
def optimizer(lr):
    d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
    g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

    return d_optimizer, g_optimizer

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
# save chosen hyperparameters of the actual training run to an excel file
def save_data(index, losses, batch_size):
    losses = np.array(losses)
    
    # Export Loss as Dataframe
    idx = range(len(losses.T[0]))
    d = {'Discriminator': losses.T[0], 'Generator': losses.T[1]}
    loss_df = pd.DataFrame(data=d, index = idx)
    train_number = train_n + index
    loss_df.to_excel('training_results/train_' + str(train_number) +'_'+ param + ".xlsx")
    
    # Export hyperparameters
    hyper_params = {'batch_size': batch_size,
                'img_size': img_size,
                'deconv-layers': 3,
                'conv-layers': 3,
                'd_conv_dim': d_conv_dim,
                'g_conv_dim': g_conv_dim,
                'z_size': z_size,
                'lr': lr,
                'beta1': beta1,
                'beta2': beta2,
                'dropout': 'no',
                'n_epochs': n_epochs
                }
    hyper_param_df = pd.DataFrame.from_dict(hyper_params, orient='index')
    hyper_param_df.to_excel('training_results/train_' + str(train_number) +'_'+ param + "_hyper_param.xlsx")
    print(hyper_params)

# %%
# plot the training losses of Discriminator and Generator for the actual training run
def plot_training_loss(losses):
    print('Plot Loss')
    fig, ax = plt.subplots()
    losses = np.array(losses)
    plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
    plt.plot(losses.T[1], label='Generator', alpha=0.5)
    plt.title("Training Losses")
    plt.legend()
    plt.show()

# %%
# helper function for viewing a list of passed in sample images
def view_samples(index, epoch):
    print('View Samples')
    train_number = train_n + index
    # Load samples from generator, taken while training
    with open('training_results_pkl/train_' + str(train_number) +'_'+ param + '_' + str(epoch) + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[-1]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))
    plt.show()

# %%
def train(D, G,  n_epochs, index=0, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    train_number = train_n + index
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # ============================================
            #            TRAIN THE DISCRIMINATOR
            # ============================================

            d_optimizer.zero_grad()

            # 1. Train with real images

            # Compute the discriminator losses on real images 
            if train_on_gpu:
                real_images = real_images.cuda()

            D_real = D(real_images)
            d_real_loss = real_loss(D_real)

            # 2. Train with fake images

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)

            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()


            # =========================================
            #            TRAIN THE GENERATOR
            # =========================================
            g_optimizer.zero_grad()

            # 1. Train with fake images and flipped labels

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels

            # perform backprop
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

        if epoch % 10 == 0:
            # Save training generator samples
            with open('training_results_pkl/train_' + str(train_number) +'_'+ param + '_' + str(epoch) + '_samples.pkl', 'wb') as f:
                pkl.dump(samples, f)
                
            _ = view_samples(index, epoch)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
n_epochs=1
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/    1] | d_loss: 1.5122 | g_loss: 0.8811
# Epoch [    1/    1] | d_loss: 0.2128 | g_loss: 3.0479
# Epoch [    1/    1] | d_loss: 0.4325 | g_loss: 7.0375
# Epoch [    1/    1] | d_loss: 0.2206 | g_loss: 3.2534
# Epoch [    1/    1] | d_loss: 0.1188 | g_loss: 4.7661
# Epoch [    1/    1] | d_loss: 0.0556 | g_loss: 4.9325
# Epoch [    1/    1] | d_loss: 0.0974 | g_loss: 6.8432
# Epoch [    1/    1] | d_loss: 0.0407 | g_loss: 8.2473
# Epoch [    1/    1] | d_loss: 0.1217 | g_loss: 5.6977
# Epoch [    1/    1] | d_loss: 0.0562 | g_loss: 3.3792
# Epoch [    1/    1] | d_loss: 0.0373 | g_loss: 3.3249
# Epoch [    1/    1] | d_loss: 0.3317 | g_loss: 6.4062
# Epoch [    1/    1] | d_loss: 0.3989 | g_loss: 5.1722
# Epoch [    1/    1] | d_loss: 0.5362 | g_loss: 4.8494
# Epoch [    1/    1] | d_loss: 0.4126 | g_loss: 4.8522
# Epoch [    1/    1] | d_loss: 0.3740 | g_loss: 1.9341
# Epoch [    1/    1] | d_loss: 0.3334 | g_loss: 4.9611
# Epoch [    1/    1] | d_loss: 1.1478 | g_loss: 2.0168
# Epoch [    1/    1] | d_loss: 2.6097 | g_loss: 1.5683
# Epoch [    1/    1] | d_loss: 0.7104 | g_loss: 5.6362
# Epoch [    1/    1] | d_loss: 0.2897 | g_loss: 3.4311
# Epoch [    1/    1] | d_loss: 0.2480 | g_loss: 3.3766
# Epoch [    1/    1] | d_loss: 0.2254 | g_loss: 3.1704
# Epoch [    1/    1] | d_loss: 0.5081 | g_loss: 3.5371
# Epoch [    1/    1] | d_loss: 0.4878 | g_loss: 3.2871
# Epoch [    1/    1] | d_loss: 2.3806 | g_loss: 2.1944
# Epoch [    1/    1] | d_loss: 0.5264 | g_loss: 2.0000
# Epoch [    1/    1] | d_loss: 0.5517 | g_loss: 1.4550
# Epoch [    1/    1] | d_loss: 0.2650 | g_loss: 4.2248
# Epoch [    1/    1] | d_loss: 0.4250 | g_loss: 2.0770
# Epoch [    1/    1] | d_loss: 0.4441 | g_loss: 2.4786
# Epoch [    1/    1] | d_loss: 0.6302 | g_loss: 4.5397
# Epoch [    1/    1] | d_loss: 0.9238 | g_loss: 2.9190
# Epoch [    1/    1] | d_loss: 0.6090 | g_loss: 0.1879
# Epoch [    1/    1] | d_loss: 0.3975 | g_loss: 3.6180
# Epoch [    1/    1] | d_loss: 0.2127 | g_loss: 2.3612
# Epoch [    1/    1] | d_loss: 0.5284 | g_loss: 2.7962
# Epoch [    1/    1] | d_loss: 0.5350 | g_loss: 3.4116
# Epoch [    1/    1] | d_loss: 0.2829 | g_loss: 4.7400
# Epoch [    1/    1] | d_loss: 1.1343 | g_loss: 6.0340
# Epoch [    1/    1] | d_loss: 0.1854 | g_loss: 3.8529
# Epoch [    1/    1] | d_loss: 0.2676 | g_loss: 2.6831
# Epoch [    1/    1] | d_loss: 0.2715 | g_loss: 1.3516
# Epoch [    1/    1] | d_loss: 1.1144 | g_loss: 0.6186
# Epoch [    1/    1] | d_loss: 0.1859 | g_loss: 3.8652
# Epoch [    1/    1] | d_loss: 0.1708 | g_loss: 3.5734
# Epoch [    1/    1] | d_loss: 0.3550 | g_loss: 2.1292
# Epoch [    1/    1] | d_loss: 0.3854 | g_loss: 3.5295
# Epoch [    1/    1] | d_loss: 0.3004 | g_loss: 1.9935
# Epoch [    1/    1] | d_loss: 0.7899 | g_loss: 1.0772
# Epoch [    1/    1] | d_loss: 0.8032 | g_loss: 5.6623
# Epoch [    1/    1] | d_loss: 0.4488 | g_loss: 4.1968
# Epoch [    1/    1] | d_loss: 1.2042 | g_loss: 4.8925
# Epoch [    1/    1] | d_loss: 0.2852 | g_loss: 1.4983
# Epoch [    1/    1] | d_loss: 0.2685 | g_loss: 2.9973
# Epoch [    1/    1] | d_loss: 0.7962 | g_loss: 2.3585
# Epoch [    1/    1] | d_loss: 0.1075 | g_loss: 2.1535
# View Samples

# %%
# tune hyperparameters by calling the training function in a loop
n_epochs=101
#for index, n_epochs in enumerate(number_epochs):
#for index, conv_dim in enumerate(conv_dim_set):
#for index, lr in enumerate(lr_set):
for index, batch_size in enumerate(batch_size_set):
    # Set Parameter
    n_epochs = n_epochs
    lr = lr
    batch_size = batch_size
    d_conv_dim = conv_dim
    g_conv_dim = conv_dim
    
    # Get dataloader
    celeba_train_loader = get_dataloader(batch_size, img_size)
    
    # Build network
    print('Build Network')
    D, G = build_network(d_conv_dim, g_conv_dim, z_size)
    
    # Reset optimizer
    d_optimizer, g_optimizer = optimizer(lr)
    
    # Calculate losses
    losses = train(D, G, n_epochs=n_epochs, index=index)
    
    # Save and Plot Data
    save_data(index, losses, batch_size)
    plot_training_loss(losses)
    #_ = view_samples(index, epoch=-1)
# Out:
# Build Network
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Epoch [    1/  101] | d_loss: 1.6967 | g_loss: 0.7526
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  101] | d_loss: 0.1458 | g_loss: 3.5950
# Epoch [    1/  101] | d_loss: 1.4516 | g_loss: 8.8800
# Epoch [    1/  101] | d_loss: 0.6478 | g_loss: 2.6812
# Epoch [    1/  101] | d_loss: 0.6001 | g_loss: 4.9813
# Epoch [    1/  101] | d_loss: 0.0760 | g_loss: 7.2700
# Epoch [    1/  101] | d_loss: 0.0711 | g_loss: 5.1529
# Epoch [    1/  101] | d_loss: 0.0660 | g_loss: 5.5430
# Epoch [    1/  101] | d_loss: 0.0789 | g_loss: 7.4283
# Epoch [    1/  101] | d_loss: 0.0092 | g_loss: 5.5323
# Epoch [    1/  101] | d_loss: 0.2328 | g_loss: 2.8562
# Epoch [    1/  101] | d_loss: 0.0244 | g_loss: 5.2370
# Epoch [    1/  101] | d_loss: 4.0548 | g_loss: 14.3084
# Epoch [    1/  101] | d_loss: 0.0399 | g_loss: 5.2851
# Epoch [    1/  101] | d_loss: 0.0739 | g_loss: 5.2749
# Epoch [    1/  101] | d_loss: 0.1542 | g_loss: 4.6284
# Epoch [    1/  101] | d_loss: 0.3678 | g_loss: 5.6279
# Epoch [    1/  101] | d_loss: 0.8881 | g_loss: 1.6087
# Epoch [    1/  101] | d_loss: 0.3393 | g_loss: 1.5376
# Epoch [    1/  101] | d_loss: 0.9083 | g_loss: 5.0318
# Epoch [    1/  101] | d_loss: 0.4372 | g_loss: 4.4761
# Epoch [    1/  101] | d_loss: 0.1791 | g_loss: 3.5693
# Epoch [    1/  101] | d_loss: 0.3560 | g_loss: 4.1605
# Epoch [    1/  101] | d_loss: 0.3107 | g_loss: 4.6477
# Epoch [    1/  101] | d_loss: 0.4655 | g_loss: 4.1662
# Epoch [    1/  101] | d_loss: 0.3066 | g_loss: 3.9903
# Epoch [    1/  101] | d_loss: 0.3493 | g_loss: 3.2508
# Epoch [    1/  101] | d_loss: 0.1418 | g_loss: 2.6091
# Epoch [    1/  101] | d_loss: 0.9828 | g_loss: 4.9990
# Epoch [    1/  101] | d_loss: 0.7917 | g_loss: 1.6971
# Epoch [    1/  101] | d_loss: 0.4911 | g_loss: 1.1368
# Epoch [    1/  101] | d_loss: 0.3949 | g_loss: 3.8217
# Epoch [    1/  101] | d_loss: 1.5249 | g_loss: 2.4231
# Epoch [    1/  101] | d_loss: 0.1968 | g_loss: 2.3478
# Epoch [    1/  101] | d_loss: 0.3194 | g_loss: 4.4860
# Epoch [    1/  101] | d_loss: 0.6161 | g_loss: 5.4164
# Epoch [    1/  101] | d_loss: 0.8267 | g_loss: 0.6098
# Epoch [    1/  101] | d_loss: 0.4339 | g_loss: 1.7674
# Epoch [    1/  101] | d_loss: 0.0848 | g_loss: 5.5270
# Epoch [    1/  101] | d_loss: 0.3727 | g_loss: 5.1888
# Epoch [    1/  101] | d_loss: 0.4890 | g_loss: 1.8229
# Epoch [    1/  101] | d_loss: 0.0461 | g_loss: 3.7708
# Epoch [    1/  101] | d_loss: 0.1840 | g_loss: 2.7867
# Epoch [    1/  101] | d_loss: 0.2513 | g_loss: 3.1742
# Epoch [    1/  101] | d_loss: 0.1513 | g_loss: 3.2750
# Epoch [    1/  101] | d_loss: 0.2161 | g_loss: 4.7373
# Epoch [    1/  101] | d_loss: 0.3711 | g_loss: 3.7036
# Epoch [    1/  101] | d_loss: 1.3792 | g_loss: 8.0203
# Epoch [    1/  101] | d_loss: 0.2360 | g_loss: 3.3472
# Epoch [    1/  101] | d_loss: 0.5586 | g_loss: 1.3871
# Epoch [    1/  101] | d_loss: 0.1868 | g_loss: 2.3560
# Epoch [    1/  101] | d_loss: 0.3987 | g_loss: 2.7174
# Epoch [    1/  101] | d_loss: 0.3919 | g_loss: 1.5572
# Epoch [    1/  101] | d_loss: 0.2809 | g_loss: 2.6278
# Epoch [    1/  101] | d_loss: 0.0918 | g_loss: 4.0977
# Epoch [    1/  101] | d_loss: 0.8576 | g_loss: 1.3884
# Epoch [    1/  101] | d_loss: 0.3097 | g_loss: 2.0401
# View Samples
# Epoch [    2/  101] | d_loss: 1.8330 | g_loss: 6.4875
# Epoch [    2/  101] | d_loss: 0.4075 | g_loss: 3.6823
# Epoch [    2/  101] | d_loss: 0.7112 | g_loss: 5.3117
# Epoch [    2/  101] | d_loss: 0.4698 | g_loss: 1.0516
# Epoch [    2/  101] | d_loss: 0.4003 | g_loss: 2.1841
# Epoch [    2/  101] | d_loss: 0.5799 | g_loss: 2.6967
# Epoch [    2/  101] | d_loss: 0.2772 | g_loss: 3.1467
# Epoch [    2/  101] | d_loss: 0.4636 | g_loss: 4.7285
# Epoch [    2/  101] | d_loss: 0.1768 | g_loss: 2.1977
# Epoch [    2/  101] | d_loss: 0.3363 | g_loss: 2.2348
# Epoch [    2/  101] | d_loss: 0.1235 | g_loss: 1.8984
# Epoch [    2/  101] | d_loss: 1.0091 | g_loss: 3.7564
# Epoch [    2/  101] | d_loss: 0.3279 | g_loss: 3.6751
# Epoch [    2/  101] | d_loss: 0.2875 | g_loss: 3.7015
# Epoch [    2/  101] | d_loss: 0.3155 | g_loss: 3.0646
# Epoch [    2/  101] | d_loss: 0.0669 | g_loss: 3.3410
# Epoch [    2/  101] | d_loss: 0.6417 | g_loss: 0.4903
# Epoch [    2/  101] | d_loss: 0.3808 | g_loss: 1.4722
# Epoch [    2/  101] | d_loss: 0.7542 | g_loss: 0.9016
# Epoch [    2/  101] | d_loss: 0.1690 | g_loss: 4.1871
# Epoch [    2/  101] | d_loss: 0.0483 | g_loss: 2.4014
# Epoch [    2/  101] | d_loss: 0.2682 | g_loss: 2.6693
# Epoch [    2/  101] | d_loss: 0.7462 | g_loss: 4.8284
# Epoch [    2/  101] | d_loss: 0.4131 | g_loss: 6.7092
# Epoch [    2/  101] | d_loss: 0.1551 | g_loss: 2.9510
# Epoch [    2/  101] | d_loss: 0.6931 | g_loss: 1.2254
# Epoch [    2/  101] | d_loss: 0.2193 | g_loss: 1.8232
# Epoch [    2/  101] | d_loss: 1.1614 | g_loss: 0.5639
# Epoch [    2/  101] | d_loss: 0.3727 | g_loss: 2.9103
# Epoch [    2/  101] | d_loss: 0.3222 | g_loss: 2.9402
# Epoch [    2/  101] | d_loss: 0.2749 | g_loss: 3.7014
# Epoch [    2/  101] | d_loss: 0.1488 | g_loss: 2.9823
# Epoch [    2/  101] | d_loss: 1.3136 | g_loss: 6.9633
# Epoch [    2/  101] | d_loss: 0.3387 | g_loss: 6.8287
# Epoch [    2/  101] | d_loss: 0.1154 | g_loss: 1.8250
# Epoch [    2/  101] | d_loss: 0.1382 | g_loss: 4.9281
# Epoch [    2/  101] | d_loss: 0.7325 | g_loss: 6.3429
# Epoch [    2/  101] | d_loss: 0.7494 | g_loss: 5.4773
# Epoch [    2/  101] | d_loss: 0.3389 | g_loss: 3.2000
# Epoch [    2/  101] | d_loss: 0.7542 | g_loss: 3.9793
# Epoch [    2/  101] | d_loss: 0.5696 | g_loss: 3.0449
# Epoch [    2/  101] | d_loss: 0.2845 | g_loss: 0.9059
# Epoch [    2/  101] | d_loss: 1.6560 | g_loss: 1.8754
# Epoch [    2/  101] | d_loss: 2.1021 | g_loss: 0.6554
# Epoch [    2/  101] | d_loss: 0.9653 | g_loss: 7.6435
# Epoch [    2/  101] | d_loss: 0.2601 | g_loss: 4.9688
# Epoch [    2/  101] | d_loss: 0.7038 | g_loss: 1.2534
# Epoch [    2/  101] | d_loss: 0.2499 | g_loss: 3.7887
# Epoch [    2/  101] | d_loss: 0.5825 | g_loss: 1.8535
# Epoch [    2/  101] | d_loss: 0.2792 | g_loss: 4.6775
# Epoch [    2/  101] | d_loss: 0.4286 | g_loss: 2.7083
# Epoch [    2/  101] | d_loss: 0.1801 | g_loss: 4.8833
# Epoch [    2/  101] | d_loss: 0.3609 | g_loss: 5.9640
# Epoch [    2/  101] | d_loss: 0.2502 | g_loss: 4.6869
# Epoch [    2/  101] | d_loss: 0.0611 | g_loss: 1.4419
# Epoch [    2/  101] | d_loss: 0.0769 | g_loss: 4.6008
# Epoch [    2/  101] | d_loss: 0.7281 | g_loss: 2.4824
# Epoch [    3/  101] | d_loss: 0.8238 | g_loss: 2.2244
# Epoch [    3/  101] | d_loss: 2.6838 | g_loss: 2.3534
# Epoch [    3/  101] | d_loss: 0.2421 | g_loss: 4.7869
# Epoch [    3/  101] | d_loss: 0.2309 | g_loss: 3.7663
# Epoch [    3/  101] | d_loss: 0.1138 | g_loss: 3.3469
# Epoch [    3/  101] | d_loss: 0.9978 | g_loss: 5.4988
# Epoch [    3/  101] | d_loss: 0.5781 | g_loss: 4.5048
# Epoch [    3/  101] | d_loss: 0.1476 | g_loss: 3.2883
# Epoch [    3/  101] | d_loss: 0.2226 | g_loss: 3.4860
# Epoch [    3/  101] | d_loss: 0.2845 | g_loss: 2.0955
# Epoch [    3/  101] | d_loss: 0.6320 | g_loss: 5.9616
# Epoch [    3/  101] | d_loss: 0.0500 | g_loss: 5.5144
# Epoch [    3/  101] | d_loss: 0.7255 | g_loss: 6.9786
# Epoch [    3/  101] | d_loss: 0.4306 | g_loss: 3.2900
# Epoch [    3/  101] | d_loss: 0.1294 | g_loss: 4.6875
# Epoch [    3/  101] | d_loss: 0.2339 | g_loss: 1.7293
# Epoch [    3/  101] | d_loss: 0.1031 | g_loss: 4.7845
# Epoch [    3/  101] | d_loss: 0.1063 | g_loss: 1.5225
# Epoch [    3/  101] | d_loss: 0.6327 | g_loss: 7.9177
# Epoch [    3/  101] | d_loss: 0.0595 | g_loss: 3.4240
# Epoch [    3/  101] | d_loss: 0.0998 | g_loss: 2.4278
# Epoch [    3/  101] | d_loss: 0.0830 | g_loss: 5.2678
# Epoch [    3/  101] | d_loss: 0.2635 | g_loss: 5.9912
# Epoch [    3/  101] | d_loss: 0.5259 | g_loss: 7.0862
# Epoch [    3/  101] | d_loss: 3.1652 | g_loss: 11.9040
# Epoch [    3/  101] | d_loss: 0.2731 | g_loss: 4.1664
# Epoch [    3/  101] | d_loss: 0.2907 | g_loss: 6.0717
# Epoch [    3/  101] | d_loss: 0.1494 | g_loss: 1.4461
# Epoch [    3/  101] | d_loss: 0.1236 | g_loss: 7.6456
# Epoch [    3/  101] | d_loss: 0.2621 | g_loss: 2.1750
# Epoch [    3/  101] | d_loss: 1.4089 | g_loss: 10.1013
# Epoch [    3/  101] | d_loss: 0.1820 | g_loss: 3.0657
# Epoch [    3/  101] | d_loss: 0.1565 | g_loss: 6.5207
# Epoch [    3/  101] | d_loss: 0.1857 | g_loss: 4.7248
# Epoch [    3/  101] | d_loss: 0.0868 | g_loss: 4.2541
# Epoch [    3/  101] | d_loss: 2.7155 | g_loss: 11.4244
# Epoch [    3/  101] | d_loss: 0.1435 | g_loss: 5.6265
# Epoch [    3/  101] | d_loss: 0.0441 | g_loss: 2.3711
# Epoch [    3/  101] | d_loss: 0.3010 | g_loss: 3.2183
# Epoch [    3/  101] | d_loss: 0.1681 | g_loss: 3.3119
# Epoch [    3/  101] | d_loss: 0.1310 | g_loss: 5.0756
# Epoch [    3/  101] | d_loss: 0.5251 | g_loss: 7.9312
# Epoch [    3/  101] | d_loss: 2.3190 | g_loss: 1.4979
# Epoch [    3/  101] | d_loss: 0.3082 | g_loss: 6.3334
# Epoch [    3/  101] | d_loss: 0.0270 | g_loss: 4.3013
# Epoch [    3/  101] | d_loss: 0.1660 | g_loss: 4.1201
# Epoch [    3/  101] | d_loss: 0.0268 | g_loss: 6.3969
# Epoch [    3/  101] | d_loss: 0.0257 | g_loss: 3.9562
# Epoch [    3/  101] | d_loss: 0.0483 | g_loss: 5.6780
# Epoch [    3/  101] | d_loss: 0.4324 | g_loss: 2.7517
# Epoch [    3/  101] | d_loss: 1.0670 | g_loss: 0.1138
# Epoch [    3/  101] | d_loss: 0.1063 | g_loss: 5.3384
# Epoch [    3/  101] | d_loss: 0.1003 | g_loss: 4.7744
# Epoch [    3/  101] | d_loss: 0.1034 | g_loss: 3.6687
# Epoch [    3/  101] | d_loss: 0.0790 | g_loss: 1.2179
# Epoch [    3/  101] | d_loss: 0.2560 | g_loss: 3.0280
# Epoch [    3/  101] | d_loss: 0.4421 | g_loss: 3.7119
# Epoch [    4/  101] | d_loss: 0.4030 | g_loss: 1.0380
# Epoch [    4/  101] | d_loss: 0.5434 | g_loss: 0.5194
# Epoch [    4/  101] | d_loss: 0.3294 | g_loss: 3.3799
# Epoch [    4/  101] | d_loss: 0.0401 | g_loss: 4.4831
# Epoch [    4/  101] | d_loss: 0.2169 | g_loss: 5.2393
# Epoch [    4/  101] | d_loss: 0.1058 | g_loss: 5.5553
# Epoch [    4/  101] | d_loss: 0.2067 | g_loss: 6.7304
# Epoch [    4/  101] | d_loss: 2.0858 | g_loss: 8.8689
# Epoch [    4/  101] | d_loss: 0.9366 | g_loss: 6.8766
# Epoch [    4/  101] | d_loss: 0.1411 | g_loss: 2.4741
# Epoch [    4/  101] | d_loss: 0.2068 | g_loss: 8.2440
# Epoch [    4/  101] | d_loss: 0.1124 | g_loss: 2.2370
# Epoch [    4/  101] | d_loss: 0.1533 | g_loss: 6.8127
# Epoch [    4/  101] | d_loss: 0.2669 | g_loss: 7.5062
# Epoch [    4/  101] | d_loss: 0.1626 | g_loss: 2.5208
# Epoch [    4/  101] | d_loss: 0.0271 | g_loss: 3.8513
# Epoch [    4/  101] | d_loss: 0.0291 | g_loss: 6.1440
# Epoch [    4/  101] | d_loss: 0.0176 | g_loss: 7.1939
# Epoch [    4/  101] | d_loss: 0.0462 | g_loss: 3.9074
# Epoch [    4/  101] | d_loss: 0.0701 | g_loss: 4.3194
# Epoch [    4/  101] | d_loss: 0.1644 | g_loss: 2.8003
# Epoch [    4/  101] | d_loss: 0.3404 | g_loss: 6.1820
# Epoch [    4/  101] | d_loss: 0.7730 | g_loss: 10.5861
# Epoch [    4/  101] | d_loss: 0.0527 | g_loss: 4.7680
# Epoch [    4/  101] | d_loss: 0.5616 | g_loss: 1.8274
# Epoch [    4/  101] | d_loss: 0.0268 | g_loss: 4.1079
# Epoch [    4/  101] | d_loss: 0.0806 | g_loss: 6.3092
# Epoch [    4/  101] | d_loss: 0.1814 | g_loss: 5.6329
# Epoch [    4/  101] | d_loss: 0.3524 | g_loss: 8.9129
# Epoch [    4/  101] | d_loss: 0.2711 | g_loss: 5.2524
# Epoch [    4/  101] | d_loss: 0.0194 | g_loss: 4.2286
# Epoch [    4/  101] | d_loss: 0.0731 | g_loss: 5.7365
# Epoch [    4/  101] | d_loss: 0.0715 | g_loss: 4.9605
# Epoch [    4/  101] | d_loss: 0.1335 | g_loss: 3.6103
# Epoch [    4/  101] | d_loss: 0.1217 | g_loss: 5.3339
# Epoch [    4/  101] | d_loss: 0.0461 | g_loss: 3.8168
# Epoch [    4/  101] | d_loss: 0.0103 | g_loss: 3.8902
# Epoch [    4/  101] | d_loss: 0.0246 | g_loss: 4.8275
# Epoch [    4/  101] | d_loss: 0.0204 | g_loss: 3.0835
# Epoch [    4/  101] | d_loss: 0.0991 | g_loss: 2.3671
# Epoch [    4/  101] | d_loss: 0.1971 | g_loss: 5.0463
# Epoch [    4/  101] | d_loss: 0.1599 | g_loss: 6.0528
# Epoch [    4/  101] | d_loss: 0.0481 | g_loss: 5.9260
# Epoch [    4/  101] | d_loss: 0.0396 | g_loss: 7.5425
# Epoch [    4/  101] | d_loss: 0.2050 | g_loss: 4.7298
# Epoch [    4/  101] | d_loss: 0.0669 | g_loss: 6.0097
# Epoch [    4/  101] | d_loss: 0.8342 | g_loss: 4.2299
# Epoch [    4/  101] | d_loss: 0.7912 | g_loss: 2.2438
# Epoch [    4/  101] | d_loss: 0.3051 | g_loss: 1.0966
# Epoch [    4/  101] | d_loss: 0.3654 | g_loss: 6.2278
# Epoch [    4/  101] | d_loss: 0.1731 | g_loss: 4.9317
# Epoch [    4/  101] | d_loss: 0.2406 | g_loss: 3.2231
# Epoch [    4/  101] | d_loss: 0.0981 | g_loss: 7.6478
# Epoch [    4/  101] | d_loss: 0.4656 | g_loss: 3.6813
# Epoch [    4/  101] | d_loss: 0.0968 | g_loss: 4.3636
# Epoch [    4/  101] | d_loss: 0.0390 | g_loss: 4.0034
# Epoch [    4/  101] | d_loss: 0.0282 | g_loss: 4.3364
# Epoch [    5/  101] | d_loss: 0.6774 | g_loss: 7.7390
# Epoch [    5/  101] | d_loss: 0.5534 | g_loss: 10.7980
# Epoch [    5/  101] | d_loss: 0.4573 | g_loss: 7.3319
# Epoch [    5/  101] | d_loss: 0.1041 | g_loss: 4.1805
# Epoch [    5/  101] | d_loss: 0.1570 | g_loss: 3.2828
# Epoch [    5/  101] | d_loss: 0.0311 | g_loss: 3.6496
# Epoch [    5/  101] | d_loss: 0.0391 | g_loss: 7.2367
# Epoch [    5/  101] | d_loss: 0.0060 | g_loss: 6.5707
# Epoch [    5/  101] | d_loss: 0.0917 | g_loss: 4.1310
# Epoch [    5/  101] | d_loss: 0.3652 | g_loss: 3.6097
# Epoch [    5/  101] | d_loss: 0.1450 | g_loss: 3.1233
# Epoch [    5/  101] | d_loss: 0.9885 | g_loss: 7.7900
# Epoch [    5/  101] | d_loss: 0.0107 | g_loss: 5.6612
# Epoch [    5/  101] | d_loss: 0.0243 | g_loss: 5.1485
# Epoch [    5/  101] | d_loss: 0.1414 | g_loss: 5.2553
# Epoch [    5/  101] | d_loss: 0.1744 | g_loss: 4.9614
# Epoch [    5/  101] | d_loss: 0.0144 | g_loss: 4.8432
# Epoch [    5/  101] | d_loss: 0.1176 | g_loss: 5.1049
# Epoch [    5/  101] | d_loss: 0.0046 | g_loss: 4.3924
# Epoch [    5/  101] | d_loss: 0.0830 | g_loss: 7.5734
# Epoch [    5/  101] | d_loss: 0.1501 | g_loss: 5.1837
# Epoch [    5/  101] | d_loss: 0.0566 | g_loss: 5.1828
# Epoch [    5/  101] | d_loss: 0.3271 | g_loss: 2.0512
# Epoch [    5/  101] | d_loss: 0.0290 | g_loss: 3.1604
# Epoch [    5/  101] | d_loss: 0.0470 | g_loss: 3.5217
# Epoch [    5/  101] | d_loss: 0.0190 | g_loss: 4.0327
# Epoch [    5/  101] | d_loss: 0.0488 | g_loss: 2.6727
# Epoch [    5/  101] | d_loss: 0.0061 | g_loss: 6.0981
# Epoch [    5/  101] | d_loss: 0.0098 | g_loss: 3.2519
# Epoch [    5/  101] | d_loss: 0.0208 | g_loss: 3.7059
# Epoch [    5/  101] | d_loss: 0.0190 | g_loss: 1.1603
# Epoch [    5/  101] | d_loss: 0.0279 | g_loss: 3.4812
# Epoch [    5/  101] | d_loss: 0.0215 | g_loss: 4.5742
# Epoch [    5/  101] | d_loss: 0.0636 | g_loss: 7.4158
# Epoch [    5/  101] | d_loss: 0.0899 | g_loss: 5.1729
# Epoch [    5/  101] | d_loss: 0.2816 | g_loss: 3.5316
# Epoch [    5/  101] | d_loss: 0.2284 | g_loss: 2.9535
# Epoch [    5/  101] | d_loss: 0.0112 | g_loss: 3.5981
# Epoch [    5/  101] | d_loss: 0.1285 | g_loss: 4.8410
# Epoch [    5/  101] | d_loss: 0.0988 | g_loss: 3.2091
# Epoch [    5/  101] | d_loss: 0.0200 | g_loss: 5.5942
# Epoch [    5/  101] | d_loss: 0.1977 | g_loss: 5.2390
# Epoch [    5/  101] | d_loss: 0.0121 | g_loss: 4.2863
# Epoch [    5/  101] | d_loss: 0.0248 | g_loss: 4.4133
# Epoch [    5/  101] | d_loss: 0.2900 | g_loss: 5.7136
# Epoch [    5/  101] | d_loss: 0.0325 | g_loss: 6.2736
# Epoch [    5/  101] | d_loss: 0.0088 | g_loss: 7.5539
# Epoch [    5/  101] | d_loss: 0.1308 | g_loss: 7.3503
# Epoch [    5/  101] | d_loss: 0.0308 | g_loss: 2.5229
# Epoch [    5/  101] | d_loss: 3.5157 | g_loss: 1.0881
# Epoch [    5/  101] | d_loss: 0.0745 | g_loss: 4.6191
# Epoch [    5/  101] | d_loss: 0.3044 | g_loss: 9.4100
# Epoch [    5/  101] | d_loss: 0.0189 | g_loss: 4.5830
# Epoch [    5/  101] | d_loss: 0.0392 | g_loss: 6.5263
# Epoch [    5/  101] | d_loss: 0.0202 | g_loss: 7.9579
# Epoch [    5/  101] | d_loss: 0.0489 | g_loss: 5.7186
# Epoch [    5/  101] | d_loss: 0.7838 | g_loss: 1.7970
# Epoch [    6/  101] | d_loss: 0.0486 | g_loss: 6.5909
# Epoch [    6/  101] | d_loss: 0.0401 | g_loss: 4.4800
# Epoch [    6/  101] | d_loss: 0.0171 | g_loss: 7.3330
# Epoch [    6/  101] | d_loss: 0.0378 | g_loss: 2.5423
# Epoch [    6/  101] | d_loss: 0.2758 | g_loss: 0.7202
# Epoch [    6/  101] | d_loss: 0.2980 | g_loss: 3.5697
# Epoch [    6/  101] | d_loss: 0.0870 | g_loss: 7.1354
# Epoch [    6/  101] | d_loss: 0.0151 | g_loss: 5.0912
# Epoch [    6/  101] | d_loss: 0.1508 | g_loss: 6.4875
# Epoch [    6/  101] | d_loss: 0.1403 | g_loss: 6.5968
# Epoch [    6/  101] | d_loss: 0.0455 | g_loss: 5.1947
# Epoch [    6/  101] | d_loss: 0.2435 | g_loss: 4.2211
# Epoch [    6/  101] | d_loss: 0.0693 | g_loss: 3.3072
# Epoch [    6/  101] | d_loss: 0.0252 | g_loss: 4.9674
# Epoch [    6/  101] | d_loss: 0.0202 | g_loss: 5.0222
# Epoch [    6/  101] | d_loss: 0.0213 | g_loss: 3.1705
# Epoch [    6/  101] | d_loss: 0.5577 | g_loss: 0.4586
# Epoch [    6/  101] | d_loss: 0.0536 | g_loss: 1.4963
# Epoch [    6/  101] | d_loss: 0.0215 | g_loss: 9.6954
# Epoch [    6/  101] | d_loss: 0.1001 | g_loss: 5.5626
# Epoch [    6/  101] | d_loss: 0.0341 | g_loss: 3.5531
# Epoch [    6/  101] | d_loss: 0.0171 | g_loss: 4.2769
# Epoch [    6/  101] | d_loss: 0.0083 | g_loss: 4.2106
# Epoch [    6/  101] | d_loss: 0.0096 | g_loss: 8.9120
# Epoch [    6/  101] | d_loss: 0.0286 | g_loss: 6.1077
# Epoch [    6/  101] | d_loss: 0.0736 | g_loss: 4.8329
# Epoch [    6/  101] | d_loss: 0.4753 | g_loss: 5.3264
# Epoch [    6/  101] | d_loss: 0.1278 | g_loss: 4.3423
# Epoch [    6/  101] | d_loss: 0.0244 | g_loss: 5.3515
# Epoch [    6/  101] | d_loss: 0.0088 | g_loss: 6.4298
# Epoch [    6/  101] | d_loss: 0.1319 | g_loss: 6.4065
# Epoch [    6/  101] | d_loss: 0.4091 | g_loss: 6.9807
# Epoch [    6/  101] | d_loss: 0.0657 | g_loss: 3.9928
# Epoch [    6/  101] | d_loss: 0.4184 | g_loss: 5.2130
# Epoch [    6/  101] | d_loss: 0.3508 | g_loss: 6.8049
# Epoch [    6/  101] | d_loss: 0.0857 | g_loss: 6.0462
# Epoch [    6/  101] | d_loss: 0.4952 | g_loss: 2.6612
# Epoch [    6/  101] | d_loss: 0.1373 | g_loss: 2.4707
# Epoch [    6/  101] | d_loss: 0.0306 | g_loss: 7.7203
# Epoch [    6/  101] | d_loss: 0.4250 | g_loss: 8.5133
# Epoch [    6/  101] | d_loss: 0.0383 | g_loss: 4.5410
# Epoch [    6/  101] | d_loss: 0.2347 | g_loss: 7.8862
# Epoch [    6/  101] | d_loss: 0.1015 | g_loss: 9.0386
# Epoch [    6/  101] | d_loss: 0.0399 | g_loss: 6.7332
# Epoch [    6/  101] | d_loss: 0.1859 | g_loss: 6.9023
# Epoch [    6/  101] | d_loss: 0.2919 | g_loss: 6.5710
# Epoch [    6/  101] | d_loss: 0.1410 | g_loss: 4.8796
# Epoch [    6/  101] | d_loss: 0.0117 | g_loss: 5.3629
# Epoch [    6/  101] | d_loss: 0.0481 | g_loss: 2.0966
# Epoch [    6/  101] | d_loss: 0.0132 | g_loss: 5.6229
# Epoch [    6/  101] | d_loss: 0.5883 | g_loss: 7.7987
# Epoch [    6/  101] | d_loss: 0.0413 | g_loss: 7.6006
# Epoch [    6/  101] | d_loss: 0.0732 | g_loss: 7.7886
# Epoch [    6/  101] | d_loss: 0.1205 | g_loss: 5.3462
# Epoch [    6/  101] | d_loss: 0.0233 | g_loss: 4.6723
# Epoch [    6/  101] | d_loss: 0.1452 | g_loss: 5.7551
# Epoch [    6/  101] | d_loss: 0.1629 | g_loss: 5.9917
# Epoch [    7/  101] | d_loss: 0.1239 | g_loss: 8.0824
# Epoch [    7/  101] | d_loss: 0.0071 | g_loss: 9.6061
# Epoch [    7/  101] | d_loss: 0.0452 | g_loss: 3.8748
# Epoch [    7/  101] | d_loss: 0.0095 | g_loss: 6.1211
# Epoch [    7/  101] | d_loss: 0.6742 | g_loss: 9.5456
# Epoch [    7/  101] | d_loss: 0.0235 | g_loss: 9.6965
# Epoch [    7/  101] | d_loss: 0.0450 | g_loss: 9.5881
# Epoch [    7/  101] | d_loss: 0.0823 | g_loss: 6.0815
# Epoch [    7/  101] | d_loss: 0.1047 | g_loss: 3.4595
# Epoch [    7/  101] | d_loss: 0.0208 | g_loss: 5.6148
# Epoch [    7/  101] | d_loss: 0.0403 | g_loss: 1.9626
# Epoch [    7/  101] | d_loss: 1.8573 | g_loss: 7.8063
# Epoch [    7/  101] | d_loss: 0.0017 | g_loss: 6.4858
# Epoch [    7/  101] | d_loss: 0.5662 | g_loss: 8.6525
# Epoch [    7/  101] | d_loss: 0.0184 | g_loss: 7.1894
# Epoch [    7/  101] | d_loss: 0.0783 | g_loss: 5.2995
# Epoch [    7/  101] | d_loss: 0.0388 | g_loss: 4.8448
# Epoch [    7/  101] | d_loss: 0.0103 | g_loss: 5.5375
# Epoch [    7/  101] | d_loss: 0.0478 | g_loss: 6.6476
# Epoch [    7/  101] | d_loss: 0.2747 | g_loss: 8.3509
# Epoch [    7/  101] | d_loss: 0.0436 | g_loss: 6.5632
# Epoch [    7/  101] | d_loss: 0.0161 | g_loss: 3.9955
# Epoch [    7/  101] | d_loss: 0.0446 | g_loss: 3.9089
# Epoch [    7/  101] | d_loss: 0.0998 | g_loss: 8.4033
# Epoch [    7/  101] | d_loss: 0.0295 | g_loss: 0.8592
# Epoch [    7/  101] | d_loss: 0.1280 | g_loss: 9.3020
# Epoch [    7/  101] | d_loss: 0.0038 | g_loss: 10.0644
# Epoch [    7/  101] | d_loss: 0.0349 | g_loss: 6.1451
# Epoch [    7/  101] | d_loss: 0.0047 | g_loss: 5.3223
# Epoch [    7/  101] | d_loss: 0.0686 | g_loss: 3.8311
# Epoch [    7/  101] | d_loss: 0.5990 | g_loss: 2.0775
# Epoch [    7/  101] | d_loss: 0.0049 | g_loss: 3.0483
# Epoch [    7/  101] | d_loss: 0.4259 | g_loss: 8.2120
# Epoch [    7/  101] | d_loss: 1.2816 | g_loss: 0.9451
# Epoch [    7/  101] | d_loss: 0.0962 | g_loss: 9.9972
# Epoch [    7/  101] | d_loss: 0.0201 | g_loss: 4.0036
# Epoch [    7/  101] | d_loss: 0.0389 | g_loss: 4.1204
# Epoch [    7/  101] | d_loss: 0.0079 | g_loss: 4.4669
# Epoch [    7/  101] | d_loss: 0.0257 | g_loss: 5.0654
# Epoch [    7/  101] | d_loss: 0.7484 | g_loss: 2.8749
# Epoch [    7/  101] | d_loss: 0.1156 | g_loss: 3.3293
# Epoch [    7/  101] | d_loss: 0.2350 | g_loss: 10.2261
# Epoch [    7/  101] | d_loss: 0.1332 | g_loss: 5.6423
# Epoch [    7/  101] | d_loss: 0.0626 | g_loss: 3.7449
# Epoch [    7/  101] | d_loss: 0.0712 | g_loss: 7.6782
# Epoch [    7/  101] | d_loss: 0.0015 | g_loss: 6.3005
# Epoch [    7/  101] | d_loss: 0.0432 | g_loss: 5.1574
# Epoch [    7/  101] | d_loss: 0.0068 | g_loss: 7.1359
# Epoch [    7/  101] | d_loss: 0.0536 | g_loss: 8.7304
# Epoch [    7/  101] | d_loss: 0.1682 | g_loss: 4.7600
# Epoch [    7/  101] | d_loss: 0.0253 | g_loss: 9.3159
# Epoch [    7/  101] | d_loss: 0.1815 | g_loss: 4.6674
# Epoch [    7/  101] | d_loss: 0.0233 | g_loss: 2.1872
# Epoch [    7/  101] | d_loss: 0.4512 | g_loss: 10.2649
# Epoch [    7/  101] | d_loss: 0.0307 | g_loss: 4.5656
# Epoch [    7/  101] | d_loss: 0.5695 | g_loss: 12.2368
# Epoch [    7/  101] | d_loss: 0.0341 | g_loss: 3.7936
# Epoch [    8/  101] | d_loss: 0.6663 | g_loss: 12.6988
# Epoch [    8/  101] | d_loss: 0.1708 | g_loss: 2.5773
# Epoch [    8/  101] | d_loss: 0.4156 | g_loss: 3.9956
# Epoch [    8/  101] | d_loss: 0.0029 | g_loss: 6.5525
# Epoch [    8/  101] | d_loss: 0.0233 | g_loss: 6.7493
# Epoch [    8/  101] | d_loss: 0.0290 | g_loss: 10.3922
# Epoch [    8/  101] | d_loss: 0.1741 | g_loss: 4.2936
# Epoch [    8/  101] | d_loss: 0.0177 | g_loss: 4.2484
# Epoch [    8/  101] | d_loss: 0.0063 | g_loss: 7.0925
# Epoch [    8/  101] | d_loss: 0.0667 | g_loss: 5.0404
# Epoch [    8/  101] | d_loss: 1.6373 | g_loss: 2.9873
# Epoch [    8/  101] | d_loss: 0.0050 | g_loss: 6.9408
# Epoch [    8/  101] | d_loss: 0.0071 | g_loss: 7.5625
# Epoch [    8/  101] | d_loss: 0.2439 | g_loss: 6.7825
# Epoch [    8/  101] | d_loss: 0.3493 | g_loss: 8.8596
# Epoch [    8/  101] | d_loss: 0.0663 | g_loss: 0.9897
# Epoch [    8/  101] | d_loss: 0.0056 | g_loss: 3.4732
# Epoch [    8/  101] | d_loss: 0.2008 | g_loss: 7.1139
# Epoch [    8/  101] | d_loss: 0.0278 | g_loss: 2.6364
# Epoch [    8/  101] | d_loss: 0.0699 | g_loss: 3.3692
# Epoch [    8/  101] | d_loss: 0.7462 | g_loss: 0.9490
# Epoch [    8/  101] | d_loss: 0.1111 | g_loss: 8.1067
# Epoch [    8/  101] | d_loss: 0.0004 | g_loss: 8.0042
# Epoch [    8/  101] | d_loss: 0.0432 | g_loss: 8.1216
# Epoch [    8/  101] | d_loss: 1.2436 | g_loss: 14.0377
# Epoch [    8/  101] | d_loss: 0.0108 | g_loss: 3.9544
# Epoch [    8/  101] | d_loss: 0.0501 | g_loss: 5.2450
# Epoch [    8/  101] | d_loss: 0.0923 | g_loss: 7.2716
# Epoch [    8/  101] | d_loss: 0.2646 | g_loss: 3.0915
# Epoch [    8/  101] | d_loss: 0.0516 | g_loss: 5.9394
# Epoch [    8/  101] | d_loss: 0.0982 | g_loss: 5.6604
# Epoch [    8/  101] | d_loss: 0.0041 | g_loss: 6.8267
# Epoch [    8/  101] | d_loss: 2.8875 | g_loss: 4.2940
# Epoch [    8/  101] | d_loss: 0.0497 | g_loss: 2.8041
# Epoch [    8/  101] | d_loss: 0.0647 | g_loss: 5.3375
# Epoch [    8/  101] | d_loss: 0.0175 | g_loss: 6.7093
# Epoch [    8/  101] | d_loss: 0.0460 | g_loss: 7.2622
# Epoch [    8/  101] | d_loss: 0.0641 | g_loss: 12.1915
# Epoch [    8/  101] | d_loss: 0.0140 | g_loss: 6.1002
# Epoch [    8/  101] | d_loss: 2.5260 | g_loss: 0.2622
# Epoch [    8/  101] | d_loss: 0.2214 | g_loss: 1.9874
# Epoch [    8/  101] | d_loss: 0.8313 | g_loss: 6.9983
# Epoch [    8/  101] | d_loss: 0.0841 | g_loss: 6.4864
# Epoch [    8/  101] | d_loss: 0.0067 | g_loss: 5.5303
# Epoch [    8/  101] | d_loss: 0.3375 | g_loss: 10.6344
# Epoch [    8/  101] | d_loss: 0.1109 | g_loss: 1.0780
# Epoch [    8/  101] | d_loss: 0.0119 | g_loss: 2.1307
# Epoch [    8/  101] | d_loss: 0.0575 | g_loss: 6.0681
# Epoch [    8/  101] | d_loss: 0.0062 | g_loss: 4.6238
# Epoch [    8/  101] | d_loss: 0.0486 | g_loss: 3.6406
# Epoch [    8/  101] | d_loss: 0.1433 | g_loss: 2.1740
# Epoch [    8/  101] | d_loss: 0.0259 | g_loss: 6.7056
# Epoch [    8/  101] | d_loss: 0.0685 | g_loss: 6.6368
# Epoch [    8/  101] | d_loss: 0.0119 | g_loss: 3.6149
# Epoch [    8/  101] | d_loss: 1.7079 | g_loss: 13.5209
# Epoch [    8/  101] | d_loss: 2.5745 | g_loss: 11.5492
# Epoch [    8/  101] | d_loss: 0.0666 | g_loss: 1.8373
# Epoch [    9/  101] | d_loss: 0.0559 | g_loss: 3.4387
# Epoch [    9/  101] | d_loss: 0.0051 | g_loss: 9.4999
# Epoch [    9/  101] | d_loss: 0.0175 | g_loss: 4.9845
# Epoch [    9/  101] | d_loss: 0.0348 | g_loss: 6.9413
# Epoch [    9/  101] | d_loss: 0.0191 | g_loss: 4.6782
# Epoch [    9/  101] | d_loss: 0.0078 | g_loss: 7.0876
# Epoch [    9/  101] | d_loss: 0.0678 | g_loss: 5.3774
# Epoch [    9/  101] | d_loss: 1.1628 | g_loss: 7.9403
# Epoch [    9/  101] | d_loss: 0.4475 | g_loss: 9.2369
# Epoch [    9/  101] | d_loss: 0.0132 | g_loss: 8.1546
# Epoch [    9/  101] | d_loss: 0.0587 | g_loss: 4.1960
# Epoch [    9/  101] | d_loss: 0.0096 | g_loss: 5.7309
# Epoch [    9/  101] | d_loss: 0.0911 | g_loss: 6.7625
# Epoch [    9/  101] | d_loss: 0.0591 | g_loss: 6.4956
# Epoch [    9/  101] | d_loss: 0.0007 | g_loss: 6.3925
# Epoch [    9/  101] | d_loss: 0.0220 | g_loss: 4.7044
# Epoch [    9/  101] | d_loss: 0.0206 | g_loss: 5.5301
# Epoch [    9/  101] | d_loss: 0.7066 | g_loss: 8.7264
# Epoch [    9/  101] | d_loss: 0.2624 | g_loss: 6.0617
# Epoch [    9/  101] | d_loss: 0.0193 | g_loss: 8.1653
# Epoch [    9/  101] | d_loss: 0.0201 | g_loss: 5.6414
# Epoch [    9/  101] | d_loss: 0.0055 | g_loss: 7.6210
# Epoch [    9/  101] | d_loss: 0.2321 | g_loss: 4.4347
# Epoch [    9/  101] | d_loss: 0.0354 | g_loss: 6.6352
# Epoch [    9/  101] | d_loss: 0.0390 | g_loss: 6.2985
# Epoch [    9/  101] | d_loss: 0.0174 | g_loss: 4.0157
# Epoch [    9/  101] | d_loss: 0.0275 | g_loss: 4.0700
# Epoch [    9/  101] | d_loss: 0.1472 | g_loss: 1.9636
# Epoch [    9/  101] | d_loss: 0.0064 | g_loss: 10.2723
# Epoch [    9/  101] | d_loss: 0.0518 | g_loss: 4.5642
# Epoch [    9/  101] | d_loss: 0.0099 | g_loss: 5.7211
# Epoch [    9/  101] | d_loss: 0.1082 | g_loss: 7.5587
# Epoch [    9/  101] | d_loss: 0.0025 | g_loss: 8.2487
# Epoch [    9/  101] | d_loss: 0.1732 | g_loss: 4.1350
# Epoch [    9/  101] | d_loss: 0.0291 | g_loss: 6.8570
# Epoch [    9/  101] | d_loss: 0.1432 | g_loss: 7.1678
# Epoch [    9/  101] | d_loss: 0.1421 | g_loss: 8.5126
# Epoch [    9/  101] | d_loss: 0.0520 | g_loss: 5.2408
# Epoch [    9/  101] | d_loss: 0.0152 | g_loss: 5.9151
# Epoch [    9/  101] | d_loss: 0.0018 | g_loss: 3.2142
# Epoch [    9/  101] | d_loss: 2.3741 | g_loss: 12.9772
# Epoch [    9/  101] | d_loss: 0.3645 | g_loss: 2.7785
# Epoch [    9/  101] | d_loss: 0.0558 | g_loss: 7.1441
# Epoch [    9/  101] | d_loss: 0.0057 | g_loss: 3.8477
# Epoch [    9/  101] | d_loss: 0.0010 | g_loss: 3.3223
# Epoch [    9/  101] | d_loss: 0.0148 | g_loss: 10.9369
# Epoch [    9/  101] | d_loss: 3.8544 | g_loss: 6.9969
# Epoch [    9/  101] | d_loss: 0.0459 | g_loss: 4.9685
# Epoch [    9/  101] | d_loss: 0.0762 | g_loss: 6.8542
# Epoch [    9/  101] | d_loss: 0.0130 | g_loss: 7.2743
# Epoch [    9/  101] | d_loss: 3.7389 | g_loss: 0.9468
# Epoch [    9/  101] | d_loss: 0.0110 | g_loss: 5.8139
# Epoch [    9/  101] | d_loss: 0.0074 | g_loss: 4.1440
# Epoch [    9/  101] | d_loss: 0.0029 | g_loss: 9.7806
# Epoch [    9/  101] | d_loss: 0.0848 | g_loss: 2.3169
# Epoch [    9/  101] | d_loss: 0.0402 | g_loss: 5.4938
# Epoch [    9/  101] | d_loss: 0.0039 | g_loss: 10.5238
# Epoch [   10/  101] | d_loss: 0.1055 | g_loss: 4.5064
# Epoch [   10/  101] | d_loss: 0.0274 | g_loss: 9.2589
# Epoch [   10/  101] | d_loss: 0.0017 | g_loss: 8.4249
# Epoch [   10/  101] | d_loss: 0.2306 | g_loss: 5.0738
# Epoch [   10/  101] | d_loss: 0.0016 | g_loss: 4.3419
# Epoch [   10/  101] | d_loss: 1.6432 | g_loss: 0.1143
# Epoch [   10/  101] | d_loss: 0.0060 | g_loss: 4.9000
# Epoch [   10/  101] | d_loss: 0.0677 | g_loss: 6.5193
# Epoch [   10/  101] | d_loss: 0.0071 | g_loss: 3.6588
# Epoch [   10/  101] | d_loss: 0.0014 | g_loss: 3.6053
# Epoch [   10/  101] | d_loss: 0.0147 | g_loss: 4.3476
# Epoch [   10/  101] | d_loss: 0.0408 | g_loss: 5.5202
# Epoch [   10/  101] | d_loss: 1.7401 | g_loss: 11.8988
# Epoch [   10/  101] | d_loss: 0.3705 | g_loss: 3.0992
# Epoch [   10/  101] | d_loss: 0.4026 | g_loss: 9.3954
# Epoch [   10/  101] | d_loss: 0.0125 | g_loss: 6.9280
# Epoch [   10/  101] | d_loss: 0.7460 | g_loss: 1.0559
# Epoch [   10/  101] | d_loss: 0.0117 | g_loss: 0.6720
# Epoch [   10/  101] | d_loss: 0.1018 | g_loss: 6.0289
# Epoch [   10/  101] | d_loss: 0.0031 | g_loss: 7.5695
# Epoch [   10/  101] | d_loss: 0.0111 | g_loss: 6.1819
# Epoch [   10/  101] | d_loss: 0.0575 | g_loss: 6.9375
# Epoch [   10/  101] | d_loss: 0.0719 | g_loss: 2.2678
# Epoch [   10/  101] | d_loss: 0.0080 | g_loss: 7.5743
# Epoch [   10/  101] | d_loss: 0.0064 | g_loss: 3.1886
# Epoch [   10/  101] | d_loss: 0.0051 | g_loss: 5.9878
# Epoch [   10/  101] | d_loss: 0.0212 | g_loss: 7.3554
# Epoch [   10/  101] | d_loss: 0.0068 | g_loss: 7.9825
# Epoch [   10/  101] | d_loss: 0.0318 | g_loss: 7.1323
# Epoch [   10/  101] | d_loss: 0.0203 | g_loss: 6.5465
# Epoch [   10/  101] | d_loss: 0.0216 | g_loss: 7.9343
# Epoch [   10/  101] | d_loss: 0.0063 | g_loss: 10.2468
# Epoch [   10/  101] | d_loss: 0.0137 | g_loss: 8.5283
# Epoch [   10/  101] | d_loss: 0.0090 | g_loss: 6.0934
# Epoch [   10/  101] | d_loss: 0.0661 | g_loss: 7.2968
# Epoch [   10/  101] | d_loss: 0.0383 | g_loss: 6.9450
# Epoch [   10/  101] | d_loss: 0.0717 | g_loss: 5.1072
# Epoch [   10/  101] | d_loss: 0.0071 | g_loss: 3.7750
# Epoch [   10/  101] | d_loss: 0.1142 | g_loss: 6.5996
# Epoch [   10/  101] | d_loss: 0.0499 | g_loss: 5.6687
# Epoch [   10/  101] | d_loss: 0.0070 | g_loss: 9.5966
# Epoch [   10/  101] | d_loss: 0.0336 | g_loss: 9.9448
# Epoch [   10/  101] | d_loss: 0.0065 | g_loss: 7.0886
# Epoch [   10/  101] | d_loss: 0.0095 | g_loss: 6.8698
# Epoch [   10/  101] | d_loss: 0.0505 | g_loss: 6.0738
# Epoch [   10/  101] | d_loss: 0.0758 | g_loss: 3.3413
# Epoch [   10/  101] | d_loss: 0.1026 | g_loss: 6.8609
# Epoch [   10/  101] | d_loss: 0.0117 | g_loss: 5.2196
# Epoch [   10/  101] | d_loss: 0.0246 | g_loss: 9.4044
# Epoch [   10/  101] | d_loss: 0.0150 | g_loss: 4.8463
# Epoch [   10/  101] | d_loss: 0.0005 | g_loss: 6.6055
# Epoch [   10/  101] | d_loss: 0.0116 | g_loss: 1.9897
# Epoch [   10/  101] | d_loss: 0.0369 | g_loss: 7.2974
# Epoch [   10/  101] | d_loss: 0.0363 | g_loss: 8.0731
# Epoch [   10/  101] | d_loss: 0.0070 | g_loss: 4.7778
# Epoch [   10/  101] | d_loss: 0.0022 | g_loss: 7.1919
# Epoch [   10/  101] | d_loss: 0.0018 | g_loss: 6.1908
# Epoch [   11/  101] | d_loss: 0.2467 | g_loss: 3.3109
# Epoch [   11/  101] | d_loss: 0.0353 | g_loss: 10.1508
# Epoch [   11/  101] | d_loss: 0.0005 | g_loss: 6.9502
# Epoch [   11/  101] | d_loss: 0.0362 | g_loss: 0.9011
# Epoch [   11/  101] | d_loss: 0.0295 | g_loss: 6.7936
# Epoch [   11/  101] | d_loss: 0.0111 | g_loss: 6.2111
# Epoch [   11/  101] | d_loss: 0.0059 | g_loss: 4.7505
# Epoch [   11/  101] | d_loss: 0.1830 | g_loss: 3.9498
# Epoch [   11/  101] | d_loss: 0.0053 | g_loss: 7.9286
# Epoch [   11/  101] | d_loss: 0.0082 | g_loss: 9.4170
# Epoch [   11/  101] | d_loss: 0.0068 | g_loss: 5.9117
# Epoch [   11/  101] | d_loss: 1.6085 | g_loss: 1.2485
# Epoch [   11/  101] | d_loss: 0.0324 | g_loss: 9.0350
# Epoch [   11/  101] | d_loss: 0.0644 | g_loss: 5.9459
# Epoch [   11/  101] | d_loss: 0.0023 | g_loss: 3.4334
# Epoch [   11/  101] | d_loss: 0.0089 | g_loss: 7.9302
# Epoch [   11/  101] | d_loss: 0.1270 | g_loss: 4.5924
# Epoch [   11/  101] | d_loss: 0.0017 | g_loss: 9.5495
# Epoch [   11/  101] | d_loss: 0.2003 | g_loss: 9.1733
# Epoch [   11/  101] | d_loss: 0.0119 | g_loss: 4.8808
# Epoch [   11/  101] | d_loss: 0.0213 | g_loss: 5.1523
# Epoch [   11/  101] | d_loss: 0.0063 | g_loss: 7.3694
# Epoch [   11/  101] | d_loss: 0.0007 | g_loss: 7.4575
# Epoch [   11/  101] | d_loss: 0.0232 | g_loss: 5.5795
# Epoch [   11/  101] | d_loss: 0.0187 | g_loss: 2.7945
# Epoch [   11/  101] | d_loss: 0.1642 | g_loss: 7.0933
# Epoch [   11/  101] | d_loss: 0.0039 | g_loss: 7.8756
# Epoch [   11/  101] | d_loss: 0.0020 | g_loss: 7.4040
# Epoch [   11/  101] | d_loss: 0.0111 | g_loss: 6.8129
# Epoch [   11/  101] | d_loss: 0.0091 | g_loss: 9.3196
# Epoch [   11/  101] | d_loss: 0.0173 | g_loss: 8.5040
# Epoch [   11/  101] | d_loss: 0.0074 | g_loss: 9.9291
# Epoch [   11/  101] | d_loss: 1.2743 | g_loss: 6.0198
# Epoch [   11/  101] | d_loss: 0.0162 | g_loss: 5.1991
# Epoch [   11/  101] | d_loss: 0.0432 | g_loss: 8.1100
# Epoch [   11/  101] | d_loss: 0.0087 | g_loss: 6.0882
# Epoch [   11/  101] | d_loss: 0.0014 | g_loss: 6.9251
# Epoch [   11/  101] | d_loss: 0.0390 | g_loss: 9.1365
# Epoch [   11/  101] | d_loss: 0.0290 | g_loss: 10.0735
# Epoch [   11/  101] | d_loss: 0.0409 | g_loss: 7.1346
# Epoch [   11/  101] | d_loss: 0.0174 | g_loss: 6.9922
# Epoch [   11/  101] | d_loss: 0.0129 | g_loss: 2.2504
# Epoch [   11/  101] | d_loss: 0.0408 | g_loss: 4.4765
# Epoch [   11/  101] | d_loss: 0.0370 | g_loss: 8.4199
# Epoch [   11/  101] | d_loss: 0.0015 | g_loss: 7.8764
# Epoch [   11/  101] | d_loss: 0.0069 | g_loss: 5.0741
# Epoch [   11/  101] | d_loss: 0.0169 | g_loss: 6.2497
# Epoch [   11/  101] | d_loss: 0.0037 | g_loss: 10.0283
# Epoch [   11/  101] | d_loss: 0.0559 | g_loss: 5.1273
# Epoch [   11/  101] | d_loss: 0.0031 | g_loss: 10.1191
# Epoch [   11/  101] | d_loss: 0.1119 | g_loss: 9.2935
# Epoch [   11/  101] | d_loss: 0.3568 | g_loss: 9.5102
# Epoch [   11/  101] | d_loss: 0.0131 | g_loss: 6.6694
# Epoch [   11/  101] | d_loss: 0.1111 | g_loss: 7.2328
# Epoch [   11/  101] | d_loss: 0.4288 | g_loss: 8.2866
# Epoch [   11/  101] | d_loss: 0.0178 | g_loss: 1.6021
# Epoch [   11/  101] | d_loss: 0.0010 | g_loss: 7.6465
# View Samples
# Epoch [   12/  101] | d_loss: 0.0538 | g_loss: 4.6501
# Epoch [   12/  101] | d_loss: 0.2698 | g_loss: 12.7570
# Epoch [   12/  101] | d_loss: 0.1991 | g_loss: 3.7349
# Epoch [   12/  101] | d_loss: 0.0112 | g_loss: 2.8820
# Epoch [   12/  101] | d_loss: 0.0056 | g_loss: 4.2772
# Epoch [   12/  101] | d_loss: 0.0349 | g_loss: 7.0123
# Epoch [   12/  101] | d_loss: 0.0073 | g_loss: 5.8248
# Epoch [   12/  101] | d_loss: 0.0411 | g_loss: 6.8321
# Epoch [   12/  101] | d_loss: 0.0108 | g_loss: 8.5357
# Epoch [   12/  101] | d_loss: 0.0064 | g_loss: 5.4632
# Epoch [   12/  101] | d_loss: 0.0119 | g_loss: 9.8690
# Epoch [   12/  101] | d_loss: 0.1588 | g_loss: 6.0773
# Epoch [   12/  101] | d_loss: 0.0019 | g_loss: 7.2035
# Epoch [   12/  101] | d_loss: 0.0007 | g_loss: 3.9391
# Epoch [   12/  101] | d_loss: 0.0186 | g_loss: 5.6642
# Epoch [   12/  101] | d_loss: 0.0135 | g_loss: 5.3393
# Epoch [   12/  101] | d_loss: 0.1923 | g_loss: 5.2697
# Epoch [   12/  101] | d_loss: 0.0034 | g_loss: 6.2865
# Epoch [   12/  101] | d_loss: 0.0051 | g_loss: 3.6405
# Epoch [   12/  101] | d_loss: 0.1218 | g_loss: 15.6428
# Epoch [   12/  101] | d_loss: 0.0170 | g_loss: 6.8905
# Epoch [   12/  101] | d_loss: 0.0053 | g_loss: 7.0880
# Epoch [   12/  101] | d_loss: 0.0031 | g_loss: 9.6134
# Epoch [   12/  101] | d_loss: 0.0264 | g_loss: 6.6236
# Epoch [   12/  101] | d_loss: 0.1936 | g_loss: 4.4231
# Epoch [   12/  101] | d_loss: 0.0080 | g_loss: 4.0401
# Epoch [   12/  101] | d_loss: 0.0111 | g_loss: 5.6287
# Epoch [   12/  101] | d_loss: 0.0134 | g_loss: 4.9603
# Epoch [   12/  101] | d_loss: 0.0037 | g_loss: 8.9383
# Epoch [   12/  101] | d_loss: 0.0486 | g_loss: 10.6620
# Epoch [   12/  101] | d_loss: 0.1428 | g_loss: 6.0480
# Epoch [   12/  101] | d_loss: 3.5072 | g_loss: 20.9794
# Epoch [   12/  101] | d_loss: 0.0186 | g_loss: 6.4251
# Epoch [   12/  101] | d_loss: 1.6035 | g_loss: 1.0745
# Epoch [   12/  101] | d_loss: 0.1043 | g_loss: 6.3237
# Epoch [   12/  101] | d_loss: 0.1071 | g_loss: 2.6485
# Epoch [   12/  101] | d_loss: 0.0044 | g_loss: 11.6228
# Epoch [   12/  101] | d_loss: 0.0067 | g_loss: 6.2863
# Epoch [   12/  101] | d_loss: 0.0126 | g_loss: 7.2429
# Epoch [   12/  101] | d_loss: 0.0066 | g_loss: 4.3111
# Epoch [   12/  101] | d_loss: 0.1364 | g_loss: 4.6416
# Epoch [   12/  101] | d_loss: 0.0078 | g_loss: 12.5384
# Epoch [   12/  101] | d_loss: 0.0039 | g_loss: 9.3699
# Epoch [   12/  101] | d_loss: 0.1103 | g_loss: 8.9941
# Epoch [   12/  101] | d_loss: 0.0004 | g_loss: 9.4511
# Epoch [   12/  101] | d_loss: 0.0023 | g_loss: 9.7713
# Epoch [   12/  101] | d_loss: 0.0005 | g_loss: 10.5175
# Epoch [   12/  101] | d_loss: 0.0214 | g_loss: 8.8830
# Epoch [   12/  101] | d_loss: 0.0225 | g_loss: 6.5668
# Epoch [   12/  101] | d_loss: 0.0213 | g_loss: 10.8570
# Epoch [   12/  101] | d_loss: 0.1239 | g_loss: 4.0842
# Epoch [   12/  101] | d_loss: 0.0184 | g_loss: 3.3768
# Epoch [   12/  101] | d_loss: 0.0051 | g_loss: 5.1966
# Epoch [   12/  101] | d_loss: 0.0264 | g_loss: 6.7831
# Epoch [   12/  101] | d_loss: 0.0132 | g_loss: 2.9398
# Epoch [   12/  101] | d_loss: 0.0482 | g_loss: 8.6410
# Epoch [   12/  101] | d_loss: 0.0377 | g_loss: 9.1441
# Epoch [   13/  101] | d_loss: 0.0168 | g_loss: 6.9456
# Epoch [   13/  101] | d_loss: 0.0094 | g_loss: 6.0763
# Epoch [   13/  101] | d_loss: 0.0073 | g_loss: 4.5259
# Epoch [   13/  101] | d_loss: 0.0108 | g_loss: 6.8392
# Epoch [   13/  101] | d_loss: 1.1415 | g_loss: 7.9553
# Epoch [   13/  101] | d_loss: 0.0722 | g_loss: 7.9455
# Epoch [   13/  101] | d_loss: 0.0102 | g_loss: 9.0791
# Epoch [   13/  101] | d_loss: 0.9601 | g_loss: 0.1453
# Epoch [   13/  101] | d_loss: 0.0049 | g_loss: 9.5333
# Epoch [   13/  101] | d_loss: 0.2391 | g_loss: 4.3495
# Epoch [   13/  101] | d_loss: 0.4323 | g_loss: 9.9281
# Epoch [   13/  101] | d_loss: 0.1209 | g_loss: 9.6127
# Epoch [   13/  101] | d_loss: 0.0122 | g_loss: 8.0402
# Epoch [   13/  101] | d_loss: 0.0009 | g_loss: 4.8868
# Epoch [   13/  101] | d_loss: 0.0903 | g_loss: 7.8098
# Epoch [   13/  101] | d_loss: 0.0113 | g_loss: 8.7950
# Epoch [   13/  101] | d_loss: 0.0073 | g_loss: 3.2900
# Epoch [   13/  101] | d_loss: 0.0042 | g_loss: 12.1707
# Epoch [   13/  101] | d_loss: 0.0010 | g_loss: 7.0271
# Epoch [   13/  101] | d_loss: 0.0023 | g_loss: 2.9394
# Epoch [   13/  101] | d_loss: 0.0032 | g_loss: 10.2097
# Epoch [   13/  101] | d_loss: 0.0182 | g_loss: 7.7003
# Epoch [   13/  101] | d_loss: 0.2310 | g_loss: 1.8599
# Epoch [   13/  101] | d_loss: 0.0758 | g_loss: 6.7180
# Epoch [   13/  101] | d_loss: 0.0038 | g_loss: 7.0342
# Epoch [   13/  101] | d_loss: 0.0239 | g_loss: 4.7237
# Epoch [   13/  101] | d_loss: 0.0759 | g_loss: 4.3735
# Epoch [   13/  101] | d_loss: 0.2355 | g_loss: 8.9086
# Epoch [   13/  101] | d_loss: 0.0899 | g_loss: 7.9555
# Epoch [   13/  101] | d_loss: 0.0103 | g_loss: 5.7782
# Epoch [   13/  101] | d_loss: 0.0065 | g_loss: 4.0219
# Epoch [   13/  101] | d_loss: 0.0088 | g_loss: 6.6208
# Epoch [   13/  101] | d_loss: 0.0015 | g_loss: 6.9565
# Epoch [   13/  101] | d_loss: 0.1245 | g_loss: 8.2602
# Epoch [   13/  101] | d_loss: 0.0012 | g_loss: 6.7558
# Epoch [   13/  101] | d_loss: 0.0109 | g_loss: 7.7172
# Epoch [   13/  101] | d_loss: 0.1461 | g_loss: 5.2121
# Epoch [   13/  101] | d_loss: 0.0034 | g_loss: 6.9090
# Epoch [   13/  101] | d_loss: 0.1011 | g_loss: 8.8408
# Epoch [   13/  101] | d_loss: 0.0063 | g_loss: 5.6143
# Epoch [   13/  101] | d_loss: 0.0065 | g_loss: 2.7620
# Epoch [   13/  101] | d_loss: 0.0749 | g_loss: 4.4477
# Epoch [   13/  101] | d_loss: 1.6427 | g_loss: 5.6295
# Epoch [   13/  101] | d_loss: 0.0860 | g_loss: 6.9667
# Epoch [   13/  101] | d_loss: 0.0024 | g_loss: 11.0057
# Epoch [   13/  101] | d_loss: 0.0199 | g_loss: 5.5292
# Epoch [   13/  101] | d_loss: 0.0027 | g_loss: 5.1164
# Epoch [   13/  101] | d_loss: 0.0037 | g_loss: 8.9880
# Epoch [   13/  101] | d_loss: 0.0010 | g_loss: 7.3472
# Epoch [   13/  101] | d_loss: 0.0008 | g_loss: 7.3588
# Epoch [   13/  101] | d_loss: 0.1759 | g_loss: 8.2608
# Epoch [   13/  101] | d_loss: 0.0221 | g_loss: 4.1515
# Epoch [   13/  101] | d_loss: 0.0027 | g_loss: 6.8669
# Epoch [   13/  101] | d_loss: 0.0022 | g_loss: 9.3810
# Epoch [   13/  101] | d_loss: 0.0338 | g_loss: 8.2624
# Epoch [   13/  101] | d_loss: 0.0221 | g_loss: 10.5771
# Epoch [   13/  101] | d_loss: 0.2661 | g_loss: 6.8692
# Epoch [   14/  101] | d_loss: 0.0102 | g_loss: 15.1488
# Epoch [   14/  101] | d_loss: 0.0065 | g_loss: 9.6154
# Epoch [   14/  101] | d_loss: 0.0366 | g_loss: 4.2572
# Epoch [   14/  101] | d_loss: 0.0033 | g_loss: 9.7818
# Epoch [   14/  101] | d_loss: 0.0050 | g_loss: 7.8598
# Epoch [   14/  101] | d_loss: 0.0138 | g_loss: 8.9545
# Epoch [   14/  101] | d_loss: 0.0393 | g_loss: 8.1000
# Epoch [   14/  101] | d_loss: 0.0206 | g_loss: 8.2662
# Epoch [   14/  101] | d_loss: 0.0005 | g_loss: 7.0841
# Epoch [   14/  101] | d_loss: 0.0041 | g_loss: 4.7275
# Epoch [   14/  101] | d_loss: 0.0234 | g_loss: 5.9052
# Epoch [   14/  101] | d_loss: 0.0506 | g_loss: 8.7272
# Epoch [   14/  101] | d_loss: 0.0189 | g_loss: 3.4630
# Epoch [   14/  101] | d_loss: 0.0300 | g_loss: 5.5025
# Epoch [   14/  101] | d_loss: 0.0142 | g_loss: 5.9927
# Epoch [   14/  101] | d_loss: 0.0022 | g_loss: 4.2860
# Epoch [   14/  101] | d_loss: 0.0009 | g_loss: 3.3699
# Epoch [   14/  101] | d_loss: 0.0790 | g_loss: 5.9462
# Epoch [   14/  101] | d_loss: 0.0536 | g_loss: 7.2719
# Epoch [   14/  101] | d_loss: 0.1181 | g_loss: 10.5925
# Epoch [   14/  101] | d_loss: 0.0349 | g_loss: 5.2048
# Epoch [   14/  101] | d_loss: 0.0399 | g_loss: 8.5876
# Epoch [   14/  101] | d_loss: 0.0029 | g_loss: 4.8752
# Epoch [   14/  101] | d_loss: 0.0007 | g_loss: 9.9194
# Epoch [   14/  101] | d_loss: 0.0002 | g_loss: 11.9988
# Epoch [   14/  101] | d_loss: 0.0012 | g_loss: 4.7701
# Epoch [   14/  101] | d_loss: 1.1698 | g_loss: 1.1623
# Epoch [   14/  101] | d_loss: 0.0965 | g_loss: 10.2463
# Epoch [   14/  101] | d_loss: 0.0016 | g_loss: 6.2711
# Epoch [   14/  101] | d_loss: 0.2033 | g_loss: 10.3965
# Epoch [   14/  101] | d_loss: 0.0010 | g_loss: 7.8753
# Epoch [   14/  101] | d_loss: 0.0146 | g_loss: 8.5807
# Epoch [   14/  101] | d_loss: 0.1622 | g_loss: 6.5177
# Epoch [   14/  101] | d_loss: 3.6282 | g_loss: 16.4383
# Epoch [   14/  101] | d_loss: 0.0222 | g_loss: 4.5382
# Epoch [   14/  101] | d_loss: 0.0141 | g_loss: 5.4900
# Epoch [   14/  101] | d_loss: 0.0087 | g_loss: 9.3354
# Epoch [   14/  101] | d_loss: 0.0024 | g_loss: 11.0016
# Epoch [   14/  101] | d_loss: 0.0229 | g_loss: 8.1310
# Epoch [   14/  101] | d_loss: 0.0042 | g_loss: 6.1318
# Epoch [   14/  101] | d_loss: 0.0031 | g_loss: 9.1096
# Epoch [   14/  101] | d_loss: 0.1016 | g_loss: 5.9890
# Epoch [   14/  101] | d_loss: 0.0285 | g_loss: 8.5056
# Epoch [   14/  101] | d_loss: 0.0242 | g_loss: 7.0923
# Epoch [   14/  101] | d_loss: 0.0097 | g_loss: 7.8234
# Epoch [   14/  101] | d_loss: 0.0064 | g_loss: 6.1037
# Epoch [   14/  101] | d_loss: 0.0270 | g_loss: 7.4893
# Epoch [   14/  101] | d_loss: 0.0006 | g_loss: 9.5586
# Epoch [   14/  101] | d_loss: 0.0004 | g_loss: 10.7488
# Epoch [   14/  101] | d_loss: 0.0310 | g_loss: 4.6241
# Epoch [   14/  101] | d_loss: 0.0086 | g_loss: 5.0891
# Epoch [   14/  101] | d_loss: 0.0002 | g_loss: 8.6371
# Epoch [   14/  101] | d_loss: 0.0006 | g_loss: 6.5256
# Epoch [   14/  101] | d_loss: 0.0122 | g_loss: 11.1762
# Epoch [   14/  101] | d_loss: 0.0010 | g_loss: 5.0096
# Epoch [   14/  101] | d_loss: 0.0596 | g_loss: 6.7481
# Epoch [   14/  101] | d_loss: 0.2162 | g_loss: 7.2314
# Epoch [   15/  101] | d_loss: 5.2400 | g_loss: 19.5907
# Epoch [   15/  101] | d_loss: 0.0067 | g_loss: 6.6748
# Epoch [   15/  101] | d_loss: 0.4775 | g_loss: 10.2929
# Epoch [   15/  101] | d_loss: 0.0801 | g_loss: 5.1893
# Epoch [   15/  101] | d_loss: 0.0579 | g_loss: 9.0728
# Epoch [   15/  101] | d_loss: 0.1201 | g_loss: 10.9962
# Epoch [   15/  101] | d_loss: 0.1423 | g_loss: 5.7913
# Epoch [   15/  101] | d_loss: 0.0024 | g_loss: 7.5955
# Epoch [   15/  101] | d_loss: 0.0040 | g_loss: 7.8471
# Epoch [   15/  101] | d_loss: 0.1522 | g_loss: 6.7864
# Epoch [   15/  101] | d_loss: 0.0019 | g_loss: 5.8680
# Epoch [   15/  101] | d_loss: 0.0106 | g_loss: 7.5262
# Epoch [   15/  101] | d_loss: 0.0032 | g_loss: 4.1522
# Epoch [   15/  101] | d_loss: 0.0034 | g_loss: 5.7021
# Epoch [   15/  101] | d_loss: 0.0174 | g_loss: 1.5095
# Epoch [   15/  101] | d_loss: 0.3726 | g_loss: 4.5864
# Epoch [   15/  101] | d_loss: 0.0004 | g_loss: 9.7671
# Epoch [   15/  101] | d_loss: 0.0206 | g_loss: 10.3992
# Epoch [   15/  101] | d_loss: 0.0047 | g_loss: 7.6507
# Epoch [   15/  101] | d_loss: 0.0312 | g_loss: 1.7093
# Epoch [   15/  101] | d_loss: 0.0216 | g_loss: 6.5574
# Epoch [   15/  101] | d_loss: 0.0832 | g_loss: 8.7991
# Epoch [   15/  101] | d_loss: 0.0003 | g_loss: 7.6629
# Epoch [   15/  101] | d_loss: 0.0511 | g_loss: 4.1179
# Epoch [   15/  101] | d_loss: 0.0048 | g_loss: 9.3373
# Epoch [   15/  101] | d_loss: 0.0075 | g_loss: 8.2213
# Epoch [   15/  101] | d_loss: 0.0088 | g_loss: 8.0069
# Epoch [   15/  101] | d_loss: 0.0239 | g_loss: 8.2222
# Epoch [   15/  101] | d_loss: 0.0028 | g_loss: 7.2465
# Epoch [   15/  101] | d_loss: 0.0043 | g_loss: 5.5245
# Epoch [   15/  101] | d_loss: 0.0183 | g_loss: 7.5732
# Epoch [   15/  101] | d_loss: 0.0117 | g_loss: 9.9687
# Epoch [   15/  101] | d_loss: 0.0533 | g_loss: 10.1414
# Epoch [   15/  101] | d_loss: 0.0189 | g_loss: 6.7217
# Epoch [   15/  101] | d_loss: 0.0058 | g_loss: 7.5254
# Epoch [   15/  101] | d_loss: 0.0016 | g_loss: 7.4403
# Epoch [   15/  101] | d_loss: 0.0009 | g_loss: 7.5763
# Epoch [   15/  101] | d_loss: 0.2984 | g_loss: 4.5900
# Epoch [   15/  101] | d_loss: 0.4626 | g_loss: 2.1021
# Epoch [   15/  101] | d_loss: 0.0003 | g_loss: 9.5939
# Epoch [   15/  101] | d_loss: 0.0005 | g_loss: 8.0552
# Epoch [   15/  101] | d_loss: 1.5735 | g_loss: 0.0365
# Epoch [   15/  101] | d_loss: 0.0008 | g_loss: 8.3194
# Epoch [   15/  101] | d_loss: 0.0027 | g_loss: 3.0722
# Epoch [   15/  101] | d_loss: 0.0191 | g_loss: 7.1365
# Epoch [   15/  101] | d_loss: 0.0888 | g_loss: 5.5359
# Epoch [   15/  101] | d_loss: 0.7062 | g_loss: 13.6691
# Epoch [   15/  101] | d_loss: 0.0010 | g_loss: 6.6396
# Epoch [   15/  101] | d_loss: 0.0022 | g_loss: 9.1676
# Epoch [   15/  101] | d_loss: 0.0010 | g_loss: 7.2085
# Epoch [   15/  101] | d_loss: 0.0013 | g_loss: 2.3485
# Epoch [   15/  101] | d_loss: 0.0047 | g_loss: 5.4982
# ...
# Epoch [   96/  101] | d_loss: 0.0000 | g_loss: 11.6676
# Epoch [   96/  101] | d_loss: 0.0000 | g_loss: 10.6469
# Epoch [   97/  101] | d_loss: 0.0070 | g_loss: 10.6006
# Epoch [   97/  101] | d_loss: 0.0032 | g_loss: 9.2742
# Epoch [   97/  101] | d_loss: 0.0012 | g_loss: 10.7612
# Epoch [   97/  101] | d_loss: 0.0001 | g_loss: 12.1593
# Epoch [   97/  101] | d_loss: 0.0003 | g_loss: 11.1311
# Epoch [   97/  101] | d_loss: 0.0048 | g_loss: 15.6570
# Epoch [   97/  101] | d_loss: 0.0009 | g_loss: 8.6541
# Epoch [   97/  101] | d_loss: 0.0619 | g_loss: 7.1750
# Epoch [   97/  101] | d_loss: 0.0007 | g_loss: 13.8265
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 17.9984
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 11.0041
# Epoch [   97/  101] | d_loss: 0.0003 | g_loss: 12.7563
# Epoch [   97/  101] | d_loss: 0.0023 | g_loss: 10.2297
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 11.1152
# Epoch [   97/  101] | d_loss: 0.0009 | g_loss: 13.9609
# Epoch [   97/  101] | d_loss: 0.0016 | g_loss: 3.7912
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 15.8031
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 11.3592
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 17.9103
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 13.0631
# Epoch [   97/  101] | d_loss: 0.0002 | g_loss: 13.3262
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 15.2210
# Epoch [   97/  101] | d_loss: 0.0121 | g_loss: 12.9251
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 17.3009
# Epoch [   97/  101] | d_loss: 0.0004 | g_loss: 14.9135
# Epoch [   97/  101] | d_loss: 0.0082 | g_loss: 8.7175
# Epoch [   97/  101] | d_loss: 0.0003 | g_loss: 11.3224
# Epoch [   97/  101] | d_loss: 0.0008 | g_loss: 11.7030
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 20.4704
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 14.1519
# Epoch [   97/  101] | d_loss: 0.0057 | g_loss: 15.9450
# Epoch [   97/  101] | d_loss: 0.0021 | g_loss: 17.3612
# Epoch [   97/  101] | d_loss: 0.0002 | g_loss: 14.6321
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 16.5331
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 26.9073
# Epoch [   97/  101] | d_loss: 0.0006 | g_loss: 12.1070
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 22.1387
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 18.7469
# Epoch [   97/  101] | d_loss: 0.0001 | g_loss: 19.2331
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 13.5782
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 12.2574
# Epoch [   97/  101] | d_loss: 0.0009 | g_loss: 12.3194
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 12.6514
# Epoch [   97/  101] | d_loss: 0.0021 | g_loss: 17.6380
# Epoch [   97/  101] | d_loss: 0.0001 | g_loss: 7.2869
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 15.7086
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 26.5280
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 29.8918
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 21.3223
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 19.3970
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 18.9565
# Epoch [   97/  101] | d_loss: 0.0004 | g_loss: 14.0793
# Epoch [   97/  101] | d_loss: 0.0015 | g_loss: 11.9858
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 19.2826
# Epoch [   97/  101] | d_loss: 0.0014 | g_loss: 17.6202
# Epoch [   97/  101] | d_loss: 0.0000 | g_loss: 12.7141
# Epoch [   97/  101] | d_loss: 0.0002 | g_loss: 13.3942
# Epoch [   98/  101] | d_loss: 0.0016 | g_loss: 11.1547
# Epoch [   98/  101] | d_loss: 0.0002 | g_loss: 19.1817
# Epoch [   98/  101] | d_loss: 0.0009 | g_loss: 10.1698
# Epoch [   98/  101] | d_loss: 0.0120 | g_loss: 11.9460
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 6.2111
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 20.0932
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 14.7199
# Epoch [   98/  101] | d_loss: 0.0009 | g_loss: 18.6707
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 12.1028
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 16.5281
# Epoch [   98/  101] | d_loss: 0.0001 | g_loss: 12.6173
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 18.8610
# Epoch [   98/  101] | d_loss: 0.0022 | g_loss: 9.6920
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 12.1830
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 18.5496
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 16.5739
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 11.1672
# Epoch [   98/  101] | d_loss: 0.0021 | g_loss: 13.7358
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 12.7528
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 23.9551
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 17.4617
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 17.0904
# Epoch [   98/  101] | d_loss: 0.0001 | g_loss: 17.8842
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 11.6869
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 18.2810
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 13.7541
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 11.5592
# Epoch [   98/  101] | d_loss: 0.0010 | g_loss: 11.2079
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 14.4290
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 29.7402
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 24.4069
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 15.4445
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 16.5995
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 26.6030
# Epoch [   98/  101] | d_loss: 0.0001 | g_loss: 15.7308
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 16.7009
# Epoch [   98/  101] | d_loss: 0.0004 | g_loss: 18.2400
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 14.8875
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 22.1648
# Epoch [   98/  101] | d_loss: 0.0004 | g_loss: 11.4900
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 10.7449
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 16.8503
# Epoch [   98/  101] | d_loss: 0.0016 | g_loss: 8.8861
# Epoch [   98/  101] | d_loss: 0.0005 | g_loss: 11.8637
# Epoch [   98/  101] | d_loss: 0.0123 | g_loss: 14.6281
# Epoch [   98/  101] | d_loss: 0.0001 | g_loss: 11.5352
# Epoch [   98/  101] | d_loss: 0.0003 | g_loss: 14.9200
# Epoch [   98/  101] | d_loss: 0.0002 | g_loss: 9.3496
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 21.6319
# Epoch [   98/  101] | d_loss: 0.0021 | g_loss: 11.1511
# Epoch [   98/  101] | d_loss: 0.0035 | g_loss: 9.0119
# Epoch [   98/  101] | d_loss: 0.0079 | g_loss: 5.7080
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 19.5264
# Epoch [   98/  101] | d_loss: 0.0000 | g_loss: 9.9004
# Epoch [   98/  101] | d_loss: 0.0004 | g_loss: 12.8325
# Epoch [   98/  101] | d_loss: 0.0047 | g_loss: 16.2575
# Epoch [   98/  101] | d_loss: 0.0054 | g_loss: 12.3343
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 10.4535
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 11.1014
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 7.3129
# Epoch [   99/  101] | d_loss: 0.0007 | g_loss: 7.0344
# Epoch [   99/  101] | d_loss: 0.0002 | g_loss: 14.1017
# Epoch [   99/  101] | d_loss: 0.0135 | g_loss: 14.3863
# Epoch [   99/  101] | d_loss: 0.0005 | g_loss: 6.6085
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 23.2238
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 13.5937
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 13.7761
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 16.5470
# Epoch [   99/  101] | d_loss: 0.0005 | g_loss: 11.3047
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 25.6555
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 19.1177
# Epoch [   99/  101] | d_loss: 0.0004 | g_loss: 11.7517
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 7.1099
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 12.0520
# Epoch [   99/  101] | d_loss: 0.0002 | g_loss: 11.2101
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 10.7718
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 10.5620
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 13.6786
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 13.4577
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 7.6620
# Epoch [   99/  101] | d_loss: 0.0004 | g_loss: 15.4258
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 22.8124
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 19.3438
# Epoch [   99/  101] | d_loss: 0.0002 | g_loss: 14.5125
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 15.7947
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 11.0229
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 11.5870
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 27.1132
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 22.5427
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 22.1302
# Epoch [   99/  101] | d_loss: 0.0007 | g_loss: 16.7356
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 19.1907
# Epoch [   99/  101] | d_loss: 0.0002 | g_loss: 15.5471
# Epoch [   99/  101] | d_loss: 0.0008 | g_loss: 13.2808
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 11.6855
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 18.7781
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 17.8816
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 16.2148
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 26.9816
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 25.5588
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 19.5016
# Epoch [   99/  101] | d_loss: 0.0005 | g_loss: 17.8378
# Epoch [   99/  101] | d_loss: 0.0054 | g_loss: 19.6341
# Epoch [   99/  101] | d_loss: 0.0007 | g_loss: 7.9804
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 11.1255
# Epoch [   99/  101] | d_loss: 0.0001 | g_loss: 7.8474
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 14.4988
# Epoch [   99/  101] | d_loss: 0.0008 | g_loss: 10.8096
# Epoch [   99/  101] | d_loss: 0.0027 | g_loss: 12.3265
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 18.0684
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 10.7625
# Epoch [   99/  101] | d_loss: 0.0006 | g_loss: 19.9126
# Epoch [   99/  101] | d_loss: 0.0003 | g_loss: 13.7946
# Epoch [   99/  101] | d_loss: 0.0000 | g_loss: 11.2564
# Epoch [  100/  101] | d_loss: 0.0023 | g_loss: 12.0660
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 18.9405
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 16.8420
# Epoch [  100/  101] | d_loss: 0.0004 | g_loss: 22.9328
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 13.7483
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 16.3872
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 19.6500
# Epoch [  100/  101] | d_loss: 0.0028 | g_loss: 17.1251
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 13.9377
# Epoch [  100/  101] | d_loss: 0.0119 | g_loss: 12.4268
# Epoch [  100/  101] | d_loss: 0.0002 | g_loss: 12.8990
# Epoch [  100/  101] | d_loss: 0.0084 | g_loss: 9.2923
# Epoch [  100/  101] | d_loss: 0.0006 | g_loss: 9.3991
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 10.6921
# Epoch [  100/  101] | d_loss: 0.0009 | g_loss: 24.8590
# Epoch [  100/  101] | d_loss: 0.0002 | g_loss: 8.6606
# Epoch [  100/  101] | d_loss: 0.0016 | g_loss: 3.4803
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 11.3955
# Epoch [  100/  101] | d_loss: 0.0011 | g_loss: 21.6030
# Epoch [  100/  101] | d_loss: 0.0129 | g_loss: 12.8431
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 9.4377
# Epoch [  100/  101] | d_loss: 0.0067 | g_loss: 15.8170
# Epoch [  100/  101] | d_loss: 0.0143 | g_loss: 16.4981
# Epoch [  100/  101] | d_loss: 0.0059 | g_loss: 10.4446
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 13.8976
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 9.1881
# Epoch [  100/  101] | d_loss: 0.0037 | g_loss: 7.3538
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 14.0018
# Epoch [  100/  101] | d_loss: 0.0086 | g_loss: 13.1490
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 12.2578
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 12.7612
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 15.8494
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 10.2051
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 14.8625
# Epoch [  100/  101] | d_loss: 0.0032 | g_loss: 11.3902
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 18.8323
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 17.7816
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 16.1115
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 14.7989
# Epoch [  100/  101] | d_loss: 0.0003 | g_loss: 12.8694
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 12.4716
# Epoch [  100/  101] | d_loss: 0.0038 | g_loss: 14.3376
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 12.3389
# Epoch [  100/  101] | d_loss: 0.0002 | g_loss: 11.7374
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 13.8391
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 11.7298
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 10.8711
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 10.5801
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 13.4823
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 16.7192
# Epoch [  100/  101] | d_loss: 0.0001 | g_loss: 18.5228
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 13.1011
# Epoch [  100/  101] | d_loss: 0.0006 | g_loss: 7.3441
# Epoch [  100/  101] | d_loss: 0.0007 | g_loss: 14.9376
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 12.9187
# Epoch [  100/  101] | d_loss: 0.0050 | g_loss: 12.5791
# Epoch [  100/  101] | d_loss: 0.0000 | g_loss: 11.5663
# Epoch [  101/  101] | d_loss: 0.0036 | g_loss: 12.2494
# Epoch [  101/  101] | d_loss: 0.0002 | g_loss: 13.0801
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 13.7112
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 11.0438
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 11.0629
# Epoch [  101/  101] | d_loss: 0.0009 | g_loss: 10.7376
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 12.4498
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 16.3345
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 18.5578
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 11.9346
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 15.7795
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 18.0425
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 5.7295
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 11.5310
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 12.1040
# Epoch [  101/  101] | d_loss: 0.0008 | g_loss: 11.7977
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 16.5113
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 12.2377
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 12.3029
# Epoch [  101/  101] | d_loss: 0.0002 | g_loss: 16.8621
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 27.7746
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 12.2621
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 24.4324
# Epoch [  101/  101] | d_loss: 0.0220 | g_loss: 14.0177
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 12.3432
# Epoch [  101/  101] | d_loss: 0.0005 | g_loss: 10.3635
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 7.0605
# Epoch [  101/  101] | d_loss: 0.0010 | g_loss: 13.5265
# Epoch [  101/  101] | d_loss: 0.0011 | g_loss: 5.8634
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 9.6939
# Epoch [  101/  101] | d_loss: 0.0045 | g_loss: 9.1412
# Epoch [  101/  101] | d_loss: 0.0008 | g_loss: 10.3752
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 15.5851
# Epoch [  101/  101] | d_loss: 0.0003 | g_loss: 15.5499
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 16.6543
# Epoch [  101/  101] | d_loss: 0.0002 | g_loss: 9.1359
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 14.4578
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 11.2936
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 13.1606
# Epoch [  101/  101] | d_loss: 0.0016 | g_loss: 8.2370
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 18.0539
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 18.6270
# Epoch [  101/  101] | d_loss: 0.0009 | g_loss: 12.2619
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 19.4696
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 11.5994
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 13.6671
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 20.1072
# Epoch [  101/  101] | d_loss: 0.0030 | g_loss: 13.9437
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 9.6328
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 10.9679
# Epoch [  101/  101] | d_loss: 0.0001 | g_loss: 12.8233
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 14.9349
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 21.9477
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 18.9871
# Epoch [  101/  101] | d_loss: 0.0007 | g_loss: 10.4847
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 19.0066
# Epoch [  101/  101] | d_loss: 0.0000 | g_loss: 14.3567
# View Samples
# {'batch_size': 32, 'img_size': 32, 'deconv-layers': 3, 'conv-layers': 3, 'd_conv_dim': 64, 'g_conv_dim': 64, 'z_size': 100, 'lr': 0.0002, 'beta1': 0.2, 'beta2': 0.999, 'dropout': 'no', 'n_epochs': 101}
# Plot Loss

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples_2(epoch, samples, train_num, param_value):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))
    fig.suptitle(param_value)
    fig.savefig('image_sets/train_' + str(train_num) + '_' + str(param_value) + '.png')

# %%
# helper function for viewing a list of passed in sample images
def view_plots(train_runs, title, param):
    number_of_pots = len(train_runs)
    train_run_list = [m[0] for m in train_runs]
    param_list = [m[1] for m in train_runs]
    epochs_calc = [m[2] for m in train_runs]
    
    ax_set = ('a' + str(m) for m in range(number_of_pots))
    
    fig, ax_set = plt.subplots(figsize=(16,4), nrows=1, ncols=number_of_pots)
    fig.suptitle(title)
    for ii,train_num in enumerate(train_run_list):
        df = pd.read_excel('training_results/train_' + str(train_num) + '_' + str(param_list[ii]) + '.xlsx')  # doctest: +SKIP
        loss_d = df['Discriminator'].values
        loss_g = df['Generator'].values
        ax_set[ii].plot(df.index/epochs_calc[ii], loss_d, label='Discriminator')
        ax_set[ii].plot(df.index/epochs_calc[ii], loss_g, label='Generator')
        ax_set[ii].set_title('Train_' + str(train_num))
        #ax_set[ii].xlabel('n_epochs', fontsize=14)
        #ax_set[iniidex].ylabel('loss', fontsize=14)
        ax_set[ii].legend()
        
    fig.savefig('plots/train_' + str(param) + '.png')

# %% [markdown]
# In the following section the parameter tuning which was investigated in separated training runs is appended.

# %% [markdown]
# ## Parameter: n_epochs
#
# Parameters          | 1st Train-Run | 2nd Train-Run | 3rd Train-Run | 4th Train-Run | 5th Train-Run | 6th Train-Run |
# ----------          | ------------- | ------------- | ------------- | ------------- | ------------- | ------------- |
# batch_size          |   128         |   128         |   128         |   128         |   128         |   128         |
# img_size            |   32          |   32          |   32          |   32          |   32          |   32          |
# deconv-layers       |   3           |   3           |   3           |   3           |   3           |   3           |
# conv-layers         |   3           |   3           |   3           |   3           |   3           |   3           |
# d_conv_dim          |   32          |   32          |   32          |   32          |   32          |   32          |
# g_conv_dim          |   32          |   32          |   32          |   32          |   32          |   32          |
# z_size              |   100         |   100         |   100         |   100         |   100         |   100         |
# lr                  |   0.001       |   0.001       |   0.001       |   0.001       |   0.001       |   0.001       |
# beta1               |   0.5         |   0.5         |   0.5         |   0.5         |   0.5         |   0.5         |
# beta2               |   0.999       |   0.999       |   0.999       |   0.999       |   0.999       |   0.999       |
# dropout             |   no          |   no          |   no          |   no          |   no          |   no          |
# **n_epochs**        |   `1`         |   `10`        |   `50`        |   `100`       |   `500`       |   `1000`      |

# %%
# n_epochs = 1, 10, 50, 100, 200, 300, 400, 500
parameter_list_name = [6* 'Train32 best off']
train_num_list = [6* best_off]
param_list = ['num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs']
epoch_list = [1, 10, 50, 100 , 200, 300, 400, 500]
for epoch, param, param_value_name, train_num in zip(epoch_list, param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_' + str(epoch) + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '_' + str(param_value_name) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[1, 'num_epochs', 3],
            [2, 'num_epochs', 3],
            [3, 'num_epochs', 3],
            [4, 'num_epochs', 3],
            [5, 'num_epochs', 3],
            [6, 'num_epochs', 3]], 'Number of epochs', 'n_epochs')

# %% [markdown]
# ### Result for parameter n_epochs:
# Best value setting for the number of epochs extends to the range 50...100. Lower epoch values lead to underfitting, higher epoch values tend to pronounced noisy behavior of the discriminator loss. In both regimes the generated face images are blurred. In the following 100 epochs will be used for further parameter studies.

# %% [markdown]
# ## Parameter: number of conv-layers and deconv-layers
#
# Parameters          | 4th Train-Run | 8th Train-Run |
# ----------          | ------------- | ------------- |
# batch_size          |   128         |   128         |
# img_size            |   32          |   32          |
# **deconv-layers**   |   `3`         |   `4`         |
# **conv-layers**     |   `3`         |   `4`         |
# d_conv_dim          |   32          |   32          |
# g_conv_dim          |   32          |   32          |
# z_size              |   100         |   100         |
# lr                  |   0.001       |   0.001       |
# beta1               |   0.5         |   0.5         |
# beta2               |   0.999       |   0.999       |
# dropout             |   no          |   no          |
# n_epochs            |   100         |   100         |

# %%
# conv-layers=deconv-layers=3 ... 4
parameter_list_name = ['conv-layers=deconv-layers=3','conv-layers=deconv-layers=4']
train_num_list = [4, 8]
param_list = ['num_epochs', 'conv_deconv']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[4, 'num_epochs', 3],
            [8, 'conv_deconv', 3]],'Number of conv- and deconv-layers', 'conv_deconv')

# %% [markdown]
# ### Result for parameter number of conv-layers and deconv-layers:
# There is no clear trend with regard to the number of conv-layers and deconv-layers. Corresponding images for conv-layers=3 and deconv-layers=3 look similar to conv-layers=4 and deconv-layers=4. However, the trend of losses is slightly better for conv-layers=4 and deconv-layers=4, higher (positive) loss for the Generator and slightly lower loss for the Discriminator. In the following conv-layers=4 and deconv-layers=4 will be used for further parameter studies.

# %% [markdown]
# ## Parameter: batch_size
#
# Parameters          | 14th Train-Run | 15th Train-Run | 16th Train-Run  | 17th Train-Run |
# ----------          | ------------- | -------------   | -------------   | -------------  |
# **batch_size**      |   `64`        |   `128`         |   `256`         |  `512`         |
# img_size            |   32          |   32            |   32            |   32           |
# deconv-layers       |   4           |   4             |   4             |   4            |
# conv-layers         |   4           |   4             |   4             |   4            |
# d_conv_dim          |   32          |   32            |   32            |   32           |
# g_conv_dim          |   32          |   32            |   32            |   32           |
# z_size              |   100         |   100           |   100           |   100          |
# lr                  |   0.001       |   0.001         |   0.001         |   0.001        |
# beta1               |   0.5         |   0.5           |   0.5           |   0.5          |
# beta2               |   0.999       |   0.999         |   0.999         |   0.999        |
# dropout             |   no          |   no            |   no            |   no           |
# n_epochs            |   100         |   100           |   100           |   100          |

# %%
# batch_size= 64 , 128, 256, 512
parameter_list_name = ['batch_size=64','batch_size=128', 'batch_size=256', 'batch_size=512']
train_num_list = [14, 15, 16, 17]
param_list = ['batch_size', 'batch_size', 'batch_size', 'batch_size']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[14, 'batch_size', 5],
            [15, 'batch_size', 3],
            [16, 'batch_size', 2],
            [17, 'batch_size', 1]], 'Batch size', 'batch_size')

# %% [markdown]
# #### Result for parameter batch_size:
# A larger batch_size has a positive effect on the computational boost. However, if the batch_size is getting too high the feature resolution is getting worse. This can be clearly seen if one compares a batch_size of 512 with a batch_size of 128. For the further study a batch_size of 128 has been chosen.

# %% [markdown]
# ## Parameter: conv_dim
#
# Parameters          | 8th Train-Run | 11th Train-Run  | 12th Train-Run  | 13th Train-Run |
# ----------          | ------------- | -------------   | -------------   | -------------  |
# batch_size          |   128         |   128           |   128           |  128           |
# img_size            |   32          |   32            |   32            |   32           |
# deconv-layers       |   4           |   4             |   4             |   4            |
# conv-layers         |   4           |   4             |   4             |   4            |
# **d_conv_dim**      |   `32`        |   `64`          |   `128`         |  `256`         |
# **g_conv_dim**      |   `32`        |   `64`          |   `128`         |  `256`         |
# z_size              |   100         |   100           |   100           |   100          |
# lr                  |   0.001       |   0.001         |   0.001         |   0.001        |
# beta1               |   0.5         |   0.5           |   0.5           |   0.5          |
# beta2               |   0.999       |   0.999         |   0.999         |   0.999        |
# dropout             |   no          |   no            |   no            |   no           |
# n_epochs            |   100         |   100           |   100           |   100          |

# %%
# conv_dim= 32, 64 , 128, 256
parameter_list_name = ['conv_dim=32', 'conv_dim=64','conv_dim=128', 'conv_dim=256']
train_num_list = [8, 11, 12, 13]
param_list = ['conv_deconv', 'conv_dim', 'conv_dim', 'conv_dim']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[8, 'conv_deconv', 3],
            [11, 'conv_dim', 3],
            [12, 'conv_dim', 3],
            [13, 'conv_dim', 3]], 'Size of conv_dim', 'conv_dim')

# %% [markdown]
# #### Result for parameter conv_dim:
# With a higher conv_dim for the Generator and the Discriminator the resolution of feature details is getting higher. For example, eyes are better resolved with a conv_dim=256 than with a conv_dim=32. However, even a conv_dim of 64 leads to convincing results.

# %% [markdown]
# ### Parameter: lr
#
# Parameters          | 21th Train-Run | 14th Train-Run  | 22th Train-Run |
# ----------          | ------------- | -------------   | -------------   |
# batch_size          |   128         |   128           |   128           |
# img_size            |   32          |   32            |   32            |
# deconv-layers       |   4           |   4             |   4             |
# conv-layers         |   4           |   4             |   4             |
# d_conv_dim          |   64          |   64            |   64            |
# g_conv_dim          |   64          |   64            |   64            |
# z_size              |   100         |   100           |   100           |
# **lr**              |   `0.01`      |   `0.001`       |   `0.0001`      |
# beta1               |   0.5         |   0.5           |   0.5           |
# beta2               |   0.999       |   0.999         |   0.999         |
# dropout             |   no          |   no            |   no            |
# n_epochs            |   100         |   100           |   100           |

# %%
# lr= 0.01, 0.001, 0.0001
parameter_list_name = ['lr=0.01', 'lr=0.001','lr=0.0001']
train_num_list = [21, 14, 22]
param_list = ['lr', 'batch_size', 'lr', 'conv_dim']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[21, 'lr', 3],
            [14, 'batch_size', 3],
            [22, 'lr', 3]], 'Learning rate', 'lr')

# %% [markdown]
# #### Result for parameter lr:
# Learning rates in the range between 0.01 and 0.0001 were tested. In all three cases the GAN is able to learn and generated fake images of faces are successfully constructed. However,  a learning rate of lr=0.001 or lr=0.0001 lead to a slightly better feature resolution than lr = 0.01.

# %% [markdown]
# ### Final hyperparameter setting
# The following table shows the best-of setting of the investigated parameter tuning.
#
# Parameters          | 14th Train-Run|
# ----------          | ------------- |
# batch_size          |   32          |
# img_size            |   32          |
# deconv-layers       |   4           |
# conv-layers         |   4           |
# d_conv_dim          |   64          |
# g_conv_dim          |   64          |
# z_size              |   100         |
# lr                  |   0.0002      |
# beta1               |   0.2         |
# beta2               |   0.999       |
# dropout             |   yes         |
# n_epochs            |   100         |

# %% [markdown]
# ### Final fake image output

# %%
# final result
parameter_list_name = ['Final result']
train_num_list = [22]
param_list = ['lr']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %% [markdown]
# ### Corresponding loss for the final setting

# %%
# loss for reasonable setting
train_num = 22
param = 'lr'
fig, ax = plt.subplots()
df = pd.read_excel('training_results/train_' + str(train_num) + '_' + str(param) + '.xlsx')  # doctest: +SKIP
loss_d = df['Discriminator'].values
loss_g = df['Generator'].values
plt.plot(df.index/3, loss_d, label='Discriminator')
plt.plot(df.index/3,loss_g, label='Generator')
plt.title("Train_22")
plt.legend()
fig.savefig('plots/train_22_single.png')

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# ### Reasons for the chosen final hyperparameter setting:
# A whole bunch of parameters setting were tested in sequences (see evaluation above).
#
# #### n_epochs:
# n_epochs was varied between 1 and 1000. Its best value setting extends to the range 50...100. Lower epoch values lead to underfitting, higher epoch values tend to pronounced noisy behavior of the discriminator loss. For both extreme regimes the generated face images are blurred. Therefore n_epochs was set to 100.
#
# #### number of conv-layers and deconv-layers:
# Two models were constructed: one with 3 and another one with 4 conv and deconv layers for the discriminator and generator, respectively. Corresponding images for conv-layers=deconv-layers=3 look similar to conv-layers=deconv-layers=4. Hence, a clear trend is hard to distinguish in these examples. However, the trend of losses is slightly better for conv-layers=deconv-layers=4 than for conv-layers=deconv-layers=3, i.e. the loss for the Generator is higher and the loss for the Discriminator is slightly lower. Therefore conv-layers=4 and deconv-layers=4 have been used for further parameter studies.
#
# #### batch_size:
# The value range for the batch_size was chosen between 16 and 512. A larger batch_size has a positive effect on the computational boost. However, if the batch_size is getting too high the feature resolution is getting worse (more blurred). This can be clearly seen if one compares a batch_size of 512 with a batch_size of 128. If the batch size is too small then the gradients will become more unstable and would need to reduce the learning rate. So batch size and learning rate are linked. Also if one use a batch size too big then the gradients will become less noisy but it will take longer to converge. Therefore a batch_size of 128 has been chosen. Up to a batch_size of 512 no out-of-memory errors were observed (getting critical for higher batch_sizes).
#
# ##### conv_dim:
# The conv_dim value was investigated in the range between 32 and 256. With a higher conv_dim for the Generator and the Discriminator the resolution of feature details is getting higher. For example, eyes are better resolved with a conv_dim=256 than with a conv_dim=32. However, even a conv_dim of 64 leads to convincing results.
#
# #### lr:
# As learning rates 0.01, 0.01 and 0.0001 were tested. In all three cases the GAN is able to learn and generated fake images of faces successfully. However, lr=0.001 or lr=0.0001 lead to a slightly better feature resolution than lr = 0.01.
#
# ### Further improvements:
# - To overcome the issue of a biased dataset (celebrity faces that are mostly white): one could add more images of non-white celebrity faces to get a more balanced dataset in the end.
#
# - The model size is limited by the number of conv-layers and deconv-layers which was set to 4 in maximum. Higher values were not tested so far. Increasing the model size could especially enhance the feature extraction of the Discriminator. The adversarial Generator is then forced to produce images with better feature resolution.
#
# - A further increase of the conv_dim could lead to better results. However, this would significantly increase the training time.
#
# - The dataset images are 64x64x3 NumPy images. In the get_dataloader function I resized the images down to 32x32x3. This is the image size for the Discriminator input and the size of the Generator output. This resolution of the generated images is noisy. If one would keep width=64 and height=64 the images could resemble more the original ones. However, this would also increase the training duration.
#
# - Regarding the optimizer strategy: For the Discriminator as well as for the Generator the same type of optimizer (Adam) was chosen with a learning rate down to 0.0001. A combination of different optimizer like SGD for the Discriminator and Adam for the Generator as proposed by [Soumith](https://github.com/soumith/ganhacks) has not been tested yet.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
