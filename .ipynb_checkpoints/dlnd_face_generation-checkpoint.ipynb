# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# !pip install --upgrade pip
# !pip install torch
#!pip install torchvision
#!pip install -U numpy
#!pip show numpy
# Out:
# Traceback (most recent call last):
#   File "/anaconda3/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/cli/main.py", line 73, in main
#     command = create_command(cmd_name, isolated=("--isolated" in cmd_args))
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/commands/__init__.py", line 96, in create_command
#     module = importlib.import_module(module_path)
#   File "/anaconda3/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/commands/install.py", line 24, in <module>
#     from pip._internal.cli.req_command import RequirementCommand
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/cli/req_command.py", line 20, in <module>
#     from pip._internal.operations.prepare import RequirementPreparer
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/operations/prepare.py", line 16, in <module>
#     from pip._internal.distributions import (
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/distributions/__init__.py", line 1, in <module>
#     from pip._internal.distributions.source import SourceDistribution
# ImportError: cannot import name 'SourceDistribution' from 'pip._internal.distributions.source' (/anaconda3/lib/python3.7/site-packages/pip/_internal/distributions/source/__init__.py)
# Traceback (most recent call last):
#   File "/anaconda3/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/cli/main.py", line 73, in main
#     command = create_command(cmd_name, isolated=("--isolated" in cmd_args))
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/commands/__init__.py", line 96, in create_command
#     module = importlib.import_module(module_path)
#   File "/anaconda3/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/commands/install.py", line 24, in <module>
#     from pip._internal.cli.req_command import RequirementCommand
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/cli/req_command.py", line 20, in <module>
#     from pip._internal.operations.prepare import RequirementPreparer
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/operations/prepare.py", line 16, in <module>
#     from pip._internal.distributions import (
#   File "/anaconda3/lib/python3.7/site-packages/pip/_internal/distributions/__init__.py", line 1, in <module>
#     from pip._internal.distributions.source import SourceDistribution
# ImportError: cannot import name 'SourceDistribution' from 'pip._internal.distributions.source' (/anaconda3/lib/python3.7/site-packages/pip/_internal/distributions/source/__init__.py)

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# unzip:  cannot find or open processed_celeba_small.zip, processed_celeba_small.zip.zip or processed_celeba_small.zip.ZIP.

# %%
# necessary imports
import pandas as pd
import torch
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from PIL import Image 
import glob
import os

# %%
data_dir = 'processed_celeba_small/'
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests


# %matplotlib inline

# %%
# Parameter settings

train_n = 37
param = 'batch_size'

# set parameter sets
number_epochs = [1, 10, 50, 100, 500, 1000]
lr_set = [0.001]
batch_size_set = [32]
conv_dim_set = [64, 128, 256]

# default
batch_size = 32
img_size = 32
n_epochs = 60
conv_dim = 64
lr = 0.001
beta1=0.2
beta2=0.999
z_size = 100

# %%
# Make directories if they do not exist
data_dir = './training_results_pkl2'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)
    
data_dir = './training_results'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)
    
data_dir = './image_sets'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
print('Number of images used for the Discriminator Training: ', len(glob.glob("processed_celeba_small/celeba/*.jpg")))
# Out:
# Number of images used for the Discriminator Training:  10674

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    # Tensor transform
    transform = transforms.Compose([transforms.Resize(image_size),
                                    transforms.CenterCrop(image_size),
                                    transforms.ToTensor()
                                    ])
    
    dataset = datasets.ImageFolder(data_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size, shuffle=True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=16
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %%
fig.savefig('image_sets/orig_examples.png')

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
     # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(0.6471)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim=32):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32x32 input
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # first layer, no batch_norm
        # 16x16 out
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        # 8x8 out
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        # 4x4 out
        self.conv4 = conv(conv_dim*4, conv_dim*8, 4)
        # 2x2 out
        
        # final, fully-connected layer
        self.fc = nn.Linear(conv_dim*8*2*2, 1)
        
        # set dropout layer
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv3(out), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv4(out), 0.2)
        # flatten
        out = out.view(-1, self.conv_dim*8*2*2)
        out = self.dropout(out)
        # final output layer
        out = self.fc(out)        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # first, fully-connected layer
        self.fc = nn.Linear(z_size, conv_dim*8*2*2)

        # transpose conv layers
        self.t_conv1 = deconv(conv_dim*8, conv_dim*4, 4)
        self.t_conv2 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv3 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv4 = deconv(conv_dim, 3, 4, batch_norm=False)
        
        # set dropout layer
        self.dropout = nn.Dropout(p=0.5)
        

    def forward(self, x):
        # fully-connected + reshape 
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*8, 2, 2) # (batch_size, depth, 2, 2)
        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out = self.dropout(out)
        out = F.relu(self.t_conv2(out))
        out = self.dropout(out)
        out = F.relu(self.t_conv3(out))
        out = self.dropout(out)
        # last layer + tanh activation
        out = self.t_conv4(out)
        out = F.tanh(out)
        
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed
# /anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
# takes in a module and applies the specified weight initialization
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and classname.find('Linear') != -1:
        m.weight.data.normal_(0, 0.02)
        m.bias.data.fill_(0)
    
    elif hasattr(m, 'weight') and classname.find('Conv') != -1:
        m.weight.data.normal_(0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        labels = torch.ones(batch_size)*0.9 # smooth, real labels = 0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models.

# %%
# Create optimizers for the discriminator and generator
def optimizer(lr):
    d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
    g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

    return d_optimizer, g_optimizer

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
# save chosen hyperparameters of the actual training run to an excel file
def save_data(index, losses, batch_size):
    losses = np.array(losses)
    
    # Export Loss as Dataframe
    idx = range(len(losses.T[0]))
    d = {'Discriminator': losses.T[0], 'Generator': losses.T[1]}
    loss_df = pd.DataFrame(data=d, index = idx)
    train_number = train_n + index
    loss_df.to_excel('training_results/train_' + str(train_number) +'_'+ param + ".xlsx")
    
    # Export hyperparameters
    hyper_params = {'batch_size': batch_size,
                'img_size': img_size,
                'deconv-layers': 3,
                'conv-layers': 3,
                'd_conv_dim': d_conv_dim,
                'g_conv_dim': g_conv_dim,
                'z_size': z_size,
                'lr': lr,
                'beta1': beta1,
                'beta2': beta2,
                'dropout': 'no',
                'n_epochs': n_epochs
                }
    hyper_param_df = pd.DataFrame.from_dict(hyper_params, orient='index')
    hyper_param_df.to_excel('training_results/train_' + str(train_number) +'_'+ param + "_hyper_param.xlsx")
    print(hyper_params)

# %%
# plot the training losses of Discriminator and Generator for the actual training run
def plot_training_loss(losses):
    print('Plot Loss')
    fig, ax = plt.subplots()
    losses = np.array(losses)
    plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
    plt.plot(losses.T[1], label='Generator', alpha=0.5)
    plt.title("Training Losses")
    plt.legend()
    plt.show()

# %%
# helper function for viewing a list of passed in sample images
def view_samples(index, epoch):
    print('View Samples')
    train_number = train_n + index
    # Load samples from generator, taken while training
    with open('training_results_pkl/train_' + str(train_number) +'_'+ param + '_' + str(epoch) + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[-1]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))
    plt.show()

# %%
def train(D, G,  n_epochs, index=0, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    train_number = train_n + index
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # ============================================
            #            TRAIN THE DISCRIMINATOR
            # ============================================

            d_optimizer.zero_grad()

            # 1. Train with real images

            # Compute the discriminator losses on real images 
            if train_on_gpu:
                real_images = real_images.cuda()

            D_real = D(real_images)
            d_real_loss = real_loss(D_real)

            # 2. Train with fake images

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)

            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()


            # =========================================
            #            TRAIN THE GENERATOR
            # =========================================
            g_optimizer.zero_grad()

            # 1. Train with fake images and flipped labels

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels

            # perform backprop
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

        if epoch % 10 == 0:
            # Save training generator samples
            with open('training_results_pkl/train_' + str(train_number) +'_'+ param + '_' + str(epoch) + '_samples.pkl', 'wb') as f:
                pkl.dump(samples, f)
                
            _ = view_samples(index, epoch)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
n_epochs=1
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/    1] | d_loss: 1.5995 | g_loss: 0.9347
# Epoch [    1/    1] | d_loss: 0.6342 | g_loss: 1.7510
# Epoch [    1/    1] | d_loss: 0.3255 | g_loss: 5.0689
# Epoch [    1/    1] | d_loss: 0.9283 | g_loss: 1.4535
# Epoch [    1/    1] | d_loss: 0.9666 | g_loss: 2.1043
# Epoch [    1/    1] | d_loss: 1.0957 | g_loss: 1.5611
# Epoch [    1/    1] | d_loss: 1.5226 | g_loss: 1.2737
# Epoch [    1/    1] | d_loss: 1.0990 | g_loss: 1.0061
# Epoch [    1/    1] | d_loss: 1.0469 | g_loss: 2.0480
# View Samples

# %%
# tune hyperparameters by calling the training function in a loop
n_epochs=101
#for index, n_epochs in enumerate(number_epochs):
#for index, conv_dim in enumerate(conv_dim_set):
#for index, lr in enumerate(lr_set):
for index, batch_size in enumerate(batch_size_set):
    # Set Parameter
    n_epochs = n_epochs
    lr = lr
    batch_size = batch_size
    d_conv_dim = conv_dim
    g_conv_dim = conv_dim
    
    # Get dataloader
    celeba_train_loader = get_dataloader(batch_size, img_size)
    
    # Build network
    print('Build Network')
    D, G = build_network(d_conv_dim, g_conv_dim, z_size)
    
    # Reset optimizer
    d_optimizer, g_optimizer = optimizer(lr)
    
    # Calculate losses
    losses = train(D, G, n_epochs=n_epochs, index=index)
    
    # Save and Plot Data
    save_data(index, losses, batch_size)
    plot_training_loss(losses)
    #_ = view_samples(index, epoch=-1)
# Out:
# Build Network
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Epoch [    1/  101] | d_loss: 1.6936 | g_loss: 2.2727
# Epoch [    1/  101] | d_loss: 0.4929 | g_loss: 2.3314
# Epoch [    1/  101] | d_loss: 1.6417 | g_loss: 4.0282
# Epoch [    1/  101] | d_loss: 1.2221 | g_loss: 0.8386
# Epoch [    1/  101] | d_loss: 1.1225 | g_loss: 2.2273
# Epoch [    1/  101] | d_loss: 1.2737 | g_loss: 1.7801
# Epoch [    1/  101] | d_loss: 0.8293 | g_loss: 1.8446
# Epoch [    1/  101] | d_loss: 1.3191 | g_loss: 0.4634
# Epoch [    1/  101] | d_loss: 1.0794 | g_loss: 1.5801
# View Samples
# Epoch [    2/  101] | d_loss: 0.9700 | g_loss: 0.9750
# Epoch [    2/  101] | d_loss: 1.6637 | g_loss: 0.9187
# Epoch [    2/  101] | d_loss: 1.4587 | g_loss: 3.2952
# Epoch [    2/  101] | d_loss: 1.0815 | g_loss: 1.3338
# Epoch [    2/  101] | d_loss: 1.3383 | g_loss: 1.7799
# Epoch [    2/  101] | d_loss: 1.4563 | g_loss: 0.6131
# Epoch [    2/  101] | d_loss: 1.2072 | g_loss: 2.9404
# Epoch [    2/  101] | d_loss: 1.1584 | g_loss: 1.0017
# Epoch [    2/  101] | d_loss: 1.1238 | g_loss: 1.4178
# Epoch [    3/  101] | d_loss: 1.7613 | g_loss: 1.3328
# Epoch [    3/  101] | d_loss: 2.3760 | g_loss: 1.0531
# Epoch [    3/  101] | d_loss: 1.1207 | g_loss: 0.3820
# Epoch [    3/  101] | d_loss: 0.9350 | g_loss: 2.0779
# Epoch [    3/  101] | d_loss: 1.1250 | g_loss: 1.0672
# Epoch [    3/  101] | d_loss: 1.1470 | g_loss: 1.2607
# Epoch [    3/  101] | d_loss: 0.8244 | g_loss: 1.6196
# Epoch [    3/  101] | d_loss: 0.9844 | g_loss: 1.1067
# Epoch [    3/  101] | d_loss: 0.8652 | g_loss: 1.2843
# Epoch [    4/  101] | d_loss: 0.6391 | g_loss: 1.8346
# Epoch [    4/  101] | d_loss: 0.6992 | g_loss: 2.5947
# Epoch [    4/  101] | d_loss: 0.5977 | g_loss: 2.3747
# Epoch [    4/  101] | d_loss: 1.3406 | g_loss: 0.9198
# Epoch [    4/  101] | d_loss: 1.0574 | g_loss: 0.8010
# Epoch [    4/  101] | d_loss: 0.8904 | g_loss: 4.4024
# Epoch [    4/  101] | d_loss: 0.3323 | g_loss: 2.0500
# Epoch [    4/  101] | d_loss: 0.7827 | g_loss: 1.8783
# Epoch [    4/  101] | d_loss: 0.7812 | g_loss: 3.5872
# Epoch [    5/  101] | d_loss: 1.8451 | g_loss: 4.1421
# Epoch [    5/  101] | d_loss: 1.1371 | g_loss: 0.9562
# Epoch [    5/  101] | d_loss: 0.6373 | g_loss: 3.7747
# Epoch [    5/  101] | d_loss: 1.1945 | g_loss: 0.6345
# Epoch [    5/  101] | d_loss: 0.7270 | g_loss: 2.8545
# Epoch [    5/  101] | d_loss: 0.9658 | g_loss: 1.2227
# Epoch [    5/  101] | d_loss: 1.1429 | g_loss: 1.2336
# Epoch [    5/  101] | d_loss: 1.2098 | g_loss: 1.4289
# Epoch [    5/  101] | d_loss: 0.9553 | g_loss: 2.3534
# Epoch [    6/  101] | d_loss: 0.6766 | g_loss: 1.0425
# Epoch [    6/  101] | d_loss: 0.3224 | g_loss: 3.5751
# Epoch [    6/  101] | d_loss: 0.2692 | g_loss: 3.1678
# Epoch [    6/  101] | d_loss: 0.3772 | g_loss: 2.9657
# Epoch [    6/  101] | d_loss: 1.9328 | g_loss: 0.5622
# Epoch [    6/  101] | d_loss: 1.9644 | g_loss: 0.9539
# Epoch [    6/  101] | d_loss: 0.7213 | g_loss: 3.7435
# Epoch [    6/  101] | d_loss: 0.6898 | g_loss: 6.3687
# Epoch [    6/  101] | d_loss: 0.4993 | g_loss: 0.9990
# Epoch [    7/  101] | d_loss: 0.3545 | g_loss: 2.0233
# Epoch [    7/  101] | d_loss: 0.2134 | g_loss: 1.5621
# Epoch [    7/  101] | d_loss: 2.4040 | g_loss: 0.4840
# Epoch [    7/  101] | d_loss: 0.3860 | g_loss: 2.9767
# Epoch [    7/  101] | d_loss: 0.2340 | g_loss: 3.8574
# Epoch [    7/  101] | d_loss: 1.2460 | g_loss: 5.0779
# Epoch [    7/  101] | d_loss: 0.1027 | g_loss: 3.9751
# Epoch [    7/  101] | d_loss: 0.5653 | g_loss: 4.7954
# Epoch [    7/  101] | d_loss: 0.1303 | g_loss: 2.8086
# Epoch [    8/  101] | d_loss: 1.0467 | g_loss: 0.9293
# Epoch [    8/  101] | d_loss: 0.3852 | g_loss: 2.3975
# Epoch [    8/  101] | d_loss: 0.4340 | g_loss: 4.2026
# Epoch [    8/  101] | d_loss: 1.7692 | g_loss: 8.1315
# Epoch [    8/  101] | d_loss: 0.3363 | g_loss: 3.3189
# Epoch [    8/  101] | d_loss: 0.2737 | g_loss: 2.8978
# Epoch [    8/  101] | d_loss: 0.4989 | g_loss: 2.2258
# Epoch [    8/  101] | d_loss: 0.9846 | g_loss: 3.5170
# Epoch [    8/  101] | d_loss: 0.2681 | g_loss: 2.4025
# Epoch [    9/  101] | d_loss: 0.5475 | g_loss: 1.7491
# Epoch [    9/  101] | d_loss: 0.3761 | g_loss: 1.3991
# Epoch [    9/  101] | d_loss: 1.2859 | g_loss: 0.0308
# Epoch [    9/  101] | d_loss: 0.1986 | g_loss: 3.7694
# Epoch [    9/  101] | d_loss: 0.2245 | g_loss: 2.4039
# Epoch [    9/  101] | d_loss: 0.1284 | g_loss: 1.4856
# Epoch [    9/  101] | d_loss: 0.4387 | g_loss: 7.3996
# Epoch [    9/  101] | d_loss: 0.0634 | g_loss: 4.1511
# Epoch [    9/  101] | d_loss: 1.1894 | g_loss: 7.5151
# Epoch [   10/  101] | d_loss: 0.1556 | g_loss: 5.8242
# Epoch [   10/  101] | d_loss: 1.1407 | g_loss: 1.3356
# Epoch [   10/  101] | d_loss: 0.0752 | g_loss: 5.3475
# Epoch [   10/  101] | d_loss: 0.1558 | g_loss: 2.0152
# Epoch [   10/  101] | d_loss: 0.5093 | g_loss: 4.9712
# Epoch [   10/  101] | d_loss: 0.0682 | g_loss: 4.8036
# Epoch [   10/  101] | d_loss: 4.2061 | g_loss: 0.5254
# Epoch [   10/  101] | d_loss: 0.0529 | g_loss: 1.5691
# Epoch [   10/  101] | d_loss: 0.0464 | g_loss: 2.2991
# Epoch [   11/  101] | d_loss: 0.1811 | g_loss: 4.5167
# Epoch [   11/  101] | d_loss: 0.2216 | g_loss: 4.2177
# Epoch [   11/  101] | d_loss: 0.8564 | g_loss: 3.7680
# Epoch [   11/  101] | d_loss: 0.0424 | g_loss: 4.7399
# Epoch [   11/  101] | d_loss: 0.1081 | g_loss: 5.1005
# Epoch [   11/  101] | d_loss: 0.0311 | g_loss: 5.0461
# Epoch [   11/  101] | d_loss: 0.5453 | g_loss: 4.8676
# Epoch [   11/  101] | d_loss: 0.0232 | g_loss: 3.9435
# Epoch [   11/  101] | d_loss: 0.0133 | g_loss: 4.5991
# View Samples
# Epoch [   12/  101] | d_loss: 0.1733 | g_loss: 3.0341
# Epoch [   12/  101] | d_loss: 0.0866 | g_loss: 4.4037
# Epoch [   12/  101] | d_loss: 0.1042 | g_loss: 4.7900
# Epoch [   12/  101] | d_loss: 0.0567 | g_loss: 5.4518
# Epoch [   12/  101] | d_loss: 0.8628 | g_loss: 8.7959
# Epoch [   12/  101] | d_loss: 0.1272 | g_loss: 5.1648
# Epoch [   12/  101] | d_loss: 0.0265 | g_loss: 4.1880
# Epoch [   12/  101] | d_loss: 0.0952 | g_loss: 2.5131
# Epoch [   12/  101] | d_loss: 0.0268 | g_loss: 7.9134
# Epoch [   13/  101] | d_loss: 0.0539 | g_loss: 4.5601
# Epoch [   13/  101] | d_loss: 2.0257 | g_loss: 7.8940
# Epoch [   13/  101] | d_loss: 0.1148 | g_loss: 5.9770
# Epoch [   13/  101] | d_loss: 0.3815 | g_loss: 4.2232
# Epoch [   13/  101] | d_loss: 0.0596 | g_loss: 7.3340
# Epoch [   13/  101] | d_loss: 0.2081 | g_loss: 4.7306
# Epoch [   13/  101] | d_loss: 0.2668 | g_loss: 3.6015
# Epoch [   13/  101] | d_loss: 0.0153 | g_loss: 2.2246
# Epoch [   13/  101] | d_loss: 0.2307 | g_loss: 3.6892
# Epoch [   14/  101] | d_loss: 0.1079 | g_loss: 5.0619
# Epoch [   14/  101] | d_loss: 0.0234 | g_loss: 6.3050
# Epoch [   14/  101] | d_loss: 0.0203 | g_loss: 6.7503
# Epoch [   14/  101] | d_loss: 0.1446 | g_loss: 3.9985
# Epoch [   14/  101] | d_loss: 0.2924 | g_loss: 3.9103
# Epoch [   14/  101] | d_loss: 0.0691 | g_loss: 5.0689
# Epoch [   14/  101] | d_loss: 0.0417 | g_loss: 3.3901
# Epoch [   14/  101] | d_loss: 0.0360 | g_loss: 6.3527
# Epoch [   14/  101] | d_loss: 0.2299 | g_loss: 8.3466
# Epoch [   15/  101] | d_loss: 0.2763 | g_loss: 4.9393
# Epoch [   15/  101] | d_loss: 0.2793 | g_loss: 5.8016
# Epoch [   15/  101] | d_loss: 0.0059 | g_loss: 7.6341
# Epoch [   15/  101] | d_loss: 0.0150 | g_loss: 6.2820
# Epoch [   15/  101] | d_loss: 0.5804 | g_loss: 7.2909
# Epoch [   15/  101] | d_loss: 0.2126 | g_loss: 2.1638
# Epoch [   15/  101] | d_loss: 0.0891 | g_loss: 5.7497
# Epoch [   15/  101] | d_loss: 0.4888 | g_loss: 9.2642
# Epoch [   15/  101] | d_loss: 0.3398 | g_loss: 6.7338
# Epoch [   16/  101] | d_loss: 0.8457 | g_loss: 9.2268
# Epoch [   16/  101] | d_loss: 0.3660 | g_loss: 4.7837
# Epoch [   16/  101] | d_loss: 0.1904 | g_loss: 3.5700
# Epoch [   16/  101] | d_loss: 0.2414 | g_loss: 7.1737
# Epoch [   16/  101] | d_loss: 0.0243 | g_loss: 4.0794
# Epoch [   16/  101] | d_loss: 0.0987 | g_loss: 6.4474
# Epoch [   16/  101] | d_loss: 0.0289 | g_loss: 8.3565
# Epoch [   16/  101] | d_loss: 0.0305 | g_loss: 8.4774
# Epoch [   16/  101] | d_loss: 0.0824 | g_loss: 6.2088
# Epoch [   17/  101] | d_loss: 0.0109 | g_loss: 4.5317
# Epoch [   17/  101] | d_loss: 0.0392 | g_loss: 7.5626
# Epoch [   17/  101] | d_loss: 0.2575 | g_loss: 2.7093
# Epoch [   17/  101] | d_loss: 0.0287 | g_loss: 6.6345
# Epoch [   17/  101] | d_loss: 0.2316 | g_loss: 3.4520
# Epoch [   17/  101] | d_loss: 0.6535 | g_loss: 2.0440
# Epoch [   17/  101] | d_loss: 0.0095 | g_loss: 4.8735
# Epoch [   17/  101] | d_loss: 0.1875 | g_loss: 4.4633
# Epoch [   17/  101] | d_loss: 0.0287 | g_loss: 3.1754
# Epoch [   18/  101] | d_loss: 0.0853 | g_loss: 6.3535
# Epoch [   18/  101] | d_loss: 4.0775 | g_loss: 1.4013
# Epoch [   18/  101] | d_loss: 0.1560 | g_loss: 3.4902
# Epoch [   18/  101] | d_loss: 0.0135 | g_loss: 3.6226
# Epoch [   18/  101] | d_loss: 0.1011 | g_loss: 4.7822
# Epoch [   18/  101] | d_loss: 0.0200 | g_loss: 5.2648
# Epoch [   18/  101] | d_loss: 0.0178 | g_loss: 3.7572
# Epoch [   18/  101] | d_loss: 0.0416 | g_loss: 6.3152
# Epoch [   18/  101] | d_loss: 0.0580 | g_loss: 6.3655
# Epoch [   19/  101] | d_loss: 0.0427 | g_loss: 5.3338
# Epoch [   19/  101] | d_loss: 0.2061 | g_loss: 9.8565
# Epoch [   19/  101] | d_loss: 0.0470 | g_loss: 4.1460
# Epoch [   19/  101] | d_loss: 0.2261 | g_loss: 5.2508
# Epoch [   19/  101] | d_loss: 0.0026 | g_loss: 5.3902
# Epoch [   19/  101] | d_loss: 0.0387 | g_loss: 7.2856
# Epoch [   19/  101] | d_loss: 0.0212 | g_loss: 6.2470
# Epoch [   19/  101] | d_loss: 0.2482 | g_loss: 6.1417
# Epoch [   19/  101] | d_loss: 0.0910 | g_loss: 3.0204
# Epoch [   20/  101] | d_loss: 0.1000 | g_loss: 3.2712
# Epoch [   20/  101] | d_loss: 0.0230 | g_loss: 4.2196
# Epoch [   20/  101] | d_loss: 0.0025 | g_loss: 4.6793
# Epoch [   20/  101] | d_loss: 0.0519 | g_loss: 4.8072
# Epoch [   20/  101] | d_loss: 0.0499 | g_loss: 2.2123
# Epoch [   20/  101] | d_loss: 0.0210 | g_loss: 7.0832
# Epoch [   20/  101] | d_loss: 0.0297 | g_loss: 6.5614
# Epoch [   20/  101] | d_loss: 0.7868 | g_loss: 9.8419
# Epoch [   20/  101] | d_loss: 0.1248 | g_loss: 7.9684
# Epoch [   21/  101] | d_loss: 0.0131 | g_loss: 5.0149
# Epoch [   21/  101] | d_loss: 0.0113 | g_loss: 1.4435
# Epoch [   21/  101] | d_loss: 0.0528 | g_loss: 2.9735
# Epoch [   21/  101] | d_loss: 0.2158 | g_loss: 8.5197
# Epoch [   21/  101] | d_loss: 0.3167 | g_loss: 5.1804
# Epoch [   21/  101] | d_loss: 0.0624 | g_loss: 6.9944
# Epoch [   21/  101] | d_loss: 0.0115 | g_loss: 5.1159
# Epoch [   21/  101] | d_loss: 0.0409 | g_loss: 6.4082
# Epoch [   21/  101] | d_loss: 0.1365 | g_loss: 2.9492
# View Samples
# Epoch [   22/  101] | d_loss: 0.0612 | g_loss: 3.1135
# Epoch [   22/  101] | d_loss: 0.1158 | g_loss: 4.1585
# Epoch [   22/  101] | d_loss: 4.4801 | g_loss: 14.6588
# Epoch [   22/  101] | d_loss: 0.7365 | g_loss: 1.7382
# Epoch [   22/  101] | d_loss: 0.0320 | g_loss: 3.1624
# Epoch [   22/  101] | d_loss: 0.0823 | g_loss: 4.5659
# Epoch [   22/  101] | d_loss: 0.2446 | g_loss: 2.7707
# Epoch [   22/  101] | d_loss: 0.0019 | g_loss: 7.5012
# Epoch [   22/  101] | d_loss: 0.2613 | g_loss: 7.6266
# Epoch [   23/  101] | d_loss: 0.0128 | g_loss: 9.2872
# Epoch [   23/  101] | d_loss: 0.0402 | g_loss: 6.4282
# Epoch [   23/  101] | d_loss: 0.0781 | g_loss: 7.2013
# Epoch [   23/  101] | d_loss: 0.0461 | g_loss: 7.4149
# Epoch [   23/  101] | d_loss: 0.0096 | g_loss: 4.6952
# Epoch [   23/  101] | d_loss: 0.1497 | g_loss: 9.7558
# Epoch [   23/  101] | d_loss: 0.1805 | g_loss: 6.1292
# Epoch [   23/  101] | d_loss: 0.0554 | g_loss: 8.6191
# Epoch [   23/  101] | d_loss: 0.0091 | g_loss: 5.8732
# Epoch [   24/  101] | d_loss: 0.0130 | g_loss: 5.9905
# Epoch [   24/  101] | d_loss: 0.4812 | g_loss: 4.0048
# Epoch [   24/  101] | d_loss: 0.0856 | g_loss: 4.6308
# Epoch [   24/  101] | d_loss: 0.0952 | g_loss: 4.0909
# Epoch [   24/  101] | d_loss: 0.0198 | g_loss: 5.6810
# Epoch [   24/  101] | d_loss: 0.1205 | g_loss: 8.0239
# Epoch [   24/  101] | d_loss: 0.0444 | g_loss: 8.5469
# Epoch [   24/  101] | d_loss: 0.0509 | g_loss: 4.0072
# Epoch [   24/  101] | d_loss: 0.1197 | g_loss: 6.0742
# Epoch [   25/  101] | d_loss: 0.0076 | g_loss: 8.5769
# Epoch [   25/  101] | d_loss: 0.6459 | g_loss: 8.7480
# Epoch [   25/  101] | d_loss: 0.0078 | g_loss: 4.4925
# Epoch [   25/  101] | d_loss: 0.1184 | g_loss: 4.5264
# Epoch [   25/  101] | d_loss: 0.0633 | g_loss: 4.9018
# Epoch [   25/  101] | d_loss: 0.3262 | g_loss: 6.6186
# Epoch [   25/  101] | d_loss: 0.0350 | g_loss: 5.3506
# Epoch [   25/  101] | d_loss: 0.0052 | g_loss: 5.2656
# Epoch [   25/  101] | d_loss: 0.1131 | g_loss: 6.2706
# Epoch [   26/  101] | d_loss: 0.0059 | g_loss: 6.4507
# Epoch [   26/  101] | d_loss: 0.0232 | g_loss: 9.0281
# Epoch [   26/  101] | d_loss: 0.0749 | g_loss: 6.5094
# Epoch [   26/  101] | d_loss: 0.0971 | g_loss: 6.7058
# Epoch [   26/  101] | d_loss: 0.0279 | g_loss: 3.9232
# Epoch [   26/  101] | d_loss: 0.2185 | g_loss: 4.9653
# Epoch [   26/  101] | d_loss: 0.1819 | g_loss: 5.6591
# Epoch [   26/  101] | d_loss: 0.0792 | g_loss: 4.5362
# Epoch [   26/  101] | d_loss: 0.3011 | g_loss: 8.7043
# Epoch [   27/  101] | d_loss: 0.1035 | g_loss: 4.6887
# Epoch [   27/  101] | d_loss: 0.2035 | g_loss: 8.9360
# Epoch [   27/  101] | d_loss: 0.0446 | g_loss: 3.0368
# Epoch [   27/  101] | d_loss: 0.1789 | g_loss: 7.4066
# Epoch [   27/  101] | d_loss: 0.4638 | g_loss: 7.4062
# Epoch [   27/  101] | d_loss: 0.0054 | g_loss: 4.6480
# Epoch [   27/  101] | d_loss: 0.4232 | g_loss: 9.1262
# Epoch [   27/  101] | d_loss: 0.0050 | g_loss: 4.6798
# Epoch [   27/  101] | d_loss: 0.0045 | g_loss: 3.6449
# Epoch [   28/  101] | d_loss: 0.0425 | g_loss: 8.3590
# Epoch [   28/  101] | d_loss: 0.0140 | g_loss: 7.1196
# Epoch [   28/  101] | d_loss: 0.0053 | g_loss: 9.1797
# Epoch [   28/  101] | d_loss: 0.0065 | g_loss: 6.1938
# Epoch [   28/  101] | d_loss: 0.0086 | g_loss: 7.7214
# Epoch [   28/  101] | d_loss: 0.0143 | g_loss: 3.6612
# Epoch [   28/  101] | d_loss: 0.0144 | g_loss: 2.9468
# Epoch [   28/  101] | d_loss: 0.0079 | g_loss: 6.5741
# Epoch [   28/  101] | d_loss: 0.0473 | g_loss: 4.6181
# Epoch [   29/  101] | d_loss: 0.0461 | g_loss: 8.1685
# Epoch [   29/  101] | d_loss: 0.0011 | g_loss: 7.4797
# Epoch [   29/  101] | d_loss: 0.0132 | g_loss: 7.0092
# Epoch [   29/  101] | d_loss: 0.0058 | g_loss: 9.0176
# Epoch [   29/  101] | d_loss: 0.0254 | g_loss: 8.5828
# Epoch [   29/  101] | d_loss: 0.0022 | g_loss: 7.7893
# Epoch [   29/  101] | d_loss: 0.0026 | g_loss: 9.7053
# Epoch [   29/  101] | d_loss: 0.0001 | g_loss: 7.1546
# Epoch [   29/  101] | d_loss: 0.0081 | g_loss: 9.8609
# Epoch [   30/  101] | d_loss: 0.0242 | g_loss: 8.5308
# Epoch [   30/  101] | d_loss: 0.0050 | g_loss: 7.5520
# Epoch [   30/  101] | d_loss: 0.2197 | g_loss: 4.0161
# Epoch [   30/  101] | d_loss: 3.5716 | g_loss: 1.9672
# Epoch [   30/  101] | d_loss: 0.0902 | g_loss: 6.3641
# Epoch [   30/  101] | d_loss: 0.0975 | g_loss: 5.5912
# Epoch [   30/  101] | d_loss: 0.0329 | g_loss: 6.2510
# Epoch [   30/  101] | d_loss: 0.0058 | g_loss: 8.7671
# Epoch [   30/  101] | d_loss: 0.0530 | g_loss: 4.9696
# Epoch [   31/  101] | d_loss: 0.1335 | g_loss: 3.9422
# Epoch [   31/  101] | d_loss: 1.8240 | g_loss: 9.9013
# Epoch [   31/  101] | d_loss: 0.5931 | g_loss: 10.4858
# Epoch [   31/  101] | d_loss: 0.0244 | g_loss: 8.0225
# Epoch [   31/  101] | d_loss: 0.0286 | g_loss: 7.6812
# Epoch [   31/  101] | d_loss: 0.0539 | g_loss: 5.2058
# Epoch [   31/  101] | d_loss: 0.1039 | g_loss: 6.4375
# Epoch [   31/  101] | d_loss: 0.0191 | g_loss: 5.3158
# Epoch [   31/  101] | d_loss: 0.0962 | g_loss: 8.5561
# View Samples
# Epoch [   32/  101] | d_loss: 0.0290 | g_loss: 6.3310
# Epoch [   32/  101] | d_loss: 0.1674 | g_loss: 3.8832
# Epoch [   32/  101] | d_loss: 0.0430 | g_loss: 5.5764
# Epoch [   32/  101] | d_loss: 0.4638 | g_loss: 7.6997
# Epoch [   32/  101] | d_loss: 0.0314 | g_loss: 8.6459
# Epoch [   32/  101] | d_loss: 0.0708 | g_loss: 10.8293
# Epoch [   32/  101] | d_loss: 0.0119 | g_loss: 7.1029
# Epoch [   32/  101] | d_loss: 0.0142 | g_loss: 3.5019
# Epoch [   32/  101] | d_loss: 0.0113 | g_loss: 8.8861
# Epoch [   33/  101] | d_loss: 0.0492 | g_loss: 5.1062
# Epoch [   33/  101] | d_loss: 2.7958 | g_loss: 13.4320
# Epoch [   33/  101] | d_loss: 0.0827 | g_loss: 2.6313
# Epoch [   33/  101] | d_loss: 0.0673 | g_loss: 8.6211
# Epoch [   33/  101] | d_loss: 0.0235 | g_loss: 4.3714
# Epoch [   33/  101] | d_loss: 0.0202 | g_loss: 6.7946
# Epoch [   33/  101] | d_loss: 1.4834 | g_loss: 1.2634
# Epoch [   33/  101] | d_loss: 0.0306 | g_loss: 7.2814
# Epoch [   33/  101] | d_loss: 0.0398 | g_loss: 6.3911
# Epoch [   34/  101] | d_loss: 0.0168 | g_loss: 9.5267
# Epoch [   34/  101] | d_loss: 0.0990 | g_loss: 7.0177
# Epoch [   34/  101] | d_loss: 0.1993 | g_loss: 6.3378
# Epoch [   34/  101] | d_loss: 0.0019 | g_loss: 6.8008
# Epoch [   34/  101] | d_loss: 0.9577 | g_loss: 0.7146
# Epoch [   34/  101] | d_loss: 0.3334 | g_loss: 4.6030
# Epoch [   34/  101] | d_loss: 0.0177 | g_loss: 2.1478
# Epoch [   34/  101] | d_loss: 0.0275 | g_loss: 8.5355
# Epoch [   34/  101] | d_loss: 0.0496 | g_loss: 6.7056
# Epoch [   35/  101] | d_loss: 0.0257 | g_loss: 6.8013
# Epoch [   35/  101] | d_loss: 0.0039 | g_loss: 10.5815
# Epoch [   35/  101] | d_loss: 0.0036 | g_loss: 4.9484
# Epoch [   35/  101] | d_loss: 0.0062 | g_loss: 5.4403
# Epoch [   35/  101] | d_loss: 0.0045 | g_loss: 10.4320
# Epoch [   35/  101] | d_loss: 0.0006 | g_loss: 5.0040
# Epoch [   35/  101] | d_loss: 0.0948 | g_loss: 7.3036
# Epoch [   35/  101] | d_loss: 0.0006 | g_loss: 7.4137
# Epoch [   35/  101] | d_loss: 0.1218 | g_loss: 4.8326
# Epoch [   36/  101] | d_loss: 0.1641 | g_loss: 2.6765
# Epoch [   36/  101] | d_loss: 0.0128 | g_loss: 5.7134
# Epoch [   36/  101] | d_loss: 0.0052 | g_loss: 5.7272
# Epoch [   36/  101] | d_loss: 0.0012 | g_loss: 9.1825
# Epoch [   36/  101] | d_loss: 0.0302 | g_loss: 5.4753
# Epoch [   36/  101] | d_loss: 0.0211 | g_loss: 7.7859
# Epoch [   36/  101] | d_loss: 0.0385 | g_loss: 6.0178
# Epoch [   36/  101] | d_loss: 0.0979 | g_loss: 4.1993
# Epoch [   36/  101] | d_loss: 0.0479 | g_loss: 6.2144
# Epoch [   37/  101] | d_loss: 0.0015 | g_loss: 5.9523
# Epoch [   37/  101] | d_loss: 0.0208 | g_loss: 4.9492
# Epoch [   37/  101] | d_loss: 0.1286 | g_loss: 5.7960
# Epoch [   37/  101] | d_loss: 0.0908 | g_loss: 7.1882
# Epoch [   37/  101] | d_loss: 0.0276 | g_loss: 5.2128
# Epoch [   37/  101] | d_loss: 0.3696 | g_loss: 4.8073
# Epoch [   37/  101] | d_loss: 0.0397 | g_loss: 8.1186
# Epoch [   37/  101] | d_loss: 0.0137 | g_loss: 4.8495
# Epoch [   37/  101] | d_loss: 0.3111 | g_loss: 9.2187
# Epoch [   38/  101] | d_loss: 0.0373 | g_loss: 7.4699
# Epoch [   38/  101] | d_loss: 0.0296 | g_loss: 6.2649
# Epoch [   38/  101] | d_loss: 0.0058 | g_loss: 8.8390
# Epoch [   38/  101] | d_loss: 0.0368 | g_loss: 9.3763
# Epoch [   38/  101] | d_loss: 0.0176 | g_loss: 5.9536
# Epoch [   38/  101] | d_loss: 0.0714 | g_loss: 6.7252
# Epoch [   38/  101] | d_loss: 0.0211 | g_loss: 10.0296
# Epoch [   38/  101] | d_loss: 0.0529 | g_loss: 4.9178
# Epoch [   38/  101] | d_loss: 0.4914 | g_loss: 8.8331
# Epoch [   39/  101] | d_loss: 0.0136 | g_loss: 9.9443
# Epoch [   39/  101] | d_loss: 0.2573 | g_loss: 4.0217
# Epoch [   39/  101] | d_loss: 0.1706 | g_loss: 3.8912
# Epoch [   39/  101] | d_loss: 0.0989 | g_loss: 7.2793
# Epoch [   39/  101] | d_loss: 0.0207 | g_loss: 8.1318
# Epoch [   39/  101] | d_loss: 0.0133 | g_loss: 7.6361
# Epoch [   39/  101] | d_loss: 0.0161 | g_loss: 8.5589
# Epoch [   39/  101] | d_loss: 0.0042 | g_loss: 6.0136
# Epoch [   39/  101] | d_loss: 0.0656 | g_loss: 6.0270
# Epoch [   40/  101] | d_loss: 0.0576 | g_loss: 7.7397
# Epoch [   40/  101] | d_loss: 0.0189 | g_loss: 5.8445
# Epoch [   40/  101] | d_loss: 0.0071 | g_loss: 6.0836
# Epoch [   40/  101] | d_loss: 0.0241 | g_loss: 7.0253
# Epoch [   40/  101] | d_loss: 0.0070 | g_loss: 9.2916
# Epoch [   40/  101] | d_loss: 0.0030 | g_loss: 6.3471
# Epoch [   40/  101] | d_loss: 0.0160 | g_loss: 9.1330
# Epoch [   40/  101] | d_loss: 0.0682 | g_loss: 6.8740
# Epoch [   40/  101] | d_loss: 0.0327 | g_loss: 5.1102
# Epoch [   41/  101] | d_loss: 0.0029 | g_loss: 7.6842
# Epoch [   41/  101] | d_loss: 0.1225 | g_loss: 5.3507
# Epoch [   41/  101] | d_loss: 0.1296 | g_loss: 7.7747
# Epoch [   41/  101] | d_loss: 0.6628 | g_loss: 0.3451
# Epoch [   41/  101] | d_loss: 0.0653 | g_loss: 5.8746
# Epoch [   41/  101] | d_loss: 0.0231 | g_loss: 4.6665
# Epoch [   41/  101] | d_loss: 0.1735 | g_loss: 3.6784
# Epoch [   41/  101] | d_loss: 0.0010 | g_loss: 5.6826
# Epoch [   41/  101] | d_loss: 0.0545 | g_loss: 5.0314
# View Samples
# Epoch [   42/  101] | d_loss: 0.0056 | g_loss: 10.4905
# Epoch [   42/  101] | d_loss: 0.0168 | g_loss: 3.1151
# Epoch [   42/  101] | d_loss: 0.0125 | g_loss: 2.7829
# Epoch [   42/  101] | d_loss: 0.0194 | g_loss: 6.5270
# Epoch [   42/  101] | d_loss: 0.1697 | g_loss: 6.9539
# Epoch [   42/  101] | d_loss: 0.1350 | g_loss: 6.9840
# Epoch [   42/  101] | d_loss: 0.0055 | g_loss: 10.2894
# Epoch [   42/  101] | d_loss: 0.0273 | g_loss: 6.9618
# Epoch [   42/  101] | d_loss: 0.1243 | g_loss: 9.1613
# Epoch [   43/  101] | d_loss: 0.0003 | g_loss: 9.0798
# Epoch [   43/  101] | d_loss: 0.0040 | g_loss: 5.2469
# Epoch [   43/  101] | d_loss: 4.7150 | g_loss: 11.5280
# Epoch [   43/  101] | d_loss: 0.2512 | g_loss: 5.3619
# Epoch [   43/  101] | d_loss: 0.0691 | g_loss: 6.5164
# Epoch [   43/  101] | d_loss: 0.0764 | g_loss: 6.5209
# Epoch [   43/  101] | d_loss: 0.0008 | g_loss: 6.6888
# Epoch [   43/  101] | d_loss: 0.0135 | g_loss: 9.1980
# Epoch [   43/  101] | d_loss: 0.0182 | g_loss: 3.5847
# Epoch [   44/  101] | d_loss: 0.0253 | g_loss: 3.0619
# Epoch [   44/  101] | d_loss: 0.0015 | g_loss: 7.6629
# Epoch [   44/  101] | d_loss: 0.0036 | g_loss: 5.4853
# Epoch [   44/  101] | d_loss: 0.0153 | g_loss: 3.9628
# Epoch [   44/  101] | d_loss: 0.0237 | g_loss: 10.8243
# Epoch [   44/  101] | d_loss: 0.0569 | g_loss: 13.4945
# Epoch [   44/  101] | d_loss: 0.0063 | g_loss: 6.9390
# Epoch [   44/  101] | d_loss: 0.0604 | g_loss: 6.5154
# Epoch [   44/  101] | d_loss: 0.0270 | g_loss: 8.7060
# Epoch [   45/  101] | d_loss: 0.0751 | g_loss: 5.3182
# Epoch [   45/  101] | d_loss: 0.0735 | g_loss: 5.8229
# Epoch [   45/  101] | d_loss: 0.0515 | g_loss: 6.5149
# Epoch [   45/  101] | d_loss: 0.0152 | g_loss: 9.5265
# Epoch [   45/  101] | d_loss: 0.0202 | g_loss: 7.2379
# Epoch [   45/  101] | d_loss: 0.3631 | g_loss: 14.7470
# Epoch [   45/  101] | d_loss: 0.0556 | g_loss: 6.9749
# Epoch [   45/  101] | d_loss: 0.1579 | g_loss: 7.7360
# Epoch [   45/  101] | d_loss: 0.0117 | g_loss: 8.7371
# Epoch [   46/  101] | d_loss: 0.1782 | g_loss: 5.0414
# Epoch [   46/  101] | d_loss: 0.0067 | g_loss: 7.3474
# Epoch [   46/  101] | d_loss: 0.0278 | g_loss: 5.4538
# Epoch [   46/  101] | d_loss: 0.0032 | g_loss: 7.7144
# Epoch [   46/  101] | d_loss: 0.0196 | g_loss: 2.7791
# Epoch [   46/  101] | d_loss: 0.0230 | g_loss: 12.3531
# Epoch [   46/  101] | d_loss: 0.0115 | g_loss: 7.9381
# Epoch [   46/  101] | d_loss: 0.3364 | g_loss: 14.4377
# Epoch [   46/  101] | d_loss: 0.0534 | g_loss: 4.2086
# Epoch [   47/  101] | d_loss: 0.0052 | g_loss: 7.7853
# Epoch [   47/  101] | d_loss: 0.1232 | g_loss: 11.5573
# Epoch [   47/  101] | d_loss: 0.2195 | g_loss: 12.2218
# Epoch [   47/  101] | d_loss: 0.2769 | g_loss: 11.1156
# Epoch [   47/  101] | d_loss: 0.0069 | g_loss: 5.5055
# Epoch [   47/  101] | d_loss: 0.0224 | g_loss: 6.9900
# Epoch [   47/  101] | d_loss: 0.0370 | g_loss: 6.4535
# Epoch [   47/  101] | d_loss: 0.1873 | g_loss: 10.4544
# Epoch [   47/  101] | d_loss: 0.0008 | g_loss: 7.7921
# Epoch [   48/  101] | d_loss: 0.0341 | g_loss: 6.8072
# Epoch [   48/  101] | d_loss: 0.0280 | g_loss: 7.1643
# Epoch [   48/  101] | d_loss: 0.0671 | g_loss: 9.3200
# Epoch [   48/  101] | d_loss: 0.4540 | g_loss: 10.8086
# Epoch [   48/  101] | d_loss: 0.0192 | g_loss: 9.7532
# Epoch [   48/  101] | d_loss: 0.0043 | g_loss: 8.4084
# Epoch [   48/  101] | d_loss: 0.0639 | g_loss: 7.0384
# Epoch [   48/  101] | d_loss: 0.0017 | g_loss: 5.9985
# Epoch [   48/  101] | d_loss: 1.6226 | g_loss: 3.4272
# Epoch [   49/  101] | d_loss: 6.4879 | g_loss: 7.1468
# Epoch [   49/  101] | d_loss: 0.0027 | g_loss: 10.9692
# Epoch [   49/  101] | d_loss: 0.0050 | g_loss: 4.7462
# Epoch [   49/  101] | d_loss: 0.0049 | g_loss: 9.7174
# Epoch [   49/  101] | d_loss: 0.0360 | g_loss: 10.2964
# Epoch [   49/  101] | d_loss: 0.0745 | g_loss: 5.2123
# Epoch [   49/  101] | d_loss: 0.0016 | g_loss: 7.2534
# Epoch [   49/  101] | d_loss: 0.0565 | g_loss: 9.4760
# Epoch [   49/  101] | d_loss: 0.0875 | g_loss: 3.9261
# Epoch [   50/  101] | d_loss: 0.0250 | g_loss: 7.0178
# Epoch [   50/  101] | d_loss: 0.0183 | g_loss: 9.1563
# Epoch [   50/  101] | d_loss: 0.0120 | g_loss: 8.0078
# Epoch [   50/  101] | d_loss: 0.0566 | g_loss: 10.9983
# Epoch [   50/  101] | d_loss: 0.1330 | g_loss: 2.9277
# Epoch [   50/  101] | d_loss: 0.0401 | g_loss: 2.9344
# Epoch [   50/  101] | d_loss: 0.0087 | g_loss: 4.8202
# Epoch [   50/  101] | d_loss: 0.0025 | g_loss: 4.4518
# Epoch [   50/  101] | d_loss: 0.0541 | g_loss: 8.6771
# Epoch [   51/  101] | d_loss: 0.0034 | g_loss: 6.7928
# Epoch [   51/  101] | d_loss: 0.0167 | g_loss: 9.7321
# Epoch [   51/  101] | d_loss: 0.0008 | g_loss: 6.9135
# Epoch [   51/  101] | d_loss: 0.0033 | g_loss: 5.0795
# Epoch [   51/  101] | d_loss: 0.2141 | g_loss: 11.5172
# Epoch [   51/  101] | d_loss: 0.0019 | g_loss: 5.6742
# Epoch [   51/  101] | d_loss: 0.0043 | g_loss: 8.2277
# Epoch [   51/  101] | d_loss: 0.0179 | g_loss: 10.3607
# Epoch [   51/  101] | d_loss: 0.0033 | g_loss: 9.1081
# View Samples
# Epoch [   52/  101] | d_loss: 0.0208 | g_loss: 12.2540
# Epoch [   52/  101] | d_loss: 0.8175 | g_loss: 12.4413
# Epoch [   52/  101] | d_loss: 0.0151 | g_loss: 4.4000
# Epoch [   52/  101] | d_loss: 0.2486 | g_loss: 5.5773
# Epoch [   52/  101] | d_loss: 0.2896 | g_loss: 9.3086
# Epoch [   52/  101] | d_loss: 0.0215 | g_loss: 9.2102
# Epoch [   52/  101] | d_loss: 0.0276 | g_loss: 7.6783
# Epoch [   52/  101] | d_loss: 0.0008 | g_loss: 10.7008
# Epoch [   52/  101] | d_loss: 0.0397 | g_loss: 6.5938
# Epoch [   53/  101] | d_loss: 0.0321 | g_loss: 6.2618
# Epoch [   53/  101] | d_loss: 0.3974 | g_loss: 5.0018
# Epoch [   53/  101] | d_loss: 0.0215 | g_loss: 10.2192
# Epoch [   53/  101] | d_loss: 0.0026 | g_loss: 6.9771
# Epoch [   53/  101] | d_loss: 0.0113 | g_loss: 10.1373
# Epoch [   53/  101] | d_loss: 0.0127 | g_loss: 8.5943
# Epoch [   53/  101] | d_loss: 2.8864 | g_loss: 12.1478
# Epoch [   53/  101] | d_loss: 0.0116 | g_loss: 8.4684
# Epoch [   53/  101] | d_loss: 0.0142 | g_loss: 12.2052
# Epoch [   54/  101] | d_loss: 0.1997 | g_loss: 8.1994
# Epoch [   54/  101] | d_loss: 0.0421 | g_loss: 6.8731
# Epoch [   54/  101] | d_loss: 0.0040 | g_loss: 10.5234
# Epoch [   54/  101] | d_loss: 0.0231 | g_loss: 6.6104
# Epoch [   54/  101] | d_loss: 0.0208 | g_loss: 4.5402
# Epoch [   54/  101] | d_loss: 0.0107 | g_loss: 6.8503
# Epoch [   54/  101] | d_loss: 0.0017 | g_loss: 8.1914
# Epoch [   54/  101] | d_loss: 0.0045 | g_loss: 9.5224
# Epoch [   54/  101] | d_loss: 0.0074 | g_loss: 12.7366
# Epoch [   55/  101] | d_loss: 0.1489 | g_loss: 10.5341
# Epoch [   55/  101] | d_loss: 0.4349 | g_loss: 1.9015
# Epoch [   55/  101] | d_loss: 0.0562 | g_loss: 5.2426
# Epoch [   55/  101] | d_loss: 0.0030 | g_loss: 11.3933
# Epoch [   55/  101] | d_loss: 0.0050 | g_loss: 7.5106
# Epoch [   55/  101] | d_loss: 0.0014 | g_loss: 11.0564
# Epoch [   55/  101] | d_loss: 0.0643 | g_loss: 7.4142
# Epoch [   55/  101] | d_loss: 0.0043 | g_loss: 10.1203
# Epoch [   55/  101] | d_loss: 0.0033 | g_loss: 7.9494
# Epoch [   56/  101] | d_loss: 0.0048 | g_loss: 7.8722
# Epoch [   56/  101] | d_loss: 0.2209 | g_loss: 2.2816
# Epoch [   56/  101] | d_loss: 0.1953 | g_loss: 11.1873
# Epoch [   56/  101] | d_loss: 0.0510 | g_loss: 6.0129
# Epoch [   56/  101] | d_loss: 0.0017 | g_loss: 6.6843
# Epoch [   56/  101] | d_loss: 0.0178 | g_loss: 8.2968
# Epoch [   56/  101] | d_loss: 0.0143 | g_loss: 6.1362
# Epoch [   56/  101] | d_loss: 0.0825 | g_loss: 6.3131
# Epoch [   56/  101] | d_loss: 0.0181 | g_loss: 8.6560
# Epoch [   57/  101] | d_loss: 0.0271 | g_loss: 7.0270
# Epoch [   57/  101] | d_loss: 0.0028 | g_loss: 7.2635
# Epoch [   57/  101] | d_loss: 0.0021 | g_loss: 4.8364
# Epoch [   57/  101] | d_loss: 0.0042 | g_loss: 6.5301
# Epoch [   57/  101] | d_loss: 0.0030 | g_loss: 8.2823
# Epoch [   57/  101] | d_loss: 0.0890 | g_loss: 5.2900
# Epoch [   57/  101] | d_loss: 0.0317 | g_loss: 7.0947
# Epoch [   57/  101] | d_loss: 0.0031 | g_loss: 4.7358
# Epoch [   57/  101] | d_loss: 0.0149 | g_loss: 6.2177
# Epoch [   58/  101] | d_loss: 0.0231 | g_loss: 9.5621
# Epoch [   58/  101] | d_loss: 0.0271 | g_loss: 12.9777
# Epoch [   58/  101] | d_loss: 0.0762 | g_loss: 11.3713
# Epoch [   58/  101] | d_loss: 0.0061 | g_loss: 5.1792
# Epoch [   58/  101] | d_loss: 0.0843 | g_loss: 8.8381
# Epoch [   58/  101] | d_loss: 0.0007 | g_loss: 9.8139
# Epoch [   58/  101] | d_loss: 0.0021 | g_loss: 5.0505
# Epoch [   58/  101] | d_loss: 0.0087 | g_loss: 9.3321
# Epoch [   58/  101] | d_loss: 0.0176 | g_loss: 7.0932
# Epoch [   59/  101] | d_loss: 0.1689 | g_loss: 4.6895
# Epoch [   59/  101] | d_loss: 0.0240 | g_loss: 9.0816
# Epoch [   59/  101] | d_loss: 0.0414 | g_loss: 5.7722
# Epoch [   59/  101] | d_loss: 0.1008 | g_loss: 9.5769
# Epoch [   59/  101] | d_loss: 0.0135 | g_loss: 3.5516
# Epoch [   59/  101] | d_loss: 0.0122 | g_loss: 6.2265
# Epoch [   59/  101] | d_loss: 0.0114 | g_loss: 10.7445
# Epoch [   59/  101] | d_loss: 0.1576 | g_loss: 5.0266
# Epoch [   59/  101] | d_loss: 0.0352 | g_loss: 6.9253
# Epoch [   60/  101] | d_loss: 0.0031 | g_loss: 11.8576
# Epoch [   60/  101] | d_loss: 0.0135 | g_loss: 7.9991
# Epoch [   60/  101] | d_loss: 0.0710 | g_loss: 10.9330
# Epoch [   60/  101] | d_loss: 0.0010 | g_loss: 7.7172
# Epoch [   60/  101] | d_loss: 0.0053 | g_loss: 5.7301
# Epoch [   60/  101] | d_loss: 0.0040 | g_loss: 10.3619
# Epoch [   60/  101] | d_loss: 0.0069 | g_loss: 7.6102
# Epoch [   60/  101] | d_loss: 0.0003 | g_loss: 11.8354
# Epoch [   60/  101] | d_loss: 0.0332 | g_loss: 12.5418
# Epoch [   61/  101] | d_loss: 0.0002 | g_loss: 6.5180
# Epoch [   61/  101] | d_loss: 0.0036 | g_loss: 4.8149
# Epoch [   61/  101] | d_loss: 1.4097 | g_loss: 0.1861
# Epoch [   61/  101] | d_loss: 0.1269 | g_loss: 5.8570
# Epoch [   61/  101] | d_loss: 0.0575 | g_loss: 8.6739
# Epoch [   61/  101] | d_loss: 0.0625 | g_loss: 8.4726
# Epoch [   61/  101] | d_loss: 0.0035 | g_loss: 2.4837
# Epoch [   61/  101] | d_loss: 0.0009 | g_loss: 6.0091
# Epoch [   61/  101] | d_loss: 0.0248 | g_loss: 6.6073
# View Samples
# Epoch [   62/  101] | d_loss: 0.3474 | g_loss: 3.2699
# Epoch [   62/  101] | d_loss: 0.1092 | g_loss: 10.7298
# Epoch [   62/  101] | d_loss: 0.0003 | g_loss: 11.9971
# Epoch [   62/  101] | d_loss: 0.0012 | g_loss: 6.3652
# Epoch [   62/  101] | d_loss: 0.0007 | g_loss: 5.7229
# Epoch [   62/  101] | d_loss: 0.4067 | g_loss: 9.4788
# Epoch [   62/  101] | d_loss: 0.0001 | g_loss: 7.3840
# Epoch [   62/  101] | d_loss: 0.0042 | g_loss: 6.2184
# Epoch [   62/  101] | d_loss: 0.0018 | g_loss: 6.2877
# Epoch [   63/  101] | d_loss: 0.0463 | g_loss: 3.0290
# Epoch [   63/  101] | d_loss: 0.0042 | g_loss: 7.6328
# Epoch [   63/  101] | d_loss: 0.0737 | g_loss: 9.6336
# Epoch [   63/  101] | d_loss: 0.0015 | g_loss: 7.5592
# Epoch [   63/  101] | d_loss: 0.0869 | g_loss: 9.0599
# Epoch [   63/  101] | d_loss: 0.1753 | g_loss: 9.9734
# Epoch [   63/  101] | d_loss: 0.0023 | g_loss: 12.1808
# Epoch [   63/  101] | d_loss: 0.0007 | g_loss: 9.3349
# Epoch [   63/  101] | d_loss: 0.0039 | g_loss: 10.4681
# Epoch [   64/  101] | d_loss: 0.0020 | g_loss: 7.5364
# Epoch [   64/  101] | d_loss: 0.0007 | g_loss: 7.5452
# Epoch [   64/  101] | d_loss: 0.0088 | g_loss: 9.3011
# Epoch [   64/  101] | d_loss: 0.0019 | g_loss: 6.6468
# Epoch [   64/  101] | d_loss: 0.0023 | g_loss: 10.9018
# Epoch [   64/  101] | d_loss: 0.0422 | g_loss: 9.0380
# Epoch [   64/  101] | d_loss: 0.0034 | g_loss: 6.0211
# Epoch [   64/  101] | d_loss: 0.0116 | g_loss: 9.8184
# Epoch [   64/  101] | d_loss: 0.0005 | g_loss: 6.1617
# Epoch [   65/  101] | d_loss: 0.0425 | g_loss: 8.4726
# Epoch [   65/  101] | d_loss: 0.0220 | g_loss: 7.5626
# Epoch [   65/  101] | d_loss: 0.0146 | g_loss: 5.3508
# Epoch [   65/  101] | d_loss: 0.2348 | g_loss: 5.6148
# Epoch [   65/  101] | d_loss: 0.0047 | g_loss: 6.1569
# Epoch [   65/  101] | d_loss: 0.0510 | g_loss: 4.6087
# Epoch [   65/  101] | d_loss: 1.4752 | g_loss: 17.9487
# Epoch [   65/  101] | d_loss: 0.2162 | g_loss: 9.2594
# Epoch [   65/  101] | d_loss: 0.0067 | g_loss: 3.9190
# Epoch [   66/  101] | d_loss: 0.2112 | g_loss: 4.6069
# Epoch [   66/  101] | d_loss: 0.0573 | g_loss: 8.9943
# Epoch [   66/  101] | d_loss: 0.0005 | g_loss: 5.7181
# Epoch [   66/  101] | d_loss: 0.1001 | g_loss: 6.3240
# Epoch [   66/  101] | d_loss: 0.0151 | g_loss: 5.7414
# Epoch [   66/  101] | d_loss: 0.0704 | g_loss: 9.4502
# Epoch [   66/  101] | d_loss: 0.0928 | g_loss: 8.0030
# Epoch [   66/  101] | d_loss: 0.0082 | g_loss: 10.7965
# Epoch [   66/  101] | d_loss: 0.0020 | g_loss: 7.8197
# Epoch [   67/  101] | d_loss: 0.6630 | g_loss: 2.1209
# Epoch [   67/  101] | d_loss: 0.2080 | g_loss: 4.3489
# Epoch [   67/  101] | d_loss: 0.0029 | g_loss: 9.1898
# Epoch [   67/  101] | d_loss: 0.0378 | g_loss: 8.5841
# Epoch [   67/  101] | d_loss: 0.0046 | g_loss: 5.4728
# Epoch [   67/  101] | d_loss: 0.0204 | g_loss: 5.7765
# Epoch [   67/  101] | d_loss: 0.0386 | g_loss: 10.3456
# Epoch [   67/  101] | d_loss: 0.0175 | g_loss: 4.4234
# Epoch [   67/  101] | d_loss: 0.0004 | g_loss: 8.9038
# Epoch [   68/  101] | d_loss: 0.0154 | g_loss: 9.3488
# Epoch [   68/  101] | d_loss: 0.0051 | g_loss: 9.4049
# Epoch [   68/  101] | d_loss: 0.0311 | g_loss: 9.3167
# Epoch [   68/  101] | d_loss: 0.0049 | g_loss: 14.6249
# Epoch [   68/  101] | d_loss: 0.0240 | g_loss: 8.5442
# Epoch [   68/  101] | d_loss: 0.3269 | g_loss: 1.2127
# Epoch [   68/  101] | d_loss: 0.0025 | g_loss: 11.0945
# Epoch [   68/  101] | d_loss: 0.0076 | g_loss: 4.2359
# Epoch [   68/  101] | d_loss: 0.0034 | g_loss: 7.9529
# Epoch [   69/  101] | d_loss: 0.0096 | g_loss: 9.8976
# Epoch [   69/  101] | d_loss: 0.6681 | g_loss: 2.4576
# Epoch [   69/  101] | d_loss: 0.0020 | g_loss: 7.5894
# Epoch [   69/  101] | d_loss: 0.0013 | g_loss: 8.4550
# Epoch [   69/  101] | d_loss: 1.3920 | g_loss: 0.3001
# Epoch [   69/  101] | d_loss: 0.0003 | g_loss: 7.9257
# Epoch [   69/  101] | d_loss: 0.0198 | g_loss: 5.7782
# Epoch [   69/  101] | d_loss: 0.1299 | g_loss: 5.9431
# Epoch [   69/  101] | d_loss: 0.0060 | g_loss: 7.9744
# Epoch [   70/  101] | d_loss: 0.0160 | g_loss: 7.6908
# Epoch [   70/  101] | d_loss: 0.0976 | g_loss: 13.5245
# Epoch [   70/  101] | d_loss: 0.0279 | g_loss: 6.1347
# Epoch [   70/  101] | d_loss: 0.0015 | g_loss: 11.2728
# Epoch [   70/  101] | d_loss: 0.0066 | g_loss: 8.2680
# Epoch [   70/  101] | d_loss: 0.0165 | g_loss: 9.9511
# Epoch [   70/  101] | d_loss: 0.3547 | g_loss: 7.6930
# Epoch [   70/  101] | d_loss: 0.2235 | g_loss: 15.8829
# Epoch [   70/  101] | d_loss: 0.0003 | g_loss: 7.1147
# Epoch [   71/  101] | d_loss: 0.0031 | g_loss: 10.3227
# Epoch [   71/  101] | d_loss: 0.0004 | g_loss: 12.8701
# Epoch [   71/  101] | d_loss: 0.0015 | g_loss: 10.4510
# Epoch [   71/  101] | d_loss: 0.3065 | g_loss: 17.9973
# Epoch [   71/  101] | d_loss: 0.0006 | g_loss: 7.4925
# Epoch [   71/  101] | d_loss: 0.0005 | g_loss: 13.6675
# Epoch [   71/  101] | d_loss: 0.0226 | g_loss: 9.9823
# Epoch [   71/  101] | d_loss: 0.0174 | g_loss: 11.8780
# Epoch [   71/  101] | d_loss: 0.0001 | g_loss: 7.7625
# View Samples
# Epoch [   72/  101] | d_loss: 0.0427 | g_loss: 6.9809
# Epoch [   72/  101] | d_loss: 0.0010 | g_loss: 8.2452
# Epoch [   72/  101] | d_loss: 0.0036 | g_loss: 14.6186
# Epoch [   72/  101] | d_loss: 0.0054 | g_loss: 11.5078
# Epoch [   72/  101] | d_loss: 0.0016 | g_loss: 10.0318
# Epoch [   72/  101] | d_loss: 0.0001 | g_loss: 7.3802
# Epoch [   72/  101] | d_loss: 0.0003 | g_loss: 10.1071
# Epoch [   72/  101] | d_loss: 1.1093 | g_loss: 20.4732
# Epoch [   72/  101] | d_loss: 0.0386 | g_loss: 3.1995
# Epoch [   73/  101] | d_loss: 0.9747 | g_loss: 9.0550
# Epoch [   73/  101] | d_loss: 0.0230 | g_loss: 7.0745
# Epoch [   73/  101] | d_loss: 0.2083 | g_loss: 12.7319
# Epoch [   73/  101] | d_loss: 0.0009 | g_loss: 6.1590
# Epoch [   73/  101] | d_loss: 0.0101 | g_loss: 5.9652
# Epoch [   73/  101] | d_loss: 0.0030 | g_loss: 7.1966
# Epoch [   73/  101] | d_loss: 0.0091 | g_loss: 8.2685
# Epoch [   73/  101] | d_loss: 0.0481 | g_loss: 9.2580
# Epoch [   73/  101] | d_loss: 0.0045 | g_loss: 6.3465
# Epoch [   74/  101] | d_loss: 1.1454 | g_loss: 15.6433
# Epoch [   74/  101] | d_loss: 0.0035 | g_loss: 8.0542
# Epoch [   74/  101] | d_loss: 0.0004 | g_loss: 9.1394
# Epoch [   74/  101] | d_loss: 0.0070 | g_loss: 9.0998
# Epoch [   74/  101] | d_loss: 0.0088 | g_loss: 11.1210
# Epoch [   74/  101] | d_loss: 0.0789 | g_loss: 15.6779
# Epoch [   74/  101] | d_loss: 0.0092 | g_loss: 6.9564
# Epoch [   74/  101] | d_loss: 0.0811 | g_loss: 8.7299
# Epoch [   74/  101] | d_loss: 0.0004 | g_loss: 9.0688
# Epoch [   75/  101] | d_loss: 0.0138 | g_loss: 7.2170
# Epoch [   75/  101] | d_loss: 0.0039 | g_loss: 9.7126
# Epoch [   75/  101] | d_loss: 0.0063 | g_loss: 7.5184
# Epoch [   75/  101] | d_loss: 0.0004 | g_loss: 14.3970
# Epoch [   75/  101] | d_loss: 0.0291 | g_loss: 3.6624
# Epoch [   75/  101] | d_loss: 0.0084 | g_loss: 5.4943
# Epoch [   75/  101] | d_loss: 0.0025 | g_loss: 7.6753
# Epoch [   75/  101] | d_loss: 0.0292 | g_loss: 7.3159
# Epoch [   75/  101] | d_loss: 0.0078 | g_loss: 7.4271
# Epoch [   76/  101] | d_loss: 0.0457 | g_loss: 10.0322
# Epoch [   76/  101] | d_loss: 0.0009 | g_loss: 9.0304
# Epoch [   76/  101] | d_loss: 0.0194 | g_loss: 9.5148
# Epoch [   76/  101] | d_loss: 0.0021 | g_loss: 11.0327
# Epoch [   76/  101] | d_loss: 0.0072 | g_loss: 5.6181
# Epoch [   76/  101] | d_loss: 0.0163 | g_loss: 9.6458
# Epoch [   76/  101] | d_loss: 0.0019 | g_loss: 5.3762
# Epoch [   76/  101] | d_loss: 0.0005 | g_loss: 12.0526
# Epoch [   76/  101] | d_loss: 0.0007 | g_loss: 6.4268
# Epoch [   77/  101] | d_loss: 0.0027 | g_loss: 8.7859
# Epoch [   77/  101] | d_loss: 0.0019 | g_loss: 6.1933
# Epoch [   77/  101] | d_loss: 0.0081 | g_loss: 7.7998
# Epoch [   77/  101] | d_loss: 0.0002 | g_loss: 6.0660
# Epoch [   77/  101] | d_loss: 0.0005 | g_loss: 9.3346
# Epoch [   77/  101] | d_loss: 0.3053 | g_loss: 9.5048
# Epoch [   77/  101] | d_loss: 0.1068 | g_loss: 9.6959
# Epoch [   77/  101] | d_loss: 0.0021 | g_loss: 1.1355
# Epoch [   77/  101] | d_loss: 0.2803 | g_loss: 4.4803
# Epoch [   78/  101] | d_loss: 0.0124 | g_loss: 4.3706
# Epoch [   78/  101] | d_loss: 0.0393 | g_loss: 7.9830
# Epoch [   78/  101] | d_loss: 0.0049 | g_loss: 3.6632
# Epoch [   78/  101] | d_loss: 0.0519 | g_loss: 6.3508
# Epoch [   78/  101] | d_loss: 0.0043 | g_loss: 7.3041
# Epoch [   78/  101] | d_loss: 0.0006 | g_loss: 8.9970
# Epoch [   78/  101] | d_loss: 0.1935 | g_loss: 7.3594
# Epoch [   78/  101] | d_loss: 0.0019 | g_loss: 6.6714
# Epoch [   78/  101] | d_loss: 0.0033 | g_loss: 5.9200
# Epoch [   79/  101] | d_loss: 0.0053 | g_loss: 7.2338
# Epoch [   79/  101] | d_loss: 0.0079 | g_loss: 2.8702
# Epoch [   79/  101] | d_loss: 0.0043 | g_loss: 9.7555
# Epoch [   79/  101] | d_loss: 0.0333 | g_loss: 11.3974
# Epoch [   79/  101] | d_loss: 0.5029 | g_loss: 2.5812
# Epoch [   79/  101] | d_loss: 0.0001 | g_loss: 15.7196
# Epoch [   79/  101] | d_loss: 0.1253 | g_loss: 8.3829
# Epoch [   79/  101] | d_loss: 0.0014 | g_loss: 11.4733
# Epoch [   79/  101] | d_loss: 0.0059 | g_loss: 8.4822
# Epoch [   80/  101] | d_loss: 0.0048 | g_loss: 10.7150
# Epoch [   80/  101] | d_loss: 0.1298 | g_loss: 9.3594
# Epoch [   80/  101] | d_loss: 0.0084 | g_loss: 6.5250
# Epoch [   80/  101] | d_loss: 0.1520 | g_loss: 6.9897
# Epoch [   80/  101] | d_loss: 0.0051 | g_loss: 5.9162
# Epoch [   80/  101] | d_loss: 0.0089 | g_loss: 9.5581
# Epoch [   80/  101] | d_loss: 0.0013 | g_loss: 10.3997
# Epoch [   80/  101] | d_loss: 0.2010 | g_loss: 9.1557
# Epoch [   80/  101] | d_loss: 0.0105 | g_loss: 9.4447
# Epoch [   81/  101] | d_loss: 0.0031 | g_loss: 4.6915
# Epoch [   81/  101] | d_loss: 0.0024 | g_loss: 6.8131
# Epoch [   81/  101] | d_loss: 0.0017 | g_loss: 8.0995
# Epoch [   81/  101] | d_loss: 0.0329 | g_loss: 8.9561
# Epoch [   81/  101] | d_loss: 0.0287 | g_loss: 11.0124
# Epoch [   81/  101] | d_loss: 0.0015 | g_loss: 7.7747
# Epoch [   81/  101] | d_loss: 0.0012 | g_loss: 9.3405
# Epoch [   81/  101] | d_loss: 0.0012 | g_loss: 14.5495
# Epoch [   81/  101] | d_loss: 0.0087 | g_loss: 2.0424
# View Samples
# Epoch [   82/  101] | d_loss: 0.0104 | g_loss: 9.6097
# Epoch [   82/  101] | d_loss: 0.0059 | g_loss: 9.8499
# Epoch [   82/  101] | d_loss: 0.0020 | g_loss: 6.5989
# Epoch [   82/  101] | d_loss: 0.0133 | g_loss: 6.6491
# Epoch [   82/  101] | d_loss: 0.0049 | g_loss: 7.7577
# Epoch [   82/  101] | d_loss: 0.0711 | g_loss: 11.4961
# Epoch [   82/  101] | d_loss: 0.0122 | g_loss: 7.9886
# Epoch [   82/  101] | d_loss: 0.0010 | g_loss: 6.4903
# Epoch [   82/  101] | d_loss: 0.0029 | g_loss: 12.8129
# Epoch [   83/  101] | d_loss: 0.0086 | g_loss: 7.3255
# Epoch [   83/  101] | d_loss: 0.0000 | g_loss: 13.4303
# Epoch [   83/  101] | d_loss: 0.0298 | g_loss: 8.3351
# Epoch [   83/  101] | d_loss: 0.0276 | g_loss: 10.8016
# Epoch [   83/  101] | d_loss: 0.0037 | g_loss: 6.8318
# Epoch [   83/  101] | d_loss: 0.0006 | g_loss: 8.3757
# Epoch [   83/  101] | d_loss: 0.0133 | g_loss: 8.0664
# Epoch [   83/  101] | d_loss: 0.0345 | g_loss: 6.4594
# Epoch [   83/  101] | d_loss: 2.7901 | g_loss: 0.0956
# Epoch [   84/  101] | d_loss: 0.0031 | g_loss: 8.1569
# Epoch [   84/  101] | d_loss: 0.0150 | g_loss: 8.6607
# Epoch [   84/  101] | d_loss: 0.1767 | g_loss: 6.3726
# Epoch [   84/  101] | d_loss: 0.0989 | g_loss: 10.0123
# Epoch [   84/  101] | d_loss: 0.0526 | g_loss: 8.1861
# Epoch [   84/  101] | d_loss: 0.0073 | g_loss: 10.7117
# Epoch [   84/  101] | d_loss: 0.0007 | g_loss: 6.0613
# Epoch [   84/  101] | d_loss: 0.0026 | g_loss: 5.4908
# Epoch [   84/  101] | d_loss: 1.5134 | g_loss: 13.4104
# Epoch [   85/  101] | d_loss: 0.0010 | g_loss: 5.2525
# Epoch [   85/  101] | d_loss: 0.0180 | g_loss: 8.7057
# Epoch [   85/  101] | d_loss: 0.0207 | g_loss: 14.0618
# Epoch [   85/  101] | d_loss: 0.0020 | g_loss: 9.7965
# Epoch [   85/  101] | d_loss: 0.0033 | g_loss: 8.3549
# Epoch [   85/  101] | d_loss: 0.1016 | g_loss: 7.9328
# Epoch [   85/  101] | d_loss: 0.2106 | g_loss: 15.5050
# Epoch [   85/  101] | d_loss: 0.0223 | g_loss: 8.8224
# Epoch [   85/  101] | d_loss: 0.0544 | g_loss: 4.7971
# Epoch [   86/  101] | d_loss: 0.0072 | g_loss: 4.4787
# Epoch [   86/  101] | d_loss: 0.0182 | g_loss: 6.4921
# Epoch [   86/  101] | d_loss: 0.0207 | g_loss: 11.8728
# Epoch [   86/  101] | d_loss: 0.0125 | g_loss: 7.8354
# Epoch [   86/  101] | d_loss: 0.0019 | g_loss: 10.3479
# Epoch [   86/  101] | d_loss: 0.0158 | g_loss: 6.1520
# Epoch [   86/  101] | d_loss: 0.0845 | g_loss: 10.9853
# Epoch [   86/  101] | d_loss: 0.0016 | g_loss: 8.3237
# Epoch [   86/  101] | d_loss: 0.0013 | g_loss: 4.5015
# Epoch [   87/  101] | d_loss: 0.0050 | g_loss: 7.6617
# Epoch [   87/  101] | d_loss: 0.0428 | g_loss: 9.6151
# Epoch [   87/  101] | d_loss: 0.0020 | g_loss: 2.6706
# Epoch [   87/  101] | d_loss: 0.1005 | g_loss: 7.5747
# Epoch [   87/  101] | d_loss: 0.0393 | g_loss: 9.0149
# Epoch [   87/  101] | d_loss: 0.1205 | g_loss: 4.6106
# Epoch [   87/  101] | d_loss: 0.0036 | g_loss: 8.7322
# Epoch [   87/  101] | d_loss: 0.0413 | g_loss: 12.2465
# Epoch [   87/  101] | d_loss: 0.0022 | g_loss: 4.6477
# Epoch [   88/  101] | d_loss: 0.0091 | g_loss: 4.5044
# Epoch [   88/  101] | d_loss: 0.0002 | g_loss: 9.1736
# Epoch [   88/  101] | d_loss: 0.0045 | g_loss: 7.8512
# Epoch [   88/  101] | d_loss: 0.0589 | g_loss: 6.9407
# Epoch [   88/  101] | d_loss: 0.0000 | g_loss: 13.4880
# Epoch [   88/  101] | d_loss: 0.0045 | g_loss: 3.9416
# Epoch [   88/  101] | d_loss: 0.0027 | g_loss: 10.4565
# Epoch [   88/  101] | d_loss: 0.0016 | g_loss: 4.5590
# Epoch [   88/  101] | d_loss: 0.0037 | g_loss: 10.4807
# Epoch [   89/  101] | d_loss: 0.0056 | g_loss: 7.0432
# Epoch [   89/  101] | d_loss: 0.0007 | g_loss: 7.7803
# Epoch [   89/  101] | d_loss: 0.1264 | g_loss: 10.0237
# Epoch [   89/  101] | d_loss: 0.0600 | g_loss: 6.5030
# Epoch [   89/  101] | d_loss: 0.0033 | g_loss: 3.4210
# Epoch [   89/  101] | d_loss: 0.0045 | g_loss: 3.8575
# Epoch [   89/  101] | d_loss: 0.0088 | g_loss: 12.5211
# Epoch [   89/  101] | d_loss: 0.0002 | g_loss: 10.7550
# Epoch [   89/  101] | d_loss: 0.0103 | g_loss: 21.7237
# Epoch [   90/  101] | d_loss: 0.0055 | g_loss: 7.5323
# Epoch [   90/  101] | d_loss: 0.0819 | g_loss: 10.3554
# Epoch [   90/  101] | d_loss: 0.0842 | g_loss: 6.7066
# Epoch [   90/  101] | d_loss: 0.0018 | g_loss: 9.9575
# Epoch [   90/  101] | d_loss: 0.0017 | g_loss: 9.6526
# Epoch [   90/  101] | d_loss: 0.0502 | g_loss: 9.9559
# Epoch [   90/  101] | d_loss: 0.0009 | g_loss: 6.7158
# Epoch [   90/  101] | d_loss: 0.0004 | g_loss: 8.7217
# Epoch [   90/  101] | d_loss: 0.0019 | g_loss: 10.4296
# Epoch [   91/  101] | d_loss: 0.0124 | g_loss: 4.4435
# Epoch [   91/  101] | d_loss: 0.1536 | g_loss: 10.5685
# Epoch [   91/  101] | d_loss: 0.0030 | g_loss: 7.8682
# Epoch [   91/  101] | d_loss: 0.0023 | g_loss: 10.7144
# Epoch [   91/  101] | d_loss: 0.0152 | g_loss: 6.2930
# Epoch [   91/  101] | d_loss: 0.0013 | g_loss: 11.6219
# Epoch [   91/  101] | d_loss: 0.0015 | g_loss: 6.3211
# Epoch [   91/  101] | d_loss: 0.1034 | g_loss: 4.7836
# Epoch [   91/  101] | d_loss: 0.0038 | g_loss: 14.8061
# View Samples
# Epoch [   92/  101] | d_loss: 0.0009 | g_loss: 7.6023
# Epoch [   92/  101] | d_loss: 0.0249 | g_loss: 7.0495
# Epoch [   92/  101] | d_loss: 0.0403 | g_loss: 6.9301
# Epoch [   92/  101] | d_loss: 0.0053 | g_loss: 8.1228
# Epoch [   92/  101] | d_loss: 0.0024 | g_loss: 9.4224
# Epoch [   92/  101] | d_loss: 0.0019 | g_loss: 7.2317
# Epoch [   92/  101] | d_loss: 0.1537 | g_loss: 6.6481
# Epoch [   92/  101] | d_loss: 0.0123 | g_loss: 6.7171
# Epoch [   92/  101] | d_loss: 0.0620 | g_loss: 10.1644
# Epoch [   93/  101] | d_loss: 0.0012 | g_loss: 7.7163
# Epoch [   93/  101] | d_loss: 0.0014 | g_loss: 14.4546
# Epoch [   93/  101] | d_loss: 0.0006 | g_loss: 9.5408
# Epoch [   93/  101] | d_loss: 0.0378 | g_loss: 9.0488
# Epoch [   93/  101] | d_loss: 0.0091 | g_loss: 11.8715
# Epoch [   93/  101] | d_loss: 0.0136 | g_loss: 7.2268
# Epoch [   93/  101] | d_loss: 0.0057 | g_loss: 11.4773
# Epoch [   93/  101] | d_loss: 0.0033 | g_loss: 8.4208
# Epoch [   93/  101] | d_loss: 0.0055 | g_loss: 10.2299
# Epoch [   94/  101] | d_loss: 0.0002 | g_loss: 9.2973
# Epoch [   94/  101] | d_loss: 0.0008 | g_loss: 14.5507
# Epoch [   94/  101] | d_loss: 0.0002 | g_loss: 3.8166
# Epoch [   94/  101] | d_loss: 0.0005 | g_loss: 10.6448
# Epoch [   94/  101] | d_loss: 0.0049 | g_loss: 8.2963
# Epoch [   94/  101] | d_loss: 0.0012 | g_loss: 12.4646
# Epoch [   94/  101] | d_loss: 0.0059 | g_loss: 8.2926
# Epoch [   94/  101] | d_loss: 0.0107 | g_loss: 10.7091
# Epoch [   94/  101] | d_loss: 0.0001 | g_loss: 12.9263
# Epoch [   95/  101] | d_loss: 0.0022 | g_loss: 12.1397
# Epoch [   95/  101] | d_loss: 0.0763 | g_loss: 10.1481
# Epoch [   95/  101] | d_loss: 0.0018 | g_loss: 3.9949
# Epoch [   95/  101] | d_loss: 0.4231 | g_loss: 15.1274
# Epoch [   95/  101] | d_loss: 0.0603 | g_loss: 7.8070
# Epoch [   95/  101] | d_loss: 0.0348 | g_loss: 9.4364
# Epoch [   95/  101] | d_loss: 0.0038 | g_loss: 6.9559
# Epoch [   95/  101] | d_loss: 0.0008 | g_loss: 6.7558
# Epoch [   95/  101] | d_loss: 0.0052 | g_loss: 6.4263
# Epoch [   96/  101] | d_loss: 0.0233 | g_loss: 8.2310
# Epoch [   96/  101] | d_loss: 0.0218 | g_loss: 9.1515
# Epoch [   96/  101] | d_loss: 0.0019 | g_loss: 6.8284
# Epoch [   96/  101] | d_loss: 0.0003 | g_loss: 9.4032
# Epoch [   96/  101] | d_loss: 0.0001 | g_loss: 3.9441
# Epoch [   96/  101] | d_loss: 0.0006 | g_loss: 12.3415
# Epoch [   96/  101] | d_loss: 0.2871 | g_loss: 13.1405
# Epoch [   96/  101] | d_loss: 0.0144 | g_loss: 7.2954
# Epoch [   96/  101] | d_loss: 0.0001 | g_loss: 11.6885
# Epoch [   97/  101] | d_loss: 0.0026 | g_loss: 17.3369
# Epoch [   97/  101] | d_loss: 0.0026 | g_loss: 7.6833
# Epoch [   97/  101] | d_loss: 0.0005 | g_loss: 4.9107
# Epoch [   97/  101] | d_loss: 0.0072 | g_loss: 11.3872
# Epoch [   97/  101] | d_loss: 0.3105 | g_loss: 13.7941
# Epoch [   97/  101] | d_loss: 0.0253 | g_loss: 9.0572
# Epoch [   97/  101] | d_loss: 0.0136 | g_loss: 10.2884
# Epoch [   97/  101] | d_loss: 0.0200 | g_loss: 6.8677
# Epoch [   97/  101] | d_loss: 0.0023 | g_loss: 15.0873
# Epoch [   98/  101] | d_loss: 0.0375 | g_loss: 6.3455
# Epoch [   98/  101] | d_loss: 0.0012 | g_loss: 8.7881
# Epoch [   98/  101] | d_loss: 0.0008 | g_loss: 5.8762
# Epoch [   98/  101] | d_loss: 0.0129 | g_loss: 8.0081
# Epoch [   98/  101] | d_loss: 0.0177 | g_loss: 9.8050
# Epoch [   98/  101] | d_loss: 0.0023 | g_loss: 6.4334
# Epoch [   98/  101] | d_loss: 0.0061 | g_loss: 6.1431
# Epoch [   98/  101] | d_loss: 0.0558 | g_loss: 6.5119
# Epoch [   98/  101] | d_loss: 0.0026 | g_loss: 7.4809
# Epoch [   99/  101] | d_loss: 0.0005 | g_loss: 4.1906
# Epoch [   99/  101] | d_loss: 0.0520 | g_loss: 6.7135
# Epoch [   99/  101] | d_loss: 0.0149 | g_loss: 9.9822
# Epoch [   99/  101] | d_loss: 0.1954 | g_loss: 9.8197
# Epoch [   99/  101] | d_loss: 0.0022 | g_loss: 3.8804
# Epoch [   99/  101] | d_loss: 0.0470 | g_loss: 10.6284
# Epoch [   99/  101] | d_loss: 0.0238 | g_loss: 13.0991
# Epoch [   99/  101] | d_loss: 0.0161 | g_loss: 9.5770
# Epoch [   99/  101] | d_loss: 0.0018 | g_loss: 10.1235
# Epoch [  100/  101] | d_loss: 0.0093 | g_loss: 12.8464
# Epoch [  100/  101] | d_loss: 0.0094 | g_loss: 10.2840
# Epoch [  100/  101] | d_loss: 0.0260 | g_loss: 9.8007
# Epoch [  100/  101] | d_loss: 0.0360 | g_loss: 8.2946
# Epoch [  100/  101] | d_loss: 0.0080 | g_loss: 8.2476
# Epoch [  100/  101] | d_loss: 0.0249 | g_loss: 6.1694
# Epoch [  100/  101] | d_loss: 0.0015 | g_loss: 7.0566
# Epoch [  100/  101] | d_loss: 0.0056 | g_loss: 7.2643
# Epoch [  100/  101] | d_loss: 0.0093 | g_loss: 10.6306
# Epoch [  101/  101] | d_loss: 0.0527 | g_loss: 8.6933
# Epoch [  101/  101] | d_loss: 0.0023 | g_loss: 8.9712
# Epoch [  101/  101] | d_loss: 0.0222 | g_loss: 8.2299
# Epoch [  101/  101] | d_loss: 0.0002 | g_loss: 8.8744
# Epoch [  101/  101] | d_loss: 0.0011 | g_loss: 5.0365
# Epoch [  101/  101] | d_loss: 0.0004 | g_loss: 11.1394
# Epoch [  101/  101] | d_loss: 0.0030 | g_loss: 9.2036
# Epoch [  101/  101] | d_loss: 0.0009 | g_loss: 10.3658
# Epoch [  101/  101] | d_loss: 0.0011 | g_loss: 9.1316
# View Samples
# {'batch_size': 32, 'img_size': 32, 'deconv-layers': 3, 'conv-layers': 3, 'd_conv_dim': 64, 'g_conv_dim': 64, 'z_size': 100, 'lr': 0.001, 'beta1': 0.2, 'beta2': 0.999, 'dropout': 'no', 'n_epochs': 101}
# Plot Loss

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples_2(epoch, samples, train_num, param_value):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))
    fig.suptitle(param_value)
    fig.savefig('image_sets/train_' + str(train_num) + '_' + str(param_value) + '.png')

# %%
# helper function for viewing a list of passed in sample images
def view_plots(train_runs, title, param):
    number_of_pots = len(train_runs)
    train_run_list = [m[0] for m in train_runs]
    param_list = [m[1] for m in train_runs]
    epochs_calc = [m[2] for m in train_runs]
    
    ax_set = ('a' + str(m) for m in range(number_of_pots))
    
    fig, ax_set = plt.subplots(figsize=(16,4), nrows=1, ncols=number_of_pots)
    fig.suptitle(title)
    for ii,train_num in enumerate(train_run_list):
        df = pd.read_excel('training_results/train_' + str(train_num) + '_' + str(param_list[ii]) + '.xlsx')  # doctest: +SKIP
        loss_d = df['Discriminator'].values
        loss_g = df['Generator'].values
        ax_set[ii].plot(df.index/epochs_calc[ii], loss_d, label='Discriminator')
        ax_set[ii].plot(df.index/epochs_calc[ii], loss_g, label='Generator')
        ax_set[ii].set_title('Train_' + str(train_num))
        #ax_set[ii].xlabel('n_epochs', fontsize=14)
        #ax_set[iniidex].ylabel('loss', fontsize=14)
        ax_set[ii].legend()
        
    fig.savefig('plots/train_' + str(param) + '.png')

# %% [markdown]
# In the following section the parameter tuning which was investigated in separated training runs is appended.

# %% [markdown]
# ## Parameter: n_epochs
#
# Parameters          | 1st Train-Run | 2nd Train-Run | 3rd Train-Run | 4th Train-Run | 5th Train-Run | 6th Train-Run |
# ----------          | ------------- | ------------- | ------------- | ------------- | ------------- | ------------- |
# batch_size          |   128         |   128         |   128         |   128         |   128         |   128         |
# img_size            |   32          |   32          |   32          |   32          |   32          |   32          |
# deconv-layers       |   3           |   3           |   3           |   3           |   3           |   3           |
# conv-layers         |   3           |   3           |   3           |   3           |   3           |   3           |
# d_conv_dim          |   32          |   32          |   32          |   32          |   32          |   32          |
# g_conv_dim          |   32          |   32          |   32          |   32          |   32          |   32          |
# z_size              |   100         |   100         |   100         |   100         |   100         |   100         |
# lr                  |   0.001       |   0.001       |   0.001       |   0.001       |   0.001       |   0.001       |
# beta1               |   0.5         |   0.5         |   0.5         |   0.5         |   0.5         |   0.5         |
# beta2               |   0.999       |   0.999       |   0.999       |   0.999       |   0.999       |   0.999       |
# dropout             |   no          |   no          |   no          |   no          |   no          |   no          |
# **n_epochs**        |   `1`         |   `10`        |   `50`        |   `100`       |   `500`       |   `1000`      |

# %%
# n_epochs = 1, 10, 50, 100, 200, 300, 400, 500
parameter_list_name = [6* 'Train32 best off']
train_num_list = [6* best_off]
param_list = ['num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs']
epoch_list = [1, 10, 50, 100 , 200, 300, 400, 500]
for epoch, param, param_value_name, train_num in zip(epoch_list, param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_' + str(epoch) + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '_' + str(param_value_name) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-072bc23f6333> in <module>
#       1 # n_epochs = 1, 10, 50, 100, 200, 300, 400, 500
#       2 parameter_list_name = [6* 'Train32 best off']
# ----> 3 train_num_list = [6* best_off]
#       4 param_list = ['num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs', 'num_epochs']
#       5 epoch_list = [1, 10, 50, 100 , 200, 300, 400, 500]
#
# NameError: name 'best_off' is not defined

# %%
view_plots([[1, 'num_epochs', 3],
            [2, 'num_epochs', 3],
            [3, 'num_epochs', 3],
            [4, 'num_epochs', 3],
            [5, 'num_epochs', 3],
            [6, 'num_epochs', 3]], 'Number of epochs', 'n_epochs')

# %% [markdown]
# ### Result for parameter n_epochs:
# Best value setting for the number of epochs extends to the range 50...100. Lower epoch values lead to underfitting, higher epoch values tend to pronounced noisy behavior of the discriminator loss. In both regimes the generated face images are blurred. In the following 100 epochs will be used for further parameter studies.

# %% [markdown]
# ## Parameter: number of conv-layers and deconv-layers
#
# Parameters          | 4th Train-Run | 8th Train-Run |
# ----------          | ------------- | ------------- |
# batch_size          |   128         |   128         |
# img_size            |   32          |   32          |
# **deconv-layers**   |   `3`         |   `4`         |
# **conv-layers**     |   `3`         |   `4`         |
# d_conv_dim          |   32          |   32          |
# g_conv_dim          |   32          |   32          |
# z_size              |   100         |   100         |
# lr                  |   0.001       |   0.001       |
# beta1               |   0.5         |   0.5         |
# beta2               |   0.999       |   0.999       |
# dropout             |   no          |   no          |
# n_epochs            |   100         |   100         |

# %%
# conv-layers=deconv-layers=3 ... 4
parameter_list_name = ['conv-layers=deconv-layers=3','conv-layers=deconv-layers=4']
train_num_list = [4, 8]
param_list = ['num_epochs', 'conv_deconv']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[4, 'num_epochs', 3],
            [8, 'conv_deconv', 3]],'Number of conv- and deconv-layers', 'conv_deconv')

# %% [markdown]
# ### Result for parameter number of conv-layers and deconv-layers:
# There is no clear trend with regard to the number of conv-layers and deconv-layers. Corresponding images for conv-layers=3 and deconv-layers=3 look similar to conv-layers=4 and deconv-layers=4. However, the trend of losses is slightly better for conv-layers=4 and deconv-layers=4, higher (positive) loss for the Generator and slightly lower loss for the Discriminator. In the following conv-layers=4 and deconv-layers=4 will be used for further parameter studies.

# %% [markdown]
# ## Parameter: batch_size
#
# Parameters          | 14th Train-Run | 15th Train-Run | 16th Train-Run  | 17th Train-Run |
# ----------          | ------------- | -------------   | -------------   | -------------  |
# **batch_size**      |   `64`        |   `128`         |   `256`         |  `512`         |
# img_size            |   32          |   32            |   32            |   32           |
# deconv-layers       |   4           |   4             |   4             |   4            |
# conv-layers         |   4           |   4             |   4             |   4            |
# d_conv_dim          |   32          |   32            |   32            |   32           |
# g_conv_dim          |   32          |   32            |   32            |   32           |
# z_size              |   100         |   100           |   100           |   100          |
# lr                  |   0.001       |   0.001         |   0.001         |   0.001        |
# beta1               |   0.5         |   0.5           |   0.5           |   0.5          |
# beta2               |   0.999       |   0.999         |   0.999         |   0.999        |
# dropout             |   no          |   no            |   no            |   no           |
# n_epochs            |   100         |   100           |   100           |   100          |

# %%
# batch_size= 64 , 128, 256, 512
parameter_list_name = ['batch_size=64','batch_size=128', 'batch_size=256', 'batch_size=512']
train_num_list = [14, 15, 16, 17]
param_list = ['batch_size', 'batch_size', 'batch_size', 'batch_size']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[14, 'batch_size', 5],
            [15, 'batch_size', 3],
            [16, 'batch_size', 2],
            [17, 'batch_size', 1]], 'Batch size', 'batch_size')

# %% [markdown]
# #### Result for parameter batch_size:
# A larger batch_size has a positive effect on the computational boost. However, if the batch_size is getting too high the feature resolution is getting worse. This can be clearly seen if one compares a batch_size of 512 with a batch_size of 128. For the further study a batch_size of 128 has been chosen.

# %% [markdown]
# ## Parameter: conv_dim
#
# Parameters          | 8th Train-Run | 11th Train-Run  | 12th Train-Run  | 13th Train-Run |
# ----------          | ------------- | -------------   | -------------   | -------------  |
# batch_size          |   128         |   128           |   128           |  128           |
# img_size            |   32          |   32            |   32            |   32           |
# deconv-layers       |   4           |   4             |   4             |   4            |
# conv-layers         |   4           |   4             |   4             |   4            |
# **d_conv_dim**      |   `32`        |   `64`          |   `128`         |  `256`         |
# **g_conv_dim**      |   `32`        |   `64`          |   `128`         |  `256`         |
# z_size              |   100         |   100           |   100           |   100          |
# lr                  |   0.001       |   0.001         |   0.001         |   0.001        |
# beta1               |   0.5         |   0.5           |   0.5           |   0.5          |
# beta2               |   0.999       |   0.999         |   0.999         |   0.999        |
# dropout             |   no          |   no            |   no            |   no           |
# n_epochs            |   100         |   100           |   100           |   100          |

# %%
# conv_dim= 32, 64 , 128, 256
parameter_list_name = ['conv_dim=32', 'conv_dim=64','conv_dim=128', 'conv_dim=256']
train_num_list = [8, 11, 12, 13]
param_list = ['conv_deconv', 'conv_dim', 'conv_dim', 'conv_dim']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[8, 'conv_deconv', 3],
            [11, 'conv_dim', 3],
            [12, 'conv_dim', 3],
            [13, 'conv_dim', 3]], 'Size of conv_dim', 'conv_dim')

# %% [markdown]
# #### Result for parameter conv_dim:
# With a higher conv_dim for the Generator and the Discriminator the resolution of feature details is getting higher. For example, eyes are better resolved with a conv_dim=256 than with a conv_dim=32. However, even a conv_dim of 64 leads to convincing results.

# %% [markdown]
# ### Parameter: lr
#
# Parameters          | 21th Train-Run | 14th Train-Run  | 22th Train-Run |
# ----------          | ------------- | -------------   | -------------   |
# batch_size          |   128         |   128           |   128           |
# img_size            |   32          |   32            |   32            |
# deconv-layers       |   4           |   4             |   4             |
# conv-layers         |   4           |   4             |   4             |
# d_conv_dim          |   64          |   64            |   64            |
# g_conv_dim          |   64          |   64            |   64            |
# z_size              |   100         |   100           |   100           |
# **lr**              |   `0.01`      |   `0.001`       |   `0.0001`      |
# beta1               |   0.5         |   0.5           |   0.5           |
# beta2               |   0.999       |   0.999         |   0.999         |
# dropout             |   no          |   no            |   no            |
# n_epochs            |   100         |   100           |   100           |

# %%
# lr= 0.01, 0.001, 0.0001
parameter_list_name = ['lr=0.01', 'lr=0.001','lr=0.0001']
train_num_list = [21, 14, 22]
param_list = ['lr', 'batch_size', 'lr', 'conv_dim']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %%
view_plots([[21, 'lr', 3],
            [14, 'batch_size', 3],
            [22, 'lr', 3]], 'Learning rate', 'lr')

# %% [markdown]
# #### Result for parameter lr:
# Learning rates in the range between 0.01 and 0.0001 were tested. In all three cases the GAN is able to learn and generated fake images of faces are successfully constructed. However,  a learning rate of lr=0.001 or lr=0.0001 lead to a slightly better feature resolution than lr = 0.01.

# %% [markdown]
# ### Final hyperparameter setting
# The following table shows the best-of setting of the investigated parameter tuning.
#
# Parameters          | 14th Train-Run|
# ----------          | ------------- |
# batch_size          |   32          |
# img_size            |   32          |
# deconv-layers       |   4           |
# conv-layers         |   4           |
# d_conv_dim          |   64          |
# g_conv_dim          |   64          |
# z_size              |   100         |
# lr                  |   0.0002      |
# beta1               |   0.2         |
# beta2               |   0.999       |
# dropout             |   yes         |
# n_epochs            |   100         |

# %% [markdown]
# ### Final fake image output

# %%
# final result
parameter_list_name = ['Final result']
train_num_list = [22]
param_list = ['lr']
for param, param_value_name, train_num in zip(param_list, parameter_list_name, train_num_list):
    """
    # plot pkl file
    with open('training_results_pkl/train_' + str(train_num) + '_' + param + '_samples.pkl', 'rb') as f:
        samples = pkl.load(f)
    _ = view_samples_2(-1, samples, train_num, param_value_name)
    """
    # plot png file
    plt.figure(figsize=(40,20))
    img = plt.imread('image_sets/train_' + str(train_num) + '.png')
    plt.axis('off')
    #plt.title(param_value)
    plt.imshow(img)

# %% [markdown]
# ### Corresponding loss for the final setting

# %%
# loss for reasonable setting
train_num = 22
param = 'lr'
fig, ax = plt.subplots()
df = pd.read_excel('training_results/train_' + str(train_num) + '_' + str(param) + '.xlsx')  # doctest: +SKIP
loss_d = df['Discriminator'].values
loss_g = df['Generator'].values
plt.plot(df.index/3, loss_d, label='Discriminator')
plt.plot(df.index/3,loss_g, label='Generator')
plt.title("Train_22")
plt.legend()
fig.savefig('plots/train_22_single.png')

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# ### Reasons for the chosen final hyperparameter setting:
# A whole bunch of parameters setting were tested in sequences (see evaluation above).
#
# #### n_epochs:
# n_epochs was varied between 1 and 1000. Its best value setting extends to the range 50...100. Lower epoch values lead to underfitting, higher epoch values tend to pronounced noisy behavior of the discriminator loss. For both extreme regimes the generated face images are blurred. Therefore n_epochs was set to 100.
#
# #### number of conv-layers and deconv-layers:
# Two models were constructed: one with 3 and another one with 4 conv and deconv layers for the discriminator and generator, respectively. Corresponding images for conv-layers=deconv-layers=3 look similar to conv-layers=deconv-layers=4. Hence, a clear trend is hard to distinguish in these examples. However, the trend of losses is slightly better for conv-layers=deconv-layers=4 than for conv-layers=deconv-layers=3, i.e. the loss for the Generator is higher and the loss for the Discriminator is slightly lower. Therefore conv-layers=4 and deconv-layers=4 have been used for further parameter studies.
#
# #### batch_size:
# The value range for the batch_size was chosen between 16 and 512. A larger batch_size has a positive effect on the computational boost. However, if the batch_size is getting too high the feature resolution is getting worse (more blurred). This can be clearly seen if one compares a batch_size of 512 with a batch_size of 128. If the batch size is too small then the gradients will become more unstable and would need to reduce the learning rate. So batch size and learning rate are linked. Also if one use a batch size too big then the gradients will become less noisy but it will take longer to converge. Therefore a batch_size of 128 has been chosen. Up to a batch_size of 512 no out-of-memory errors were observed (getting critical for higher batch_sizes).
#
# ##### conv_dim:
# The conv_dim value was investigated in the range between 32 and 256. With a higher conv_dim for the Generator and the Discriminator the resolution of feature details is getting higher. For example, eyes are better resolved with a conv_dim=256 than with a conv_dim=32. However, even a conv_dim of 64 leads to convincing results.
#
# #### lr:
# As learning rates 0.01, 0.01 and 0.0001 were tested. In all three cases the GAN is able to learn and generated fake images of faces successfully. However, lr=0.001 or lr=0.0001 lead to a slightly better feature resolution than lr = 0.01.
#
# ### Further improvements:
# - To overcome the issue of a biased dataset (celebrity faces that are mostly white): one could add more images of non-white celebrity faces to get a more balanced dataset in the end.
#
# - The model size is limited by the number of conv-layers and deconv-layers which was set to 4 in maximum. Higher values were not tested so far. Increasing the model size could especially enhance the feature extraction of the Discriminator. The adversarial Generator is then forced to produce images with better feature resolution.
#
# - A further increase of the conv_dim could lead to better results. However, this would significantly increase the training time.
#
# - The dataset images are 64x64x3 NumPy images. In the get_dataloader function I resized the images down to 32x32x3. This is the image size for the Discriminator input and the size of the Generator output. This resolution of the generated images is noisy. If one would keep width=64 and height=64 the images could resemble more the original ones. However, this would also increase the training duration.
#
# - Regarding the optimizer strategy: For the Discriminator as well as for the Generator the same type of optimizer (Adam) was chosen with a learning rate down to 0.0001. A combination of different optimizer like SGD for the Discriminator and Adam for the Generator as proposed by [Soumith](https://github.com/soumith/ganhacks) has not been tested yet.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
